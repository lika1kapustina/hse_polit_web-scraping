# %% [markdown]
# # Сбор данных с Web-scraping и API для социально-научных исследований
# ---
# ## Семинары 7-8. Понятие API. Работа с API ВКонтакте.
#
# ---
# *ФСН, ОП "Политология", 2023-2024 гг.*
#
# Лика Капустина,
#
# lkapustina@hse.ru
#
# **План занятия:**
# 1. [Введение в API](#par1)
# 2. [API ВКонтакте: документация и получение доступа](#par2)
# 3. [Как отправить запрос к API и обработать json](#par3)
# 4. [Немного о docstrings](#par4)
# 5. [Собираем данные о наших друзьях](#par5)
# 6. [Генерируем данные для сетевого анализа](#par6)
# 7. [Заключение](#parlast)
# ---
#
# **Основные ссылки**
# - [Документация API ВКонтакте](https://dev.vk.com/ru/api/overview);
# - [Как получить токен для работы с API ВКонтакте](https://github.com/lika1kapustina/hse_polit_web-scraping/blob/main/api_vk_get_token_and_test.ipynb).

# %% [markdown]
# ## Введение в API<a name="par1"></a>
#
# В рамках презентации мы с вами подробно обсудили понятие **API**. Для тех, кто пропустил этот материал – **API – Application Programming Interface** – это интерфейс, позволяющий вам взаимодействовать с приложением или веб-сервером.
#
# <font color='blue'>Например, представим что вы студент, которому нужно забронировать аудиторию для проведения консультации. Делать вы это будете через учебный офис. В этой ситуации:</font>
# * **Вы – студент – <font color='green'>пользователь</font>**;
# * **<font color='orange'>Сервер</font>, к которому вы бы хотели обратиться – это корпоративные системы университета**;
# * **<font color='violet'>API</font>**, которое позволяет вам отправить запрос к серверу и получить данные в удобном формате – **учебный офис**. Вас не беспокоит в каком формате происходит взаимодействие <font color='violet'>API</font> и <font color='orange'>сервера</font> (через какие внутренние сервисы учебный офис будет проверять доступность аудиторий и бронировать для вас её), вам нужно получить только ответ от <font color='violet'>API</font> – то есть, от учебного офиса: письмо о том, что аудитория найдена и забронирована.
# * **Взаимодействие с API ограничивается прописанными методами**: вы можете попросить учебный офис прислать вам расписание, принять вашу справку об уважительной причине пропуска занятий, забронировать вам аудиторию для консультации или отписать вас от факультатива. Но у сотрудников учебного офиса есть ряд рабочих обязанностей – это как методы у API, и они не будут делать то что выходит за их пределы. *Например, вы не можете попросить сотрудников учебного офиса отменить вам пересдачу, выставить оценку выше реальной или прислать вам мем*.
#
# **Особенности API, которые мы сейчас с вами увидим:**
# 1. Запросы к API строго унифицированы;
# 2. Перед тем как отправить запрос к API, чаще всего нужно получить токен;
# 3. API отдает вам данные в основном в форматах JSON и XML.

# %% [markdown]
# ## API ВКонтакте: документация и получение доступа <a name="par1"></a>
#
# **API ВКонтакте: документация**
#
# Социальная сеть ВКонтакте имеет очень много сервисов для разработчиков, в том числе, понятный и хорошо задокументированный API. Документация API ВКонтакте доступна по [ссылке](https://dev.vk.com/ru/api/overview).
#
# **API ВКонтакте имеет множество семейств методов**: `Apps`, `Account`, `Adds`, `Photos` и другие. В чем содержательный смысл? Определенное семейство методов отвечает за взаимодействие с определенными объектами – приложениями, аккаунтом, рекламой, фотографиями и т.д.
#
# **Например**: обращаясь к семейству методов [`Groups`](https://dev.vk.com/ru/method/groups), вы узнаете о методах работы с группами: вы можете получить список сообществ из выбранной категории каталога с помощью метода `groups.getCatalog`, с помощью метода `groups.get` получить список сообществ определенного пользователя, с помощью метода `groups.getById` получить информацию об одном или нескольких сообществах по их id.
# <p></p>
# <center><b><font size=4>Задача №1</font></b></center>
#
# **Давайте попрактикуемся в работе с API ВКонтакте. Найдите следующие методы и сохраните значения в переменные `answer_1`, `answer_2`, `answer_3`:**
# 1. Метод, с помощью которого можно **сделать пост** на вашей стене;
# 2. Метод, с помощью которого можно **получить детальную информацию** об опросе;
# 3. Метод, с помощью которого можно **получить информацию о подписчиках пользователя**

# %%
answer_1 = 'wall.post'
answer_2 = 'polls.getById'
answer_3 = 'users.getFollowers'

# %% [markdown]
# **В чем особенности API ВКонтакте?**
# 1. Это API готово отдать вам огромное количество самых разных данных о разных объектах;
# 2. Позволяет не просто получать данные из социальной сети, а и управлять группами или своей страницей (пролайкать чужие посты, написать кому-то в сообщения, забанить и т.д.);
# 3. Имеет хорошую и подробную документацию;
# 4. Поддержка отвечает в течение суток или двух;
#
# **В чем ограничения API ВКонтакте?**
# 1. Вы можете получить доступ только к тем данным, к которым имеете доступ в приложении. Не получиться залезть в чужие переписки, получить список друзей пользователя с закрытой страницей и т.д.;
# 2. Есть [ограничения на число запросов](https://dev.vk.com/ru/api/api-requests#:~:text=К%20методам%20API%20ВКонтакте%20(за,составляет%2020%20запросов%20в%20секунду.): **не больше 3 запросов в секунду**;
#
#
# **Что нужно, чтобы пользоваться API ВКонтакте?** Нужно получить специальный токен, который позволит ВКонтакте понимать, что запросы отправляете вы и что вы можете получать только определенные данные в ответ (например, вы можете запросить список сообщений, но должны получить только сообщения, отправленные вами, а не сообщения из переписок которые вели другие пользователи). Инструкция по получению токена доступна по [ссылке](https://github.com/lika1kapustina/hse_polit_web-scraping/blob/main/api_vk_get_token_and_test.ipynb).
#
# **Как выглядит токен ВКонтакте?**
# По структуре он выглядит так, где:
# `vk1.533bacf01e1165b57531ad114461ae8736d6506a3ууу1e2texpires_in=864000id=1111111`
# * `vk1.533bacf01e1165b57531ad114461ae8736d6506a3ууу1e2texpires_in=864000id=1111111` – это ваш токен;
# * `expires_in=86400` это число секунд, через которое токен потеряет силу (86400 секунд это 24 часа, то есть этот токен действует 24 часа);
# * `id=1111111` это ваш id пользователя;
#
# <font color='red'>Важно:</font> если вы сгенерировали токен и собираетесь получать данные из ВКонтакте, не пользуйтесь VPN-сервисами и не меняйте IP-адрес. Если вы включите VPN, то наткнетесь на ошибку `'User authorization failed: access_token was given to another ip address'`.
# * Хорошая новость в том, что если его отключить, то вы сможете продолжать пользоваться вашим токеном и отправлять запросы к ВКонтакте.
# * Если вы поменяли IP-адрес, всегда можно перегенерировать токен, сохранить его в переменную, и продолжить работу.
#
# <font color='red'>Важно: НИКОМУ НЕ ПРИСЫЛАЙТЕ СВОЙ ТОКЕН.</font> ВКонтакте ласково напомнит вам об этом в процессе его получения, но запомните – если вы отдадите кому-то свой токен, то можете потерять доступ к аккаунту.
#
# **Когда вы получили токен, сохраните его в переменную в ноутбуке/файле `.py` из которого будете отправлять запросы к API ВКонтакте**.

# %% [markdown]
# ## Как отправить запрос к API<a name="par3"></a>
#
# Каждый наш запрос к API ВКонтакте будет выглядеть следующим образом:
#
# 0. **Если мы работаем с новым методом ВКонтакте, то первым делом изучаем справку по нему**: какие параметры можно включить в запрос, какой объект этот метод вернет:
#     * Например, мы решили собрать посты из сообщества с помощью метода `wall.get`. Документация к нему доступна по [ссылке](https://dev.vk.com/ru/method/wall.get);
#     * Там же мы видим раздел **Результат**:
# >```После успешного выполнения возвращает объект, содержащий число результатов в поле count и массив объектов записей на стене в поле items. Если был задан параметр extended = 1, возвращает число результатов в поле count, отдельно массив объектов записей на стене в поле items, пользователей в поле profiles и сообществ в поле groups```
#     * Помимо этого, на странице с методом мы **в конце увидим, информацию об объектах какого типа он возвращает**. Там же содержится ссылка на описание этого типа объектов. Для `wall.get` это **записи на стене**. Вы можете кликнуть на [ссылку, ведущую на описание этого типа объектов](https://dev.vk.com/ru/reference/objects/post) и увидите там следующее: ```Объект, описывающий запись на стене пользователя или сообщества, содержит следующие поля``` (и перечисленные поля и возможные значения.
#
#
#
# 1. **Подбираем параметры**. <font color='blue'>Эти параметры отличаются для разных методов</font>. На странице с методом `wall.get` указаны параметры, которые нам нужно/можно скормить методу. А именно:
#     * `owner_id` – Идентификатор пользователя или сообщества, со стены которого необходимо получить записи (по умолчанию — текущий пользователь);
#     * `domain` – Короткий адрес пользователя или сообщества;
#     * `offset` – Смещение, необходимое для выборки определённого подмножества записей;
#     * `count` – Количество записей, которое необходимо получить. Максимальное значение: `100` (то есть, за один запрос мы можем получить только 100 записей);
#     * `filter` – Определяет, какие типы записей на стене необходимо получить. Возможные значения: `owner` (записи владельца стены), `others` (записи не от владельца стены) и т.д.;
#     * `extended` – Если равен `1` — в ответе будут возвращены дополнительные поля `profiles` и `groups`, содержащие информацию о пользователях и сообществах. По умолчанию: `0`.
#
# 2. **Создаем ссылку для запроса:** <font color='green'>Этот шаблон универсален для всех методов</font>. Как она выглядит? В общем виде так:
#
#
# >```url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token```
#
# **Где:**
# * `method` - метод (например, `wall.get`);
# * `parameters` – параметры запроса для этого метода (см. пункт №1);
# * `version` – версия API ВКонтакте;
# * `token` – ваш токен.
#
# **Как уточнить параметры запроса?**
#
# Давайте посмотрим на эту строчку:
#
# >```parameters=f'owner_id=-{group_id}&count=5&filter=owner&extended=1&offset={offset}&fields=name,screen_name,members_count'```
#
# **Где все переменные это параметры из пункта №1:**
# * `owner_id` это `Идентификатор пользователя или сообщества, со стены которого необходимо получить записи (по умолчанию — текущий пользователь)`;
# * `count=5` означает что мы хотим получить 5 постов;
# * `filter=owner` означает что мы хотим получить только посты от имени сообщества;
# * `extended=1` означает что мы хотим получить дополнительную информацию по полям `profiles` и `groups`;
# * `offset=` означает сдвиг для получения постов;
# * `fields=` означает переменные которые мы хотим получить для сообществ.
#
#
# Здесь мы используем f-строку, не пугайтесь. Напомню синтаксис f-строк в ячейке ниже.
#
# 3. **Отправляем запрос с помощью `requests.get()` и обрабатываем информацию!**

# %%
# когда вы используете f-строки, вы можете удобнее создавать и печатать строки. Например:
name = input('Введите ваше имя') # вводим значение

print('Ваше имя это', name) # печать без f-строки
print(f'Выше имя это {name}') # начинаем строку с f, открываем кавычки, открываем фигурные скобки когда хотим 
# напечатать какую-то конкретную переменную

# %% [markdown]
# Чтобы начать, давайте импортируем необходимые библиотеки

# %%
import requests      # запросы к серверу
import pandas as pd  # работа с таблицами
import numpy as np   # работа с арифметическими операциями
import json          # работа с файлами json

# %% [markdown]
# Введем сюда наши данные (хватит только токена)

# %%
token = input('Введите ваш токен тут: ') # вводим токен;
myid = token.split('user_id=')[1]        # получим ваш id пользователя из токена;
version = '5.199'                        # версия api вк, которую вы используете

# %% [markdown]
# Сгенерируем строку, чтобы получить посты сообщества [Уполномоченный по правам студентов и аспирантов НИУ ВШЭ](https://vk.com/ombudsman_hse), используя метод `wall.get`:

# %%
method = 'wall.get'           # метод
group_id = '203966578'        # id групы
offset = 0                    # сдвиг
q = 5                         # число постов, которые нам вернет этот метод

# Создаем строку с параметрами;
parameters=f'owner_id=-{group_id}&count={q}&filter=owner&extended=1&offset={offset}&fields=name,screen_name,members_count'

# Генерируем ссылку 
url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token

# Отправляем запрос:
response = requests.get(url) # привет, requests
wall_data = response.json() # превращаем ответ в объект json, сохраняем в переменную wall_data

# %% [markdown]
# Перед тем, как мы посмотрим на объект `wall_data`, давайте посмотрим на ссылку `url`, которую мы создали. Что же там находится?

# %%
print(f'Откройте ссылку: {url}')

# %% [markdown]
# Верно, там находится ровно та же самая информация, что и в `wall_data`. **Отличие в том,** что мы обработали эти данные с помощью `requests.get()`, преобразовали в **json**, и сохранили в переменную.
#
# Теперь давайте исследуем объект `wall_data`:

# %%
wall_data # посмотрим на объект
# Out:
# {'response': {'count': 92,
#   'items': [{'inner_type': 'wall_wallpost',
#     'can_delete': 1,
#     'can_pin': 1,
#     'donut': {'is_donut': False},
#     'is_pinned': 1,
#     'comments': {'count': 0},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'btsjLvwY7QErOnCxhHaG439TyGal',
#     'has_translation': False,
#     'postponed_id': 468,
#     'type': 'post',
#     'carousel_offset': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1703315938,
#        'id': 457239480,
#        'owner_id': -203966578,
#        'access_key': '723ffb2b329aab3986',
#        'sizes': [{'height': 75,
#          'type': 's',
#          'width': 75,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=75x75&quality=95&sign=e02501c46310b8866db249785430ff3b&c_uniq_tag=73php1pSyosrCipg3ZrWMqtf3VFcIgnwTEgbm4O4Cqc&type=album'},
#         {'height': 130,
#          'type': 'm',
#          'width': 130,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#         {'height': 604,
#          'type': 'x',
#          'width': 604,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=604x604&quality=95&sign=b3681730a3954fc805d85104af5d47c8&c_uniq_tag=n2623OgYPiktK_aWyk8KWf0Yeggsb66qg1UepEOAfoo&type=album'},
#         {'height': 800,
#          'type': 'y',
#          'width': 800,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=800x800&quality=95&sign=dfa9d79dcd7434f890beb84aeac733d5&c_uniq_tag=SxfKOF0ovsW-6qQf-Mofgksg0AvSuyZu5yYXcgF_vkE&type=album'},
#         {'height': 130,
#          'type': 'o',
#          'width': 130,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#         {'height': 200,
#          'type': 'p',
#          'width': 200,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=200x200&quality=95&sign=825b9adccefd411daf03cf2283a92233&c_uniq_tag=t8FIZdvgvquHTjPrfFvJY6BSONdRd34MZ1KqIJS2ipE&type=album'},
#         {'height': 320,
#          'type': 'q',
#          'width': 320,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=320x320&quality=95&sign=0c1227d4ad034ec4760950f19d3dcbd6&c_uniq_tag=KpcQvP8TjXrGd8Yi8QSpNRZJIrvz15x5IoM-kRvzHVo&type=album'},
#         {'height': 510,
#          'type': 'r',
#          'width': 510,
#          'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size
, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1361 \n🔹 Дмитрий Щагин, ФКН, локальный омбудсмен Факультета компьютерных наук - https://vk.com/wall-130897705_460 \n🔸 Аня Молчанова, ФЭН, секретарь Аппарата Уполномоченного - https://vk.com/wall-130899601_798 \n🔹 Екатерина Егерева, ФКИ, защищает права студентов ОП «Журналистика» и «Медиакоммуникации» - https://vk.com/wall-130898791_1199 \n🔸 Екатерина Иванова, ФСН, локальная омбудсвумен ОП «Государственное и муниципальное управление» - https://vk.com/wall-130899141_1528 \n🔹 Артем Терехов, МИЭМ, локальный омбудсмен «Прикладной математики» и «Компьютерной безопасности» - https://vk.com/wall-130896227_849 \n🔸 Мария Мишхожева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1363 \n🔹 Вася Вольских, Общежитие 2, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130907078_95 \n🔸 Данила Морозов, ФП, Уполномоченный по правам студентов ВШЭ - https://vk.com/wall-130899003_1372 \n🔹 Арсений Самусенко, ФП, глава отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1335 \n🔸 Лика Капустина, ФСН, глава Аппарата Уполномоченного - https://vk.com/wall-130899141_1628 \n🔹 Артем Лебедев, ВШБ, защищает права жителей «ЖК Level Амурская» - https://vk.com/wall-130896736_1207 \n🔸 Даниил Баранков, ФКН, член отдела аналитики Аппарата Уполномоченного - https://vk.com/wall-130897705_495 \n \n📌 Проголосовать за ваших кандидатов можно по ссылке: vote.studsovet.me \n \n⏰ Не откладывайте: возможность отдать голос за своих представителей закроется в понедельник, 25 декабря, 19:00. \n \nСостоящий из прекрасных правозащитников и неравнодушных студентов, \nВсегда ваш - Аппарат Уполномоченного ❤',
#     'views': {'count': 3276}},
#    {'inner_type': 'wall_wallpost',
#     'can_delete': 1,
#     'can_pin': 1,
#     'donut': {'is_donut': False},
#     'comments': {'count': 0},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'vZMDq6aBzd48_3sSJxcDGaNbF6w8',
#     'has_translation': False,
#     'postponed_id': 475,
#     'type': 'post',
#     'attachments': [{'type': 'doc',
#       'doc': {'id': 670711017,
#        'owner_id': 357249335,
#        'title': 'с нг.jpg',
#        'size': 97285,
#        'ext': 'jpg',
#        'date': 1704045756,
#        'type': 4,
#        'url': 'https://vk.com/doc357249335_670711017?hash=aBfkbVjmq7swss2UFNigOV1ABlZffSPL453xbOoKKHs&dl=51ymg39v24Z8fCin8bt6weI5MBbuxRqi0q4EBEyqM9g&api=1&no_preview=1',
#        'preview': {'photo': {'sizes': [{'src': 'https://sun9-73.userapi.com/c235131/u357249335/d40/-3/m_6b6b9b99b3.jpg',
#            'width': 130,
#            'height': 100,
#            'type': 'm'},
#           {'src': 'https://sun9-75.userapi.com/c235131/u357249335/d40/-3/s_6b6b9b99b3.jpg',
#            'width': 100,
#            'height': 75,
#            'type': 's'},
#           {'src': 'https://sun9-49.userapi.com/c235131/u357249335/d40/-3/x_6b6b9b99b3.jpg',
#            'width': 604,
#            'height': 602,
#            'type': 'x'},
#           {'src': 'https://sun9-70.userapi.com/c235131/u357249335/d40/-3/o_6b6b9b99b3.jpg',
#            'width': 803,
#            'height': 800,
#            'type': 'o'}]}},
#        'is_unsafe': 0,
#        'access_key': 'yfJvyUKKXKng03l4uvRsDU8ni0D6Wp0YG7QeWEjkaZg'}}],
#     'date': 1704051000,
#     'edited': 1704128627,
#     'from_id': -203966578,
#     'id': 476,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 13, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 13, 'items': [{'id': 0, 'count': 13}]},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count':
type=album'},
#         {'height': 604,
#          'type': 'x',
#          'width': 604,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=604x604&quality=95&sign=a43cdaf06e1bf77478ef080fe90d237e&c_uniq_tag=1MXhd0YtLA_wDoRwN5YkKB6I3wk85bWSSXmu6wPkQzM&type=album'},
#         {'height': 800,
#          'type': 'y',
#          'width': 800,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=800x800&quality=95&sign=30ab4e426fb5b829c047f9735e008304&c_uniq_tag=Ni6p2q82V-nzoIl9mCw5gez3fp-fLw4NSW6FDwLtS_c&type=album'},
#         {'height': 130,
#          'type': 'o',
#          'width': 130,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=130x130&quality=95&sign=ced61ed384ec03d39d24a78f8d81e344&c_uniq_tag=S-WOurtUuvLNaxV_73q8cgGBnskE2-PwRk7tcan0vpg&type=album'},
#         {'height': 200,
#          'type': 'p',
#          'width': 200,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=200x200&quality=95&sign=d9cb5e7c510b0b8d263c9629d5abc038&c_uniq_tag=R1hIcenSgSPrT-TDxgVwM3AiFh21D_xYaE-ECQ960NE&type=album'},
#         {'height': 320,
#          'type': 'q',
#          'width': 320,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=320x320&quality=95&sign=aa48b8c184e218bca815930058e6265f&c_uniq_tag=1An0l3Br4z5CcZxc1ZH7Fg-a2ObSuChQJE6W4h_PAIM&type=album'},
#         {'height': 510,
#          'type': 'r',
#          'width': 510,
#          'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=510x510&quality=95&sign=6af5cb3e864036ff7db9d6a659aa6013&c_uniq_tag=pcmjVWiG6pZMqJ9uNmeEBbh7q95wVVCCnIqWeQ7BddI&type=album'}],
#        'text': '',
#        'user_id': 100,
#        'web_view_token': 'c14343dbd31ce4334c',
#        'has_tags': False}}],
#     'date': 1703669400,
#     'from_id': -203966578,
#     'id': 474,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 10, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 10,
#      'items': [{'id': 0, 'count': 10}],
#      'user_reaction': 0},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count': 3, 'wall_count': 0, 'mail_count': 3},
#     'text': 'Дорогие вышкинцы! \n \nСегодня мы подробно разбираем для вас «Положение о предоставлении скидок по оплате обучения студентам, обучающимся по договорам об образовании, заключаемым при приеме на обучение за счет средств физических и или юридических лиц» (https://www.hse.ru/docs/807180592.html). \n\nНадеемся, что этот пост будет полезен для вас! Не забудьте переслать его друзьям и знакомым, чтобы они тоже знали всё о скидках, на которые можно рассчитывать в нашем университете!\n\nС любовью, \nАппарат Уполномоченного❣️',
#     'views': {'count': 651}},
#    {'inner_type': 'wall_wallpost',
#     'can_delete': 1,
#     'can_pin': 1,
#     'donut': {'is_donut': False},
#     'comments': {'count': 0},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'sTAywZ9MTeBxzIPWM6UENiG1VaMN',
#     'has_translation': False,
#     'postponed_id': 470,
#     'type': 'post',
#     'carousel_offset': 0,
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1703317351,
#        'id': 457239482,
#        'owner_id': -203966578,
#        'access_key': 'b138384cbdfc750155',
#        'sizes': [{'height': 75,
#          'type': 's',
#          'width': 75,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=75x75&quality=95&sign=6f58c6c1029c091e5d12b204fb0610b6&c_uniq_tag=VWRLPi9q3Fg_t4N4pydrgDZL1nPi-k_U_z6eF1JiQ08&type=album'},
#         {'height': 130,
#          'type': 'm',
#          'width': 130,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=130x130&quality=95&sign=3ac5f30e2e1d681dd71f5d507f9946bd&c_uniq_tag=aUYUaOckrKNRA9PXAgpswIyM0O2cgNh45HFZNUGcLKo&type=album'},
#         {'height': 604,
#          'type': 'x',
#          'width': 604,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=604x604&quality=95&sign=10564256620156a445b4736bae0f8c79&c_uniq_tag=wA1jX2kU9AzFWstb93XtQ4JnRimZdAenD3OctxpWPc0&type=album'},
#         {'height': 800,
#          'type': 'y',
#          'width': 800,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=800x800&quality=95&sign=3deb0c4e85716298c50b06cffdae5d91&c_uniq_tag=aixkQzLDPDCGKfRuTYe4hrCB4mkZAOWgqadpRl4C3kQ&type=album'},
#         {'height': 130,
#          'type': 'o',
#          'width': 130,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=130x130&quality=95&sign=3ac5f30e2e1d681dd71f5d507f9946bd&c_uniq_tag=aUYUaOckrKNRA9PXAgpswIyM0O2cgNh45HFZNUGcLKo&type=album'},
#         {'height': 200,
#          'type': 'p',
#          'width': 200,
#          'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size
url': 'https://sun9-57.userapi.com/impg/FcthGf6iRtbWzPvTjzSlOc8dyJLCFA75Botyow/fHdcODbqIEo.jpg?size=510x510&quality=95&sign=3fa872031de210671e8bb8003868bfce&c_uniq_tag=5u0coOx3Jpf1VEr7TgWeQRne29ldKyFfzEU8fUlHrGs&type=album'}],
#          'text': '',
#          'user_id': 100,
#          'web_view_token': '7cfc27a0031b992a9a',
#          'has_tags': False}}],
#       'date': 1703408403,
#       'from_id': -64952366,
#       'id': 8300,
#       'owner_id': -64952366,
#       'post_source': {'platform': 'iphone', 'type': 'api'},
#       'post_type': 'post',
#       'text': "О ПОПАТКУСе\n\nАдминистрация университета инициировала поправки в главный документ, который регулирует образовательный процесс в Вышке — Положение об организации промежуточной аттестации и текущего контроля успеваемости студентов (ПОПАТКУС).\n\nСтуденческий совет предложил множество изменений в положение, например: \n\n— Допустить до пересдачи студентов, чей накоп составляет 0,1, если элемент контроля пропущен по уважительной причине. В предыдущем документе пересдача допускалась с 0,3 и выше;\n— Дать возможность покинуть элемент контроля (контрольную, экзамен и т.д.) при возникшем недомогании с правом на пересдачу;\n— Откорректировать сроки различных процессов в пользу студентов.\n\nАдминистрация согласилась лишь с небольшой частью предложений — многие принципиальные для нас пункты в итоговый документ не попали. Проект был принят Учёным советом, а внесение каких-либо дополнительных правок было представлено как невозможное. \n\nПри общении с администрацией университета мы узнали, что ключевые нововведения связаны с необходимостью привести документы Вышки в соответствие с Федеральным законом об образовании. Сейчас руководство университета готово взаимодействовать со Студсоветом для отработки кейсов, в которых новые пункты могут поставить студента в несправедливое положение. Мы уже работаем над конкретными механизмами действий, которые помогут продолжать защищать ваши права в новых обстоятельствах. Помимо этого мы продолжим переговоры о внесении каких-либо изменений.\n\nВ ближайшее время мы подробно проинформируем вас о правках в ПОПАТКУС и о том, как именно они отразятся на учебном процессе. Мы знаем, что по различным каналам уже распространяются трактовки обновленного документа. Предупреждаем: не все из них достоверны. \n\nСтуденческий совет крайне встревожен тем, каким образом и с каким содержанием был принят основной образовательный документ Вышки. Мы выражаем решительное несогласие с предлагаемыми изменениями. Диалог не может быть односторонним, а любые правки в основополагающие документы должны учитывать интересы всех сторон образовательного процесса.\n\nПродолжает бороться за права студентов,\nТвой Студсовет🧡\n\n- - - [English version] - - -\n\nAbout the RIOAS\n\nThe University administration has initiated amendments to the main document which is regulating the educational process at HSE — the Regulations for Interim and Ongoing Assessments of Students (RIOAS). \n\nThe Student Council has proposed many changes, such as: \n\n- lowering the threshold for mandatory provision of the opportunity to retake the element of control because of a valid reason from 0.3 to 0.1;\n- the opportunity to leave during the element of control (test, exam, etc.) in case of illness with the right to retake it;\n- adjusting the timing of various processes in favor of students;\nand other edits that improve the comfort and quality of the educational process.\nThe administration agreed with only a small part of our proposals — many points which were principle for us were not included in the final draft of the document. The draft was accepted by the Academic Council, and any additional edits were presented as impossible. \n\nIn communication with the university administration we found out that the key innovations are related to the need to bring the university's documents in line with the Federal Law on Education. The administration also expressed its willingness to work with the Student Council to work out cases in which the new items may put the student in an unfair position. We are already working on specific action mechanisms that will help us to continue protecting your rights in new circumstances. In addition to working out the consequences of the innovations, we will continue negotiations on trying to make changes to this document. \n\nIn the near future we will inform you in detail about the edits to RIOAS and how exactly they will affect the learning process. We know that interpretations of the updated document are already be ...
#     'can_delete': 1,
#     'can_pin': 1,
#     'donut': {'is_donut': False},
#     'comments': {'count': 0},
#     'marked_as_ads': 0,
#     'short_text_rate': 0.8,
#     'hash': 'LrAMZduJ0umX7PsgRQfxr-cJzT-A',
#     'has_translation': False,
#     'type': 'post',
#     'attachments': [],
#     'date': 1703414444,
#     'from_id': -203966578,
#     'id': 472,
#     'is_favorite': False,
#     'likes': {'can_like': 0, 'count': 22, 'user_likes': 0},
#     'reaction_set_id': 'reactions',
#     'reactions': {'count': 22, 'items': [{'id': 0, 'count': 22}]},
#     'owner_id': -203966578,
#     'post_type': 'post',
#     'reposts': {'count': 3, 'wall_count': 0, 'mail_count': 3},
#     'text': 'Уполномоченный по правам студентов и аспирантов разделяет позицию Студенческого совета НИУ ВШЭ по проекту ПОПАТКУСа.\n\nПредложенный проект редакции создает условия, ставящее студентов в уязвимое положение и существенно ограничивает объем прав обучающихся.',
#     'views': {'count': 529}}],
#   'profiles': [{'id': 100,
#     'screen_name': 'id100',
#     'first_name': 'Администрация ВКонтакте',
#     'last_name': '',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 357249335,
#     'screen_name': 'margaret_lis',
#     'first_name': 'Margaret',
#     'last_name': 'Eliseeva',
#     'can_access_closed': True,
#     'is_closed': False}],
#   'groups': [{'id': 203966578,
#     'members_count': 1421,
#     'name': 'Уполномоченный по правам студентов НИУ ВШЭ',
#     'screen_name': 'ombudsman_hse',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun6-20.userapi.com/s/v1/ig2/z62AU5hRrRQI1kzlpqzsAJtYgGhLpAB0itKNjepO2gbSCPVZZbQjFtQeYvBiIxUh0L3kccrmZAuVQdoNxeqVyBhQ.jpg?size=50x50&quality=96&crop=0,227,1819,1819&ava=1',
#     'photo_100': 'https://sun6-20.userapi.com/s/v1/ig2/P7494n-87s2HwRHVN4kotnYyHpfB88P3-Q0tjQ2M8Jc1E0NYXOB2es0vxmCm9kYIUIinOsxNB6CdjasilE8aPoxx.jpg?size=100x100&quality=96&crop=0,227,1819,1819&ava=1',
#     'photo_200': 'https://sun6-20.userapi.com/s/v1/ig2/SK8b0Ewhf9BJ-2xegajAIfSWScN5w-JHMcjdGGvi7-LEFG8qvuA9VSk1O2mkyhElbtY6kDO8ZoHeOxCEncQuaBui.jpg?size=200x200&quality=96&crop=0,227,1819,1819&ava=1'},
#    {'id': 64952366,
#     'members_count': 10946,
#     'name': 'Студенческий совет НИУ ВШЭ',
#     'screen_name': 'hsecouncil',
#     'is_closed': 0,
#     'type': 'page',
#     'photo_50': 'https://sun6-23.userapi.com/s/v1/ig2/LgJ-T2hUc4AipDZkNss-0ckMmgS4OH3VAnrO_8xQ3VpEmhh2Hsjc-GQggpSYpTrLNOKG5n_8F9XseT7DNp6Pkewt.jpg?size=50x50&quality=95&crop=1,1,639,639&ava=1',
#     'photo_100': 'https://sun6-23.userapi.com/s/v1/ig2/hGefVzqPTDWrCbazPAZ8Q2GFBxgfol3h8AyrFtjaeSOPZReUYzvxIBPSUA99EJkFbKEfcp7kOPIU5Zh-I7tykTWA.jpg?size=100x100&quality=95&crop=1,1,639,639&ava=1',
#     'photo_200': 'https://sun6-23.userapi.com/s/v1/ig2/YZR6mkqyZeiC12ju_hK0UWcIRjtqxwrAJRLdI4PIuaZ383tGNL4odsD57frmyJ7nz7wNDZZXSbqNvtB77Er9Fa5-.jpg?size=200x200&quality=95&crop=1,1,639,639&ava=1'}],
#   'reaction_sets': [{'id': 'reactions',
#     'items': [{'id': 0,
#       'title': 'Нравится',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions

#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'FF8000', 'dark': 'FFC233'},
#          'background': {'light': 'FFF2D6', 'dark': '352E23'}}},
#        'title_color': {'light': 'FF8000', 'dark': 'FFC233'}}},
#      {'id': 5,
#       'title': 'Печаль',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-5?c_uniq_tag=c61122c8c334154cb10ccf0e0687057bf1f0f40c2817198b2e1150df534c22c4',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-5-32?c_uniq_tag=a07ac888553814f1cbc8c9342b636bf30ca6d80d14e7e38170ea02dad0bfafbf',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-5-48?c_uniq_tag=31bcb230babad96120a62589c52af22811aaba54d4ed73a36cfd499d9d94102f',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-5-72?c_uniq_tag=a840d0eb581c133d97638ff5bf34f4b33f3fb8557b932cfe3516925b88e2f151',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-5-96?c_uniq_tag=8cff3bac94202cbb5bee1d598f113134e0038804a3837be750f28ff27d3ffb05',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-5-144?c_uniq_tag=8bf31a92656dd0c0d3482505bf1b6fb3d2493a3e4c93e0e62723aef81c7da052',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': '4986CC', 'dark': '71AAEB'},
#          'background': {'light': 'EDF3FA', 'dark': '27303C'}}},
#        'title_color': {'light': '4986CC', 'dark': '71AAEB'}}},
#      {'id': 4,
#       'title': '&$#%!',
#       'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-4?c_uniq_tag=063e6b2dd888bb5a9716cf6153f03bf9c0c9707713b857eed8fe1e4e09aea2b3',
#        'images': [{'url': 'https://vk.com/reaction/1-reactions-4-32?c_uniq_tag=ac5ab70367285c3fbbee7ba2adde88cbb65db2d35e05b09b4ae5593ee0bcc535',
#          'width': 32,
#          'height': 32},
#         {'url': 'https://vk.com/reaction/1-reactions-4-48?c_uniq_tag=c80e3224c299a73384c057ff065c9458dcd533d57a1458875eb98883c3a96783',
#          'width': 48,
#          'height': 48},
#         {'url': 'https://vk.com/reaction/1-reactions-4-72?c_uniq_tag=a0eddba1ec31f96adbb9afa2c6c14bec055b95f8d9f113bdf759fb5a9c9054f0',
#          'width': 72,
#          'height': 72},
#         {'url': 'https://vk.com/reaction/1-reactions-4-96?c_uniq_tag=5495709e616048fd43683ac693ebd09f3615c797af2493d0334402befded2885',
#          'width': 96,
#          'height': 96},
#         {'url': 'https://vk.com/reaction/1-reactions-4-144?c_uniq_tag=a79fce98e0d7769284290ab78936b3aa6d15a42caa50e6071bdeb5013d950251',
#          'width': 144,
#          'height': 144}],
#        'title': {'color': {'foreground': {'light': 'EF5203', 'dark': 'FA5300'},
#          'background': {'light': 'FDEBE8', 'dark': '3C2421'}}},
#        'title_color': {'light': 'EF5203', 'dark': 'FA5300'}}}]}]}}

# %%
wall_data.keys() # ключи, которые есть у объекта - только response
# Out:
# dict_keys(['response'])

# %%
wall_data['response'].keys() # что внутри объекта response?
# Out:
# dict_keys(['count', 'items', 'profiles', 'groups', 'reaction_sets'])

# %% [markdown]
# Давайте исследуем эти объекты. Как к ним обратиться? Вызвать квадратные скобки и написать их название внутри.
#
# Как когда вы хотите получить значение из словаря по названию ключа:

# %%
# Представим, что мы с вами работаем со словарем, который имеет следующую структуру:
# ключ - это номер группы; значение - это список кураторов группы.
my_dictionary = {'202': ['Жестовская', 'Атабегашвили'],
                 '203': ['Капустина',  'Кувивчак', 'Музыка'],
                '204': ['Крипайтис', 'Белоклокова']}

# Как получить список кураторов группы (значение)? Обратиться к номеру группы (ключу):
my_dictionary['203']
# Out:
# ['Капустина', 'Кувивчак', 'Музыка']

# %% [markdown]
# То же самое мы делаем когда работаем с json объектами:

# %%
wall_data['response']['count'] # 92 - это число постов на стене всего.
# даже если мы запросили всего три последних поста, мы все равно получим этот параметр
# Out:
# 92

# %%
wall_data['response']['groups'] # информация о группах, которые являются авторами постов которые мы получили
# Out:
# [{'id': 203966578,
#   'members_count': 1421,
#   'name': 'Уполномоченный по правам студентов НИУ ВШЭ',
#   'screen_name': 'ombudsman_hse',
#   'is_closed': 0,
#   'type': 'page',
#   'photo_50': 'https://sun6-20.userapi.com/s/v1/ig2/z62AU5hRrRQI1kzlpqzsAJtYgGhLpAB0itKNjepO2gbSCPVZZbQjFtQeYvBiIxUh0L3kccrmZAuVQdoNxeqVyBhQ.jpg?size=50x50&quality=96&crop=0,227,1819,1819&ava=1',
#   'photo_100': 'https://sun6-20.userapi.com/s/v1/ig2/P7494n-87s2HwRHVN4kotnYyHpfB88P3-Q0tjQ2M8Jc1E0NYXOB2es0vxmCm9kYIUIinOsxNB6CdjasilE8aPoxx.jpg?size=100x100&quality=96&crop=0,227,1819,1819&ava=1',
#   'photo_200': 'https://sun6-20.userapi.com/s/v1/ig2/SK8b0Ewhf9BJ-2xegajAIfSWScN5w-JHMcjdGGvi7-LEFG8qvuA9VSk1O2mkyhElbtY6kDO8ZoHeOxCEncQuaBui.jpg?size=200x200&quality=96&crop=0,227,1819,1819&ava=1'},
#  {'id': 64952366,
#   'members_count': 10946,
#   'name': 'Студенческий совет НИУ ВШЭ',
#   'screen_name': 'hsecouncil',
#   'is_closed': 0,
#   'type': 'page',
#   'photo_50': 'https://sun6-23.userapi.com/s/v1/ig2/LgJ-T2hUc4AipDZkNss-0ckMmgS4OH3VAnrO_8xQ3VpEmhh2Hsjc-GQggpSYpTrLNOKG5n_8F9XseT7DNp6Pkewt.jpg?size=50x50&quality=95&crop=1,1,639,639&ava=1',
#   'photo_100': 'https://sun6-23.userapi.com/s/v1/ig2/hGefVzqPTDWrCbazPAZ8Q2GFBxgfol3h8AyrFtjaeSOPZReUYzvxIBPSUA99EJkFbKEfcp7kOPIU5Zh-I7tykTWA.jpg?size=100x100&quality=95&crop=1,1,639,639&ava=1',
#   'photo_200': 'https://sun6-23.userapi.com/s/v1/ig2/YZR6mkqyZeiC12ju_hK0UWcIRjtqxwrAJRLdI4PIuaZ383tGNL4odsD57frmyJ7nz7wNDZZXSbqNvtB77Er9Fa5-.jpg?size=200x200&quality=95&crop=1,1,639,639&ava=1'}]

# %%
wall_data['response']['reaction_sets'] # объект с информацией о реакциях;
# Out:
# [{'id': 'reactions',
#   'items': [{'id': 0,
#     'title': 'Нравится',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-0?c_uniq_tag=83b2081a8e4adfc36ee536f5f1b4ad470174c89678369a4b9dc5547614a3955e',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-0-32?c_uniq_tag=464ba6bdc06e9f204a9b2c865a046355d835f601d8d82be4dc77e43a028741ff',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-0-48?c_uniq_tag=e6bee176471af6e4f7ca0f57ac099847d57b8101bf07944e47b42b097a6d8455',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-0-72?c_uniq_tag=d6f55fe94c0add8f817b447cbd804768752eb996c06ef222b39eb3fd35834780',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-0-96?c_uniq_tag=0a64c3d34d3a1368b05716ff24f94ff51b2257a2287957423ced36a00b020cb6',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-0-144?c_uniq_tag=47a911186fd9ce6d9aba1f9273e49ef70d1e0149e7470d1dae40941d81a1ece4',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'FF3347', 'dark': 'FF5C5C'},
#        'background': {'light': 'FFEDED', 'dark': '3E2526'}}},
#      'title_color': {'light': 'FF3347', 'dark': 'FF5C5C'}}},
#    {'id': 1,
#     'title': 'Смешно',
#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions

#     'asset': {'animation_url': 'https://vk.com/reaction/3-reactions-4?c_uniq_tag=063e6b2dd888bb5a9716cf6153f03bf9c0c9707713b857eed8fe1e4e09aea2b3',
#      'images': [{'url': 'https://vk.com/reaction/1-reactions-4-32?c_uniq_tag=ac5ab70367285c3fbbee7ba2adde88cbb65db2d35e05b09b4ae5593ee0bcc535',
#        'width': 32,
#        'height': 32},
#       {'url': 'https://vk.com/reaction/1-reactions-4-48?c_uniq_tag=c80e3224c299a73384c057ff065c9458dcd533d57a1458875eb98883c3a96783',
#        'width': 48,
#        'height': 48},
#       {'url': 'https://vk.com/reaction/1-reactions-4-72?c_uniq_tag=a0eddba1ec31f96adbb9afa2c6c14bec055b95f8d9f113bdf759fb5a9c9054f0',
#        'width': 72,
#        'height': 72},
#       {'url': 'https://vk.com/reaction/1-reactions-4-96?c_uniq_tag=5495709e616048fd43683ac693ebd09f3615c797af2493d0334402befded2885',
#        'width': 96,
#        'height': 96},
#       {'url': 'https://vk.com/reaction/1-reactions-4-144?c_uniq_tag=a79fce98e0d7769284290ab78936b3aa6d15a42caa50e6071bdeb5013d950251',
#        'width': 144,
#        'height': 144}],
#      'title': {'color': {'foreground': {'light': 'EF5203', 'dark': 'FA5300'},
#        'background': {'light': 'FDEBE8', 'dark': '3C2421'}}},
#      'title_color': {'light': 'EF5203', 'dark': 'FA5300'}}}]}]

# %% [markdown]
# А теперь посмотрим на самый интересный объект - `items`.
#
# Что здесь находится? Здесь находится информация о постах.

# %%
wall_data['response']['items']
# Out:
# [{'inner_type': 'wall_wallpost',
#   'can_delete': 1,
#   'can_pin': 1,
#   'donut': {'is_donut': False},
#   'is_pinned': 1,
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'btsjLvwY7QErOnCxhHaG439TyGal',
#   'has_translation': False,
#   'postponed_id': 468,
#   'type': 'post',
#   'carousel_offset': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1703315938,
#      'id': 457239480,
#      'owner_id': -203966578,
#      'access_key': '723ffb2b329aab3986',
#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=75x75&quality=95&sign=e02501c46310b8866db249785430ff3b&c_uniq_tag=73php1pSyosrCipg3ZrWMqtf3VFcIgnwTEgbm4O4Cqc&type=album'},
#       {'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#       {'height': 604,
#        'type': 'x',
#        'width': 604,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=604x604&quality=95&sign=b3681730a3954fc805d85104af5d47c8&c_uniq_tag=n2623OgYPiktK_aWyk8KWf0Yeggsb66qg1UepEOAfoo&type=album'},
#       {'height': 800,
#        'type': 'y',
#        'width': 800,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=800x800&quality=95&sign=dfa9d79dcd7434f890beb84aeac733d5&c_uniq_tag=SxfKOF0ovsW-6qQf-Mofgksg0AvSuyZu5yYXcgF_vkE&type=album'},
#       {'height': 130,
#        'type': 'o',
#        'width': 130,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#       {'height': 200,
#        'type': 'p',
#        'width': 200,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=200x200&quality=95&sign=825b9adccefd411daf03cf2283a92233&c_uniq_tag=t8FIZdvgvquHTjPrfFvJY6BSONdRd34MZ1KqIJS2ipE&type=album'},
#       {'height': 320,
#        'type': 'q',
#        'width': 320,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=320x320&quality=95&sign=0c1227d4ad034ec4760950f19d3dcbd6&c_uniq_tag=KpcQvP8TjXrGd8Yi8QSpNRZJIrvz15x5IoM-kRvzHVo&type=album'},
#       {'height': 510,
#        'type': 'r',
#        'width': 510,
#        'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=510x510&quality=95&sign=98e54dd6e41168b7ef59d7ddc685599e&c_uniq_tag=LOnI_PYcLnkXhb76yNgiR25A66UbcmMR8s33IlV0IDE&type=album'}],
#      'text': '',
#      'user_id': 100,
#      'web_view_token': 'b6ff6483b9169a5080',
#      'has_tags': False}},
#    {'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1703382039,
#      'id': 457239506,
#      'owner_id': -203966578,
#      'access_key': 'f18e77fa30aac83c58',
#      'sizes': [{'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#       {'height': 130,
#        'type': 'o',
#        'width': 130,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#       {'height': 200,
#        'type': 'p',
#        'width': 200,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=200x200&quality=96&sign=a12152da9f44c4c358efddf80fcfe368&c_uniq_tag=Hhqt22cbQ43FREJ9x1xoKLVe7Pe3IsMmYawU7H6Mt08&type=album'},
#       {'height': 320,
#        'type': 'q',
#        'width': 320,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=320x320&quality=96&sign=e5407e4a8759ea996ba72868ae554d4a&c_uniq_tag=ikJbtjUu0ElXGr3kuZ-37EkKWp0F9jCNczSEp93eHtQ&type=album'},
#       {'height': 510,
#        'type': 'r',
#        'width': 510,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=510x510&quality=96&sign=249e951d87751a327551670d623ae69f&c_uniq_tag=y_pkXPw3cyO6Bt6dXL5HSbQ-kRyXk1vKTObczujYOgk&type=album'},
#       {'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size
дела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1335 \n🔸 Лика Капустина, ФСН, глава Аппарата Уполномоченного - https://vk.com/wall-130899141_1628 \n🔹 Артем Лебедев, ВШБ, защищает права жителей «ЖК Level Амурская» - https://vk.com/wall-130896736_1207 \n🔸 Даниил Баранков, ФКН, член отдела аналитики Аппарата Уполномоченного - https://vk.com/wall-130897705_495 \n \n📌 Проголосовать за ваших кандидатов можно по ссылке: vote.studsovet.me \n \n⏰ Не откладывайте: возможность отдать голос за своих представителей закроется в понедельник, 25 декабря, 19:00. \n \nСостоящий из прекрасных правозащитников и неравнодушных студентов, \nВсегда ваш - Аппарат Уполномоченного ❤',
#   'views': {'count': 3276}},
#  {'inner_type': 'wall_wallpost',
#   'can_delete': 1,
#   'can_pin': 1,
#   'donut': {'is_donut': False},
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'vZMDq6aBzd48_3sSJxcDGaNbF6w8',
#   'has_translation': False,
#   'postponed_id': 475,
#   'type': 'post',
#   'attachments': [{'type': 'doc',
#     'doc': {'id': 670711017,
#      'owner_id': 357249335,
#      'title': 'с нг.jpg',
#      'size': 97285,
#      'ext': 'jpg',
#      'date': 1704045756,
#      'type': 4,
#      'url': 'https://vk.com/doc357249335_670711017?hash=aBfkbVjmq7swss2UFNigOV1ABlZffSPL453xbOoKKHs&dl=51ymg39v24Z8fCin8bt6weI5MBbuxRqi0q4EBEyqM9g&api=1&no_preview=1',
#      'preview': {'photo': {'sizes': [{'src': 'https://sun9-73.userapi.com/c235131/u357249335/d40/-3/m_6b6b9b99b3.jpg',
#          'width': 130,
#          'height': 100,
#          'type': 'm'},
#         {'src': 'https://sun9-75.userapi.com/c235131/u357249335/d40/-3/s_6b6b9b99b3.jpg',
#          'width': 100,
#          'height': 75,
#          'type': 's'},
#         {'src': 'https://sun9-49.userapi.com/c235131/u357249335/d40/-3/x_6b6b9b99b3.jpg',
#          'width': 604,
#          'height': 602,
#          'type': 'x'},
#         {'src': 'https://sun9-70.userapi.com/c235131/u357249335/d40/-3/o_6b6b9b99b3.jpg',
#          'width': 803,
#          'height': 800,
#          'type': 'o'}]}},
#      'is_unsafe': 0,
#      'access_key': 'yfJvyUKKXKng03l4uvRsDU8ni0D6Wp0YG7QeWEjkaZg'}}],
#   'date': 1704051000,
#   'edited': 1704128627,
#   'from_id': -203966578,
#   'id': 476,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 13, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 13, 'items': [{'id': 0, 'count': 13}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 0, 'wall_count': 0, 'mail_count': 0},
#   'text': 'Дорогие вышкинцы!\n\nНаша команда хочет поздравить вас с новым годом и пожелать, чтобы в вашей студенческой жизни было как можно меньше трудностей и неприятностей!\n\nТакже мы хотим поздравить [id215481586|Рину Егереву] и [id241798539|Николая Лобова] с победой на выборах Омбудсмена Вышки и поделиться с вами памятками, которые Коля, локальный омбудсмен ФМЭиМП, сделал для помощи вам в сдаче НОКов по цифровым компетенциям!\n\nПамятка по Цифровой грамотности — https://docs.google.com/document/d/1LsFog31DFp9AYlE34Eu1lzOhJvC_ETsP6K8QKrzKRRI/edit#heading=h.45211km3knvt\n\nПамятка по Программированию на языке Пайтон — https://docs.google.com/document/d/1rrTVAi8c_bDJbZ0XUz6JKYvTfsGxW6JHyLOmdodzIbA/edit#heading=h.45211km3knvt\n\nПамятка по Анализу данных на питоне — https://docs.google.com/document/d/1S4NnyFeTbFZczKfAh-ddvlMGoaDb37L_JbByeyUTcGY/edit#heading=h.45211km3knvt\n\nХороших вам праздников!\nВаш Аппарат Уполномоченного',
#   'views': {'count': 479}},
#  {'inner_type': 'wall_wallpost',
#   'can_delete': 1,
#   'can_pin': 1,
#   'donut': {'is_donut': False},
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 

#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=75x75&quality=95&sign=e3d709e1242ac755e1c0d9f936884943&c_uniq_tag=-1fgrXCdFprMBCnJgI4yMnU_ilfkoBnEazuj7z0TTKE&type=album'},
#       {'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=130x130&quality=95&sign=ced61ed384ec03d39d24a78f8d81e344&c_uniq_tag=S-WOurtUuvLNaxV_73q8cgGBnskE2-PwRk7tcan0vpg&type=album'},
#       {'height': 604,
#        'type': 'x',
#        'width': 604,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=604x604&quality=95&sign=a43cdaf06e1bf77478ef080fe90d237e&c_uniq_tag=1MXhd0YtLA_wDoRwN5YkKB6I3wk85bWSSXmu6wPkQzM&type=album'},
#       {'height': 800,
#        'type': 'y',
#        'width': 800,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=800x800&quality=95&sign=30ab4e426fb5b829c047f9735e008304&c_uniq_tag=Ni6p2q82V-nzoIl9mCw5gez3fp-fLw4NSW6FDwLtS_c&type=album'},
#       {'height': 130,
#        'type': 'o',
#        'width': 130,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=130x130&quality=95&sign=ced61ed384ec03d39d24a78f8d81e344&c_uniq_tag=S-WOurtUuvLNaxV_73q8cgGBnskE2-PwRk7tcan0vpg&type=album'},
#       {'height': 200,
#        'type': 'p',
#        'width': 200,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=200x200&quality=95&sign=d9cb5e7c510b0b8d263c9629d5abc038&c_uniq_tag=R1hIcenSgSPrT-TDxgVwM3AiFh21D_xYaE-ECQ960NE&type=album'},
#       {'height': 320,
#        'type': 'q',
#        'width': 320,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=320x320&quality=95&sign=aa48b8c184e218bca815930058e6265f&c_uniq_tag=1An0l3Br4z5CcZxc1ZH7Fg-a2ObSuChQJE6W4h_PAIM&type=album'},
#       {'height': 510,
#        'type': 'r',
#        'width': 510,
#        'url': 'https://sun9-33.userapi.com/impg/sDGfYiy0z9U3LhPnS7q4AlhDbiR8iozVCxv57g/_Kqeyq-HXcY.jpg?size=510x510&quality=95&sign=6af5cb3e864036ff7db9d6a659aa6013&c_uniq_tag=pcmjVWiG6pZMqJ9uNmeEBbh7q95wVVCCnIqWeQ7BddI&type=album'}],
#      'text': '',
#      'user_id': 100,
#      'web_view_token': 'c14343dbd31ce4334c',
#      'has_tags': False}}],
#   'date': 1703669400,
#   'from_id': -203966578,
#   'id': 474,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 10, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 10,
#    'items': [{'id': 0, 'count': 10}],
#    'user_reaction': 0},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 3, 'wall_count': 0, 'mail_count': 3},
#   'text': 'Дорогие вышкинцы! \n \nСегодня мы подробно разбираем для вас «Положение о предоставлении скидок по оплате обучения студентам, обучающимся по договорам об образовании, заключаемым при приеме на обучение за счет средств физических и или юридических лиц» (https://www.hse.ru/docs/807180592.html). \n\nНадеемся, что этот пост будет полезен для вас! Не забудьте переслать его друзьям и знакомым, чтобы они тоже знали всё о скидках, на которые можно рассчитывать в нашем университете!\n\nС любовью, \nАппарат Уполномоченного❣️',
#   'views': {'count': 651}},
#  {'inner_type': 'wall_wallpost',
#   'can_delete': 1,
#   'can_pin': 1,
#   'donut': {'is_donut': False},
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'sTAywZ9MTeBxzIPWM6UENiG1VaMN',
#   'has_translation': False,
#   'postponed_id': 470,
#   'type': 'post',
#   'carousel_offset': 0,
#   'attachments': [{'type': 'photo',
#     'photo': {'album_id': -7,
#      'date': 1703317351,
#      'id': 457239482,
#      'owner_id': -203966578,
#      'access_key': 'b138384cbdfc750155',
#      'sizes': [{'height': 75,
#        'type': 's',
#        'width': 75,
#        'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=75x75&quality=95&sign=6f58c6c1029c091e5d12b204fb0610b6&c_uniq_tag=VWRLPi9q3Fg_t4N4pydrgDZL1nPi-k_U_z6eF1JiQ08&type=album'},
#       {'height': 130,
#        'type': 'm',
#        'width': 130,
#        'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size=130x130&quality=95&sign=3ac5f30e2e1d681dd71f5d507f9946bd&c_uniq_tag=aUYUaOckrKNRA9PXAgpswIyM0O2cgNh45HFZNUGcLKo&type=album'},
#       {'height': 604,
#        'type': 'x',
#        'width': 604,
#        'url': 'https://sun9-9.userapi.com/impg/bC-PIfhuwNjZw4IwciXPaFOh3VyFw8MlAkUnJQ/nE9q7f5wU_8.jpg?size
type=album'}],
#        'text': '',
#        'user_id': 100,
#        'web_view_token': '7cfc27a0031b992a9a',
#        'has_tags': False}}],
#     'date': 1703408403,
#     'from_id': -64952366,
#     'id': 8300,
#     'owner_id': -64952366,
#     'post_source': {'platform': 'iphone', 'type': 'api'},
#     'post_type': 'post',
#     'text': "О ПОПАТКУСе\n\nАдминистрация университета инициировала поправки в главный документ, который регулирует образовательный процесс в Вышке — Положение об организации промежуточной аттестации и текущего контроля успеваемости студентов (ПОПАТКУС).\n\nСтуденческий совет предложил множество изменений в положение, например: \n\n— Допустить до пересдачи студентов, чей накоп составляет 0,1, если элемент контроля пропущен по уважительной причине. В предыдущем документе пересдача допускалась с 0,3 и выше;\n— Дать возможность покинуть элемент контроля (контрольную, экзамен и т.д.) при возникшем недомогании с правом на пересдачу;\n— Откорректировать сроки различных процессов в пользу студентов.\n\nАдминистрация согласилась лишь с небольшой частью предложений — многие принципиальные для нас пункты в итоговый документ не попали. Проект был принят Учёным советом, а внесение каких-либо дополнительных правок было представлено как невозможное. \n\nПри общении с администрацией университета мы узнали, что ключевые нововведения связаны с необходимостью привести документы Вышки в соответствие с Федеральным законом об образовании. Сейчас руководство университета готово взаимодействовать со Студсоветом для отработки кейсов, в которых новые пункты могут поставить студента в несправедливое положение. Мы уже работаем над конкретными механизмами действий, которые помогут продолжать защищать ваши права в новых обстоятельствах. Помимо этого мы продолжим переговоры о внесении каких-либо изменений.\n\nВ ближайшее время мы подробно проинформируем вас о правках в ПОПАТКУС и о том, как именно они отразятся на учебном процессе. Мы знаем, что по различным каналам уже распространяются трактовки обновленного документа. Предупреждаем: не все из них достоверны. \n\nСтуденческий совет крайне встревожен тем, каким образом и с каким содержанием был принят основной образовательный документ Вышки. Мы выражаем решительное несогласие с предлагаемыми изменениями. Диалог не может быть односторонним, а любые правки в основополагающие документы должны учитывать интересы всех сторон образовательного процесса.\n\nПродолжает бороться за права студентов,\nТвой Студсовет🧡\n\n- - - [English version] - - -\n\nAbout the RIOAS\n\nThe University administration has initiated amendments to the main document which is regulating the educational process at HSE — the Regulations for Interim and Ongoing Assessments of Students (RIOAS). \n\nThe Student Council has proposed many changes, such as: \n\n- lowering the threshold for mandatory provision of the opportunity to retake the element of control because of a valid reason from 0.3 to 0.1;\n- the opportunity to leave during the element of control (test, exam, etc.) in case of illness with the right to retake it;\n- adjusting the timing of various processes in favor of students;\nand other edits that improve the comfort and quality of the educational process.\nThe administration agreed with only a small part of our proposals — many points which were principle for us were not included in the final draft of the document. The draft was accepted by the Academic Council, and any additional edits were presented as impossible. \n\nIn communication with the university administration we found out that the key innovations are related to the need to bring the university's documents in line with the Federal Law on Education. The administration also expressed its willingness to work with the Student Council to work out cases in which the new items may put the student in an unfair position. We are already working on specific action mechanisms that will help us to continue protecting your rights in new circumstances. In addition to working out the consequences of the innovations, we will continue negotiations on trying to make changes to this document. \n\nIn the near future we will inform you in detail about the edits to RIOAS and how exactly they will affect the learning process. We know that interpretations of the updated document are already bein ...
#   'can_delete': 1,
#   'can_pin': 1,
#   'donut': {'is_donut': False},
#   'comments': {'count': 0},
#   'marked_as_ads': 0,
#   'short_text_rate': 0.8,
#   'hash': 'LrAMZduJ0umX7PsgRQfxr-cJzT-A',
#   'has_translation': False,
#   'type': 'post',
#   'attachments': [],
#   'date': 1703414444,
#   'from_id': -203966578,
#   'id': 472,
#   'is_favorite': False,
#   'likes': {'can_like': 0, 'count': 22, 'user_likes': 0},
#   'reaction_set_id': 'reactions',
#   'reactions': {'count': 22, 'items': [{'id': 0, 'count': 22}]},
#   'owner_id': -203966578,
#   'post_type': 'post',
#   'reposts': {'count': 3, 'wall_count': 0, 'mail_count': 3},
#   'text': 'Уполномоченный по правам студентов и аспирантов разделяет позицию Студенческого совета НИУ ВШЭ по проекту ПОПАТКУСа.\n\nПредложенный проект редакции создает условия, ставящее студентов в уязвимое положение и существенно ограничивает объем прав обучающихся.',
#   'views': {'count': 529}}]

# %% [markdown]
# **Как превратить объект json в табличные данные?**
#
# Для начала отметим, что json файлы поддерживают индексацию. Это значительно упрощает нам жизнь, потому что позволяет пользоваться как циклами, так и генераторами списков:

# %%
wall_data['response']['items'][0] # обратимся к индексу.
# Out:
# {'inner_type': 'wall_wallpost',
#  'can_delete': 1,
#  'can_pin': 1,
#  'donut': {'is_donut': False},
#  'is_pinned': 1,
#  'comments': {'count': 0},
#  'marked_as_ads': 0,
#  'short_text_rate': 0.8,
#  'hash': 'btsjLvwY7QErOnCxhHaG439TyGal',
#  'has_translation': False,
#  'postponed_id': 468,
#  'type': 'post',
#  'carousel_offset': 0,
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1703315938,
#     'id': 457239480,
#     'owner_id': -203966578,
#     'access_key': '723ffb2b329aab3986',
#     'sizes': [{'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=75x75&quality=95&sign=e02501c46310b8866db249785430ff3b&c_uniq_tag=73php1pSyosrCipg3ZrWMqtf3VFcIgnwTEgbm4O4Cqc&type=album'},
#      {'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=604x604&quality=95&sign=b3681730a3954fc805d85104af5d47c8&c_uniq_tag=n2623OgYPiktK_aWyk8KWf0Yeggsb66qg1UepEOAfoo&type=album'},
#      {'height': 800,
#       'type': 'y',
#       'width': 800,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=800x800&quality=95&sign=dfa9d79dcd7434f890beb84aeac733d5&c_uniq_tag=SxfKOF0ovsW-6qQf-Mofgksg0AvSuyZu5yYXcgF_vkE&type=album'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=200x200&quality=95&sign=825b9adccefd411daf03cf2283a92233&c_uniq_tag=t8FIZdvgvquHTjPrfFvJY6BSONdRd34MZ1KqIJS2ipE&type=album'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=320x320&quality=95&sign=0c1227d4ad034ec4760950f19d3dcbd6&c_uniq_tag=KpcQvP8TjXrGd8Yi8QSpNRZJIrvz15x5IoM-kRvzHVo&type=album'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=510x510&quality=95&sign=98e54dd6e41168b7ef59d7ddc685599e&c_uniq_tag=LOnI_PYcLnkXhb76yNgiR25A66UbcmMR8s33IlV0IDE&type=album'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'b6ff6483b9169a5080',
#     'has_tags': False}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1703382039,
#     'id': 457239506,
#     'owner_id': -203966578,
#     'access_key': 'f18e77fa30aac83c58',
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=200x200&quality=96&sign=a12152da9f44c4c358efddf80fcfe368&c_uniq_tag=Hhqt22cbQ43FREJ9x1xoKLVe7Pe3IsMmYawU7H6Mt08&type=album'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=320x320&quality=96&sign=e5407e4a8759ea996ba72868ae554d4a&c_uniq_tag=ikJbtjUu0ElXGr3kuZ-37EkKWp0F9jCNczSEp93eHtQ&type=album'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=510x510&quality=96&sign=249e951d87751a327551670d623ae69f&c_uniq_tag=y_pkXPw3cyO6Bt6dXL5HSbQ-kRyXk1vKTObczujYOgk&type=album'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=75x75&quality=96&sign=0e8c83ed977164bae43f7845b2411b0b&c_uniq_tag=yKj6aG6eHWJgkvPzeOjKci5kgyc8SkeMdYnnTpo6cKo&type=album'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=604x604&quality=96&sign=be90cd6ed2d33cbbb5f2c19b3ca6658f&c_uniq_tag=fHMcCCbxdJgEffEIRX4WQxvmHBtL9AkTi8UmQnlctlk&type=album'},
#      {'height': 800,
#       'type': 'y',
#       'width': 800,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=800x800&quality=96&sign=70cd766354ad2182f4c1cfe73092794e&c_uniq_tag=BjxV3bGgTWsBhN2PoFuLY5988O36nOMF8ZQE9TX4TmE&type=album'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'aa66bab758db82f35f',
#     'has_tags': False}}],
#  'date': 1703315788,
#  'edited': 1703382039,
#  'from_id': -203966578,
#  'id': 469,
#  'is_favorite': False,
#  'likes': {'can_like': 0, 'count': 38, 'user_likes': 0},
#  'reaction_set_id': 'reactions',
#  'reactions': {'count': 38,
#   'items': [{'id': 0, 'count': 38}],
#   'user_reaction': 0},
#  'owner_id': -203966578,
#  'post_type': 'post',
#  'reposts': {'count': 2, 'wall_count': 1, 'mail_count': 1},
#  'text': 'Выборы-выборы-выборы! 🗳 \n \nГолосование заканчивается уже 25 декабря, а вы еще не проголосовали? Самое время это сделать! При этом обратите внимание на тех, кто уже принимал участие в развитии студенческого самоуправления и получил большой опыт в работе локальным омбудсменом или членом Аппарата Уполномоченного🙋 \n \nУзнайте, кто защищает Ваши права и голосуйте на выборах в студенческое самоуправление за них: \n \n🔹 Арсен Алексанян, ФКИ, защищает права студентов ОП «Реклама и связи с общественностью» - https://vk.com/wall-130898791_1181 \n🔸 Терентий Ващекин, ФП, локальный омбудсмен ОП «Право» - https://vk.com/wall-130899003_1382 \n🔹 Аня Старовойтова, ФГН, защищает права студентов ОП «Философия» - https://vk.com/wall-130897171_962 \n🔸 Данила Сергеев, ФГН, защищает права 1-2 курса ОП «Философия» и «Широкого бакалавриата» - https://vk.com/wall-130897171_961 \n🔹 Максим Осипенко, ФГРР, локальный омбудсмен ОП «Городское планирование» - https://vk.com/wall-130930090_306 (а еще ЖК Level Амурская - https://vk.com/wall-209113730_151) \n🔸 Анастасия Куршева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1361 \n🔹 Дмитрий Щагин, ФКН, локальный омбудсмен Факультета компьютерных наук - https://vk.com/wall-130897705_460 \n🔸 Аня Молчанова, ФЭН, секретарь Аппарата Уполномоченного - https://vk.com/wall-130899601_798 \n🔹 Екатерина Егерева, ФКИ, защищает права студентов ОП «Журналистика» и «Медиакоммуникации» - https://vk.com/wall-130898791_1199 \n🔸 Екатерина Иванова, ФСН, локальная омбудсвумен ОП «Государственное и муниципальное управление» - https://vk.com/wall-130899141_1528 \n🔹 Артем Терехов, МИЭМ, локальный омбудсмен «Прикладной математики» и «Компьютерной безопасности» - https://vk.com/wall-130896227_849 \n🔸 Мария Мишхожева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1363 \n🔹 Вася Вольских, Общежитие 2, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130907078_95 \n🔸 Данила Морозов, ФП, Уполномоченный по правам студентов ВШЭ - https://vk.com/wall-130899003_1372 \n🔹 Арсений Самусенко, ФП, глава отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1335 \n🔸 Лика Капустина, ФСН, глава Аппарата Уполномоченного - https://vk.com/wall-130899141_1628 \n🔹 Артем Лебедев, ВШБ, защищает права жителей «ЖК Level Амурская» - https://vk.com/wall-130896736_1207 \n🔸 Даниил Баранков, ФКН, член отдела аналитики Аппарата Уполномоченного - https://vk.com/wall-130897705_495 \n \n📌 Проголосовать за ваших кандидатов можно по ссылке: vote.studsovet.me \n \n⏰ Не откладывайте: возможность отдать голос за своих представителей закроется в понедельник, 25 декабря, 19:00. \n \nСостоящий из прекрасных правозащитников и неравнодушных студентов, \nВсегда ваш - Аппарат Уполномоченного ❤',
#  'views': {'count': 3276}}

# %% [markdown]
# **Как получить конкретные значения для первого поста?**
#
# Чтобы понять какие вообще параметры у нас относятся к конкретному посту, давайте посмотрим на ключи этого json:

# %%
wall_data['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'can_delete': 1,
#  'can_pin': 1,
#  'donut': {'is_donut': False},
#  'is_pinned': 1,
#  'comments': {'count': 0},
#  'marked_as_ads': 0,
#  'short_text_rate': 0.8,
#  'hash': 'btsjLvwY7QErOnCxhHaG439TyGal',
#  'has_translation': False,
#  'postponed_id': 468,
#  'type': 'post',
#  'carousel_offset': 0,
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1703315938,
#     'id': 457239480,
#     'owner_id': -203966578,
#     'access_key': '723ffb2b329aab3986',
#     'sizes': [{'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=75x75&quality=95&sign=e02501c46310b8866db249785430ff3b&c_uniq_tag=73php1pSyosrCipg3ZrWMqtf3VFcIgnwTEgbm4O4Cqc&type=album'},
#      {'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=604x604&quality=95&sign=b3681730a3954fc805d85104af5d47c8&c_uniq_tag=n2623OgYPiktK_aWyk8KWf0Yeggsb66qg1UepEOAfoo&type=album'},
#      {'height': 800,
#       'type': 'y',
#       'width': 800,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=800x800&quality=95&sign=dfa9d79dcd7434f890beb84aeac733d5&c_uniq_tag=SxfKOF0ovsW-6qQf-Mofgksg0AvSuyZu5yYXcgF_vkE&type=album'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=130x130&quality=95&sign=7e5e32786874551cf43212cac16998da&c_uniq_tag=9Ux-wNgKtUZjC7mkIdZAZKclAX0UQ1GkraJJBoj8Zhc&type=album'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=200x200&quality=95&sign=825b9adccefd411daf03cf2283a92233&c_uniq_tag=t8FIZdvgvquHTjPrfFvJY6BSONdRd34MZ1KqIJS2ipE&type=album'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=320x320&quality=95&sign=0c1227d4ad034ec4760950f19d3dcbd6&c_uniq_tag=KpcQvP8TjXrGd8Yi8QSpNRZJIrvz15x5IoM-kRvzHVo&type=album'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-27.userapi.com/impg/PEwP6Hikm8w0hpDToWS8mvvBoiQX3cTnpjK3tQ/FfKEepH9gRA.jpg?size=510x510&quality=95&sign=98e54dd6e41168b7ef59d7ddc685599e&c_uniq_tag=LOnI_PYcLnkXhb76yNgiR25A66UbcmMR8s33IlV0IDE&type=album'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'b6ff6483b9169a5080',
#     'has_tags': False}},
#   {'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1703382039,
#     'id': 457239506,
#     'owner_id': -203966578,
#     'access_key': 'f18e77fa30aac83c58',
#     'sizes': [{'height': 130,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#      {'height': 130,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=130x130&quality=96&sign=c806b091a6167ec600c2f3b07ea65dcf&c_uniq_tag=KK7fVcwdpXDglIJYVIRTztNfcFTjWK9_H046nkZnBKM&type=album'},
#      {'height': 200,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=200x200&quality=96&sign=a12152da9f44c4c358efddf80fcfe368&c_uniq_tag=Hhqt22cbQ43FREJ9x1xoKLVe7Pe3IsMmYawU7H6Mt08&type=album'},
#      {'height': 320,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=320x320&quality=96&sign=e5407e4a8759ea996ba72868ae554d4a&c_uniq_tag=ikJbtjUu0ElXGr3kuZ-37EkKWp0F9jCNczSEp93eHtQ&type=album'},
#      {'height': 510,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=510x510&quality=96&sign=249e951d87751a327551670d623ae69f&c_uniq_tag=y_pkXPw3cyO6Bt6dXL5HSbQ-kRyXk1vKTObczujYOgk&type=album'},
#      {'height': 75,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=75x75&quality=96&sign=0e8c83ed977164bae43f7845b2411b0b&c_uniq_tag=yKj6aG6eHWJgkvPzeOjKci5kgyc8SkeMdYnnTpo6cKo&type=album'},
#      {'height': 604,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=604x604&quality=96&sign=be90cd6ed2d33cbbb5f2c19b3ca6658f&c_uniq_tag=fHMcCCbxdJgEffEIRX4WQxvmHBtL9AkTi8UmQnlctlk&type=album'},
#      {'height': 800,
#       'type': 'y',
#       'width': 800,
#       'url': 'https://sun9-79.userapi.com/impg/J8NrQo1L4pJOPqGxY_WWqIBALsUE36Rhml_zog/OclCI3iut4w.jpg?size=800x800&quality=96&sign=70cd766354ad2182f4c1cfe73092794e&c_uniq_tag=BjxV3bGgTWsBhN2PoFuLY5988O36nOMF8ZQE9TX4TmE&type=album'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'aa66bab758db82f35f',
#     'has_tags': False}}],
#  'date': 1703315788,
#  'edited': 1703382039,
#  'from_id': -203966578,
#  'id': 469,
#  'is_favorite': False,
#  'likes': {'can_like': 0, 'count': 38, 'user_likes': 0},
#  'reaction_set_id': 'reactions',
#  'reactions': {'count': 38,
#   'items': [{'id': 0, 'count': 38}],
#   'user_reaction': 0},
#  'owner_id': -203966578,
#  'post_type': 'post',
#  'reposts': {'count': 2, 'wall_count': 1, 'mail_count': 1},
#  'text': 'Выборы-выборы-выборы! 🗳 \n \nГолосование заканчивается уже 25 декабря, а вы еще не проголосовали? Самое время это сделать! При этом обратите внимание на тех, кто уже принимал участие в развитии студенческого самоуправления и получил большой опыт в работе локальным омбудсменом или членом Аппарата Уполномоченного🙋 \n \nУзнайте, кто защищает Ваши права и голосуйте на выборах в студенческое самоуправление за них: \n \n🔹 Арсен Алексанян, ФКИ, защищает права студентов ОП «Реклама и связи с общественностью» - https://vk.com/wall-130898791_1181 \n🔸 Терентий Ващекин, ФП, локальный омбудсмен ОП «Право» - https://vk.com/wall-130899003_1382 \n🔹 Аня Старовойтова, ФГН, защищает права студентов ОП «Философия» - https://vk.com/wall-130897171_962 \n🔸 Данила Сергеев, ФГН, защищает права 1-2 курса ОП «Философия» и «Широкого бакалавриата» - https://vk.com/wall-130897171_961 \n🔹 Максим Осипенко, ФГРР, локальный омбудсмен ОП «Городское планирование» - https://vk.com/wall-130930090_306 (а еще ЖК Level Амурская - https://vk.com/wall-209113730_151) \n🔸 Анастасия Куршева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1361 \n🔹 Дмитрий Щагин, ФКН, локальный омбудсмен Факультета компьютерных наук - https://vk.com/wall-130897705_460 \n🔸 Аня Молчанова, ФЭН, секретарь Аппарата Уполномоченного - https://vk.com/wall-130899601_798 \n🔹 Екатерина Егерева, ФКИ, защищает права студентов ОП «Журналистика» и «Медиакоммуникации» - https://vk.com/wall-130898791_1199 \n🔸 Екатерина Иванова, ФСН, локальная омбудсвумен ОП «Государственное и муниципальное управление» - https://vk.com/wall-130899141_1528 \n🔹 Артем Терехов, МИЭМ, локальный омбудсмен «Прикладной математики» и «Компьютерной безопасности» - https://vk.com/wall-130896227_849 \n🔸 Мария Мишхожева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1363 \n🔹 Вася Вольских, Общежитие 2, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130907078_95 \n🔸 Данила Морозов, ФП, Уполномоченный по правам студентов ВШЭ - https://vk.com/wall-130899003_1372 \n🔹 Арсений Самусенко, ФП, глава отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1335 \n🔸 Лика Капустина, ФСН, глава Аппарата Уполномоченного - https://vk.com/wall-130899141_1628 \n🔹 Артем Лебедев, ВШБ, защищает права жителей «ЖК Level Амурская» - https://vk.com/wall-130896736_1207 \n🔸 Даниил Баранков, ФКН, член отдела аналитики Аппарата Уполномоченного - https://vk.com/wall-130897705_495 \n \n📌 Проголосовать за ваших кандидатов можно по ссылке: vote.studsovet.me \n \n⏰ Не откладывайте: возможность отдать голос за своих представителей закроется в понедельник, 25 декабря, 19:00. \n \nСостоящий из прекрасных правозащитников и неравнодушных студентов, \nВсегда ваш - Аппарат Уполномоченного ❤',
#  'views': {'count': 3276}}

# %%
wall_data['response']['items'][0].keys() # все параметры одного поста
# Out:
# dict_keys(['inner_type', 'can_delete', 'can_pin', 'donut', 'is_pinned', 'comments', 'marked_as_ads', 'short_text_rate', 'hash', 'has_translation', 'postponed_id', 'type', 'carousel_offset', 'attachments', 'date', 'edited', 'from_id', 'id', 'is_favorite', 'likes', 'reaction_set_id', 'reactions', 'owner_id', 'post_type', 'reposts', 'text', 'views'])

# %%
wall_data['response']['items'][0]['views']['count']
# Out:
# 3276

# %% [markdown]
# Чтобы получить текст поста, нужно обратиться к первому элементу из `items` в нашем json: ```wall_data['response']['items'][0]```, а далее вызвать нужный атрибут: `['text']` (где `[0]` это индекс первого поста):

# %%
wall_data['response']['items'][0]['text'] # получим текст первого поста
# Out:
# 'Выборы-выборы-выборы! 🗳 \n \nГолосование заканчивается уже 25 декабря, а вы еще не проголосовали? Самое время это сделать! При этом обратите внимание на тех, кто уже принимал участие в развитии студенческого самоуправления и получил большой опыт в работе локальным омбудсменом или членом Аппарата Уполномоченного🙋 \n \nУзнайте, кто защищает Ваши права и голосуйте на выборах в студенческое самоуправление за них: \n \n🔹 Арсен Алексанян, ФКИ, защищает права студентов ОП «Реклама и связи с общественностью» - https://vk.com/wall-130898791_1181 \n🔸 Терентий Ващекин, ФП, локальный омбудсмен ОП «Право» - https://vk.com/wall-130899003_1382 \n🔹 Аня Старовойтова, ФГН, защищает права студентов ОП «Философия» - https://vk.com/wall-130897171_962 \n🔸 Данила Сергеев, ФГН, защищает права 1-2 курса ОП «Философия» и «Широкого бакалавриата» - https://vk.com/wall-130897171_961 \n🔹 Максим Осипенко, ФГРР, локальный омбудсмен ОП «Городское планирование» - https://vk.com/wall-130930090_306 (а еще ЖК Level Амурская - https://vk.com/wall-209113730_151) \n🔸 Анастасия Куршева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1361 \n🔹 Дмитрий Щагин, ФКН, локальный омбудсмен Факультета компьютерных наук - https://vk.com/wall-130897705_460 \n🔸 Аня Молчанова, ФЭН, секретарь Аппарата Уполномоченного - https://vk.com/wall-130899601_798 \n🔹 Екатерина Егерева, ФКИ, защищает права студентов ОП «Журналистика» и «Медиакоммуникации» - https://vk.com/wall-130898791_1199 \n🔸 Екатерина Иванова, ФСН, локальная омбудсвумен ОП «Государственное и муниципальное управление» - https://vk.com/wall-130899141_1528 \n🔹 Артем Терехов, МИЭМ, локальный омбудсмен «Прикладной математики» и «Компьютерной безопасности» - https://vk.com/wall-130896227_849 \n🔸 Мария Мишхожева, ФП, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1363 \n🔹 Вася Вольских, Общежитие 2, член Отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130907078_95 \n🔸 Данила Морозов, ФП, Уполномоченный по правам студентов ВШЭ - https://vk.com/wall-130899003_1372 \n🔹 Арсений Самусенко, ФП, глава отдела правового сопровождения Аппарата Уполномоченного - https://vk.com/wall-130899003_1335 \n🔸 Лика Капустина, ФСН, глава Аппарата Уполномоченного - https://vk.com/wall-130899141_1628 \n🔹 Артем Лебедев, ВШБ, защищает права жителей «ЖК Level Амурская» - https://vk.com/wall-130896736_1207 \n🔸 Даниил Баранков, ФКН, член отдела аналитики Аппарата Уполномоченного - https://vk.com/wall-130897705_495 \n \n📌 Проголосовать за ваших кандидатов можно по ссылке: vote.studsovet.me \n \n⏰ Не откладывайте: возможность отдать голос за своих представителей закроется в понедельник, 25 декабря, 19:00. \n \nСостоящий из прекрасных правозащитников и неравнодушных студентов, \nВсегда ваш - Аппарат Уполномоченного ❤'

# %% [markdown]
# И так далее:

# %%
wall_data['response']['items'][0]['views'] # число просмотров
# Out:
# {'count': 3276}

# %%
wall_data['response']['items'][0]['views']['count'] # чтобы получить конкретную цифру, нужно обратиться к параметру count
# Out:
# 3276

# %%
wall_data['response']['items'][0]['likes']
# Out:
# {'can_like': 0, 'count': 38, 'user_likes': 0}

# %%
wall_data['response']['items'][0]['likes'] # число лайков
# Out:
# {'can_like': 0, 'count': 38, 'user_likes': 0}

# %%
wall_data['response']['items'][0]['likes']['count'] # число лайков от пользователей
# Out:
# 38

# %% [markdown]
# А как собрать все эти данные вместе? Хорошо, что у нас с вами есть генераторы списков (если вы забыли как они работают, посмотрите [заполненный ноутбук к семинарам 5-6](https://github.com/lika1kapustina/hse_polit_web-scraping/blob/main/web-scraping_seminar5-6-with_answers.ipynb)). Наши с вами `item` в `items` индексируются, что значит, что мы можем обратиться к конкретному параметру, просто поменяв индекс в квадратных скобках:

# %%
# Здесь и далее мы используем вот этот кусочек. Что он значит?
# Это число элементов, которое лежит у нас в items - оно совпадает с запросом, который мы делали (5 постов)
len(wall_data['response']['items'])
# Out:
# 5

# %%
# использование функции range() создать последовательность от 0 до 4 включительно:
range(len(wall_data['response']['items']))
# Out:
# range(0, 5)

# %%
# наглядное подтверждение:
for i in range(len(wall_data['response']['items'])):
    print(i) # эти индексы мы и будем в дальнейшем использовать чтобы разобраться с
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Итак, соберем в один список просмотры на постах:

# %%
# Вариант один - просто с помощью цикла:

for i in range(len(wall_data['response']['items'])): # проходимся по индекс (от 0 до 4 включительно)
    print(wall_data['response']['items'][i]['views']) # печатаем то что содержится под ключом 'views'
# Out:
# {'count': 3273}
# {'count': 473}
# {'count': 646}
# {'count': 985}
# {'count': 528}

# %%
# чтобы получить точное число просмотров, обращаемся к ключу 'count'
for i in range(len(wall_data['response']['items'])):
    print(wall_data['response']['items'][i]['views']['count'])
# Out:
# 3273
# 473
# 646
# 985
# 528

# %% [markdown]
# Другой вариант - используя генераторы списков.
#
# **Расшифруем запись ниже:**
#
# * Смотрим с конца: ```for i in range(len(wall_data['response']['items']))```:
#
#     * Кусочек ```len(wall_data['response']['items']``` возвращает число объектов `items` – то есть, сколько постов (в данном примере) у нас есть – а это целое число **5**;
#     * Кусочек ```range(len(wall_data['response']['items']))``` возвращает `range(0, 5)` - то есть, последовательность от 0 включительно до 5 невключительно - `[0, 1, 2, 3, 4]`;
#     * Когда мы используем цикл и проходимся по последовательности `range(0, 5)`, это позволяет нам в дальнейшем вызывать конкретные элементы (смотрим дальше).
#
#
#
# * А теперь на кусочек ```wall_data['response']['items'][i]['views']['count']```:
#     * Что такое `wall_data`? Это наш объект json, куда мы сохранили наш объект;
#     * Что лежит в `wall_data['response']`? Ответ API с разными ключами: если вы запустите строчку кода ```wall_data['response'].keys()```, то увидите, что там есть такие ключи – ```['count', 'items', 'profiles', 'groups', 'reaction_sets']```;
#     * Чтобы получить именно `items` - то есть некоторые объекты - мы обращаемся к соответствующему ключу. Получается `wall_data['response']['items']` – и этот код возвращает нам словарь с элементами (то есть, с постами);
#     * **Чтобы получить конкретный пост**, мы используем запись ```wall_data['response']['items'][i]['views']``` где `i` - это конкретный индекс элемента в `items`.
#         * Чтобы понять, сколько всего элементов у вас в `items`, воспользуйтесь кодом ```len(wall_data['response']['items']```.
#     * **Чтобы получить конкретный атрибут конкретного поста**, используйте запись вида ```[wall_data['response']['items'][i]['views']``` где `['views']` это один конкретный атрибут.
#         * Чтобы понять, какие атрибуты вы можете получить из вашего элемента, обратитесь к документации или используйте запись ```wall_data['response']['items'][i].keys()``` где `i` - индекс конкретного элемента;
#         * Лучше ориентироваться на документацию и быть готовым к тому, что не во всех элементах будет та информация которую вы хотите получить (например, если вы собираете 1000 последних постов по поисковому запросу в разделе "новости" (метод `newsfeed.search`), вам могут попасться посты сообществ у которых включено отображение просмотров и не включено. Вызов `['views']['count']` может вызвать ошибку. В таких ситуациях надо вспомнить про конструкцию `try-except`.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
wall_data['response']['items'][0].keys()
# Out:
# dict_keys(['inner_type', 'can_delete', 'can_pin', 'donut', 'is_pinned', 'comments', 'marked_as_ads', 'short_text_rate', 'hash', 'has_translation', 'postponed_id', 'type', 'carousel_offset', 'attachments', 'date', 'edited', 'from_id', 'id', 'is_favorite', 'likes', 'reaction_set_id', 'reactions', 'owner_id', 'post_type', 'reposts', 'text', 'views'])

# %%
[wall_data['response']['items'][i]['views']['count'] for i in range(len(wall_data['response']['items']))] # просмотры
# Out:
# [3276, 479, 651, 988, 529]

# %% [markdown]
# <p></p>
# <center><b><font size=4>Задача №2</font></b></center>
#
#
# Давайте соберем `pandas.DataFrame` с информацией о тех пяти постах, которые есть у нас в `wall_data`. Используя генераторы списков или циклы, сделайте следующее:
#
# 1. **Создайте следующие списки:**
#     * `owner_ids` - список со значениями атрибута `owner_id` (кто запостил запись);
#     * `dates` - список с датами публикаций каждого поста (*внутри будут странные целые числа, пока не обращайте внимание*);
#     * `texts` - список с текстом каждого поста;
#     * `likes` - список с числом лайков на каждом посте (целые числа);
#     * `reposts` - список с числом репостов каждого поста.

# %%
# YOUR CODE HERE

owner_ids = [wall_data['response']['items'][i]['owner_id'] for i in range(len(wall_data['response']['items']))]
dates = [wall_data['response']['items'][i]['date'] for i in range(len(wall_data['response']['items']))]
texts = [wall_data['response']['items'][i]['text'] for i in range(len(wall_data['response']['items']))]
likes = [wall_data['response']['items'][i]['likes']['count'] for i in range(len(wall_data['response']['items']))]
reposts = [wall_data['response']['items'][i]['reposts']['count'] for i in range(len(wall_data['response']['items']))]

# %% [markdown]
# 2. **После того как списки созданы, создайте `posts` - `pandas.DataFrame` с информацией об этих постах:**
#
# Как создаются датафреймы в `pandas` можно посмотреть в [официальной документации](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html). Вы также можете запустить ячейку с кодом ```help(pd.DataFrame)``` или познакомиться с примером ниже:

# %%
# синтаксис внутри мягких скобок: {'название колонки': значения, которые там будут}

small_df = pd.DataFrame({'name_of_first_column': [1, 2, 3, 4],
                        'name_of_second_column': ['value', 'value', 'value', 'value']})
small_df # пример
# Out:
#    name_of_first_column name_of_second_column
# 0                     1                 value
# 1                     2                 value
# 2                     3                 value
# 3                     4                 value

# %% [markdown]
#  Данные должны выглядеть вот так :)

# %%
posts_new = pd.DataFrame({'owner_id': owner_ids,
                         'date': dates,
                         'text': texts,
                         'likes': likes,
                         'reposts': reposts})
posts_new
# Out:
#     owner_id        date                                               text
# 0 -203966578  1703315788  Выборы-выборы-выборы! 🗳 \n \nГолосование закан...  \
# 1 -203966578  1704051000  Дорогие вышкинцы!\n\nНаша команда хочет поздра...
# 2 -203966578  1703669400  Дорогие вышкинцы! \n \nСегодня мы подробно раз...
# 3 -203966578  1703496600  Дорогие вышкинцы!\n \nСегодня мы, совестно с П...
# 4 -203966578  1703414444  Уполномоченный по правам студентов и аспиранто...
#
#    likes  reposts
# 0     38        2
# 1     13        0
# 2     10        3
# 3     25        7
# 4     22        3

# %%
# YOUR CODE HERE
posts
# Out:
#     owner_id        date                                               text
# 0 -203966578  1703315788  Выборы-выборы-выборы! 🗳 \n \nГолосование закан...  \
# 1 -203966578  1704051000  Дорогие вышкинцы!\n\nНаша команда хочет поздра...
# 2 -203966578  1703669400  Дорогие вышкинцы! \n \nСегодня мы подробно раз...
# 3 -203966578  1703496600  Дорогие вышкинцы!\n \nСегодня мы, совестно с П...
# 4 -203966578  1703414444  Уполномоченный по правам студентов и аспиранто...
#
#    likes  reposts
# 0     38        2
# 1     13        0
# 2     10        3
# 3     25        7
# 4     22        3

# %% [markdown]
# 3. **Теперь, когда мы написали код, который обрабатывает полученный json в датафрейм с информацией о постах, давайте с вами напишем функцию `get_last_posts()`:**
#
# **Алгоритм решения задачи:**
# 1. Создайте функцию `get_last_posts()`. Пропишите в скобках, какие параметры она будет принимать:
#     * `group_id` - id сообщества, посты которого мы хотим собрать;
#     * `q` - целое число, столько последних постов, сколько мы хотели бы получить (до `100`).
#     * `offset=0` – параметр, по умолчанию равный `0` (сдвиг);
#     * `method='wall.get'` - параметр, по умолчанию равный `'wall.get'` – название метода, который мы используем.
# 2. Оставьте внутри тела функции три комментария и по пустой строке после них:
#     * `# 1. Отправка запроса`;
#     * `# 2. Обработка данных`;
#     * `# 3. Создание датафрейма`.
# 3. Перенесите код выше:
#     * Сперва перенесите код в раздел `# 1. Отправка запроса` – тот код, который отвечал за генерацию ссылки: начинался с создания строки `parameters` и заканчивался созданием объекта `wall_data`;
#         * При создании строки `parameters` замените значение `5` на переменную, которая содержит в себе число запрашиваемых постов (см. пункт 1) (вспомните синтаксис f-строк);
#     * Далее перенесите код в раздел `# 2. Обработка данных` – тот код, который помогал вам сгенерировать вам списки `dates`, `likes`, `reposts`, и прочее.
#     * Далее в раздел `# 3. Создание датафрейма` перенесите код, с помощью которого вы генерировали `pandas.DataFrame`;
#     * Верните получившийся `pandas.DataFrame` с помощью ключевого слова `return`.

# %%
# YOUR CODE HERE
def get_last_posts(group_id, q, offset=0, method='wall.get'):
    # 1. Отправка запроса
    # Создаем строку с параметрами;
    parameters=f'owner_id=-{group_id}&count={q}&filter=owner&extended=1&offset={offset}&fields=name,screen_name,members_count'

    # Генерируем ссылку 
    url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token

    # Отправляем запрос:
    response = requests.get(url) # привет, requests
    wall_data = response.json() # превращаем ответ в объект json, сохраняем в переменную wall_data
    
    # 2. Обрабокта данных
    owner_ids = [wall_data['response']['items'][i]['owner_id'] for i in range(len(wall_data['response']['items']))]
    dates = [wall_data['response']['items'][i]['date'] for i in range(len(wall_data['response']['items']))]
    texts = [wall_data['response']['items'][i]['text'] for i in range(len(wall_data['response']['items']))]
    likes = [wall_data['response']['items'][i]['likes']['count'] for i in range(len(wall_data['response']['items']))]
    reposts = [wall_data['response']['items'][i]['reposts']['count'] for i in range(len(wall_data['response']['items']))]

    # 3. Создание датафрейма
    posts_new = pd.DataFrame({'owner_id': owner_ids,
                         'date': dates,
                         'text': texts,
                         'likes': likes,
                         'reposts': reposts})
    return posts_new

# %%
get_last_posts(group_id=203966578, q=100, offset=0, method='wall.get')
# Out:
#      owner_id        date                                               text
# 0  -203966578  1696258802  Дорогие студенты! \n\n21ого сентября Уполномоч...  \
# 1  -203966578  1696255146  Дорогие вышкинцы! \n\nСегодня мы хотим поделит...
# 2  -203966578  1696086001  Дорогие студенты и студентки! \n \nМы завершае...
# 3  -203966578  1695481201  Дорогие студенты и студентки! \n \nМы продолжа...
# 4  -203966578  1694879955  Дорогие студенты и студентки! \n \nМы продолжа...
# ..        ...         ...                                                ...
# 72 -203966578  1645376401  Друзья, всем привет! 💙 #итогинедели\n\nРассказ...
# 73 -203966578  1645117201  Привет! Новости из Питера 💙\n\nНа этой неделе ...
# 74 -203966578  1644944401  Pov: готовишь студента к Дисциплинарной комисс...
# 75 -203966578  1644843602  Друзья, всем привет! 💓\n\nПоздравляем вас с Дн...
# 76 -203966578  1644778801  Друзья, всем привет! 💙 #итогинедели\n\nКаждое ...
#
#     likes  reposts
# 0       9        0
# 1      23        0
# 2      12        8
# 3      11        4
# 4      14        7
# ..    ...      ...
# 72     49        6
# 73     42        8
# 74     49        5
# 75     66       15
# 76     55        6
#
# [77 rows x 5 columns]

# %%
# Запустите эту ячейку. У вас должна получиться вот такая таблица:
get_last_posts(group_id=203966578, q=100, offset=0, method='wall.get')
# Out:
#      owner_id        date                                               text
# 0  -203966578  1703315788  Выборы-выборы-выборы! 🗳 \n \nГолосование закан...  \
# 1  -203966578  1704051000  Дорогие вышкинцы!\n\nНаша команда хочет поздра...
# 2  -203966578  1703669400  Дорогие вышкинцы! \n \nСегодня мы подробно раз...
# 3  -203966578  1703496600  Дорогие вышкинцы!\n \nСегодня мы, совестно с П...
# 4  -203966578  1703414444  Уполномоченный по правам студентов и аспиранто...
# ..        ...         ...                                                ...
# 87 -203966578  1645376401  Друзья, всем привет! 💙 #итогинедели\n\nРассказ...
# 88 -203966578  1645117201  Привет! Новости из Питера 💙\n\nНа этой неделе ...
# 89 -203966578  1644944401  Pov: готовишь студента к Дисциплинарной комисс...
# 90 -203966578  1644843602  Друзья, всем привет! 💓\n\nПоздравляем вас с Дн...
# 91 -203966578  1644778801  Друзья, всем привет! 💙 #итогинедели\n\nКаждое ...
#
#     likes  reposts
# 0      38        2
# 1      13        0
# 2      10        3
# 3      25        7
# 4      22        3
# ..    ...      ...
# 87     49        6
# 88     42        8
# 89     49        5
# 90     66       15
# 91     55        6
#
# [92 rows x 5 columns]

# %% [markdown]
# <b><font color='green'>Поздравляю! У нас с вами получилось написать функцию, которая получает `n` последних постов со стены сообщества.</font></b>. В теории, ничто не мешает вам в дальнейшем усложнить эту функцию, добавить дополнительные переменные, которые вы будете собирать, "углубить" поиск (используя параметр `offset` начинать собирать больше чем 100 последних постов) и так далее. Но этот пример был нужен чтобы показать вам общую линию работы с API ВКонтакте: **как генерируется запрос**, **как понять какие данные вы можете получить**, **как их обработать** и **как собрать нормальную функцию из отдельных кусочков кода**.

# %% [markdown]
# 4. <font color='blue'>EXTRA – если вы справились раньше остальных</font><b>. Исследуйте документацию API ВК по типу объектов [запись на стене](https://dev.vk.com/ru/reference/objects/post) и выясните, почему в колонке `date` так странно отражается дата публикации поста. </b>
#
#     <b>Осуществите поиск в интернете и выясните, как с помощью модуля <code>datetime</code> можно осуществить преобразование этого целого числа в адекватную дату. Примените этот код к столбцу `date`.</b>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Методы `friends` и немного о docstrings<a name="par4"></a>
#
# В этой части мы с вами соберем данные по вашим друзьям и поговорим о такой вещи, как **docstrings**.
#
# **Что такое docstrings? Это документация к модулю, функции, классу или методу**. Её главное назначение – давать пользователю понять, что же в этом коде происходит, какие у функции есть аргументы, как выглядит пример её использования.
#
# **Зачем и когда нужно использовать docstring?**
# * **Когда вы пишите большие функции, которые возвращают сложные объекты:**
#     * Если вы пишите функцию в пять строчек, которая адекватно называется, пользуется базовыми арифметическими функциями, и возвращает целое число – вам может не понадобиться документация;
#     * Если вы пишите функцию в 40 строк кода, которая делает запрос к API, обрабатывает данные, возвращает `pandas.DataFrame` с 15 колонками – вам нужна документация к функции (docstring);
# * **Когда вы работаете в команде, собираетесь использовать код больше одного раза и показывать код другим людям**. Банально есть риск, что если вы вернетесь к вашим функциям спустя месяц, вы можете не вспомнить, откуда берутся те или иные значения в возвращаемом результате.
# * **Когда вам важно поддерживать порядок в вашем коде.**
#
# В разделе [PEP 257](https://peps.python.org/pep-0257/) описаны некоторые конвенции разработчиков относительно docstrings. Перевод на русский доступен на [Хабре по ссылке](https://habr.com/ru/articles/499358/).
#
# Как создать docstring? Проиллюстрирую на примере:

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
# создаем функцию
def get_some_info(a, b):
    '''Здесь содержится какая-то информация.''' # открываем по три кавычки с каждой стороны, пишем текст

# %% [markdown]
# Если теперь вызвать функцию `help()` по этой функции, мы видим эту самую информацию!

# %%
help(get_some_info)
# Out:
# Help on function get_some_info in module __main__:
#
# get_some_info(a, b)
#     Здесь содержится какая-то информация.

# %% [markdown]
# **Если вы пишите функции для сбора данных из API или с веб-страниц, я советую вам делать следующее**:
# * **Создавать docstrings**;
# * **Указывать, на какие методы API опирается функция**/с каким типом страниц работает;
# * **Описывать параметры**, которые есть у функции (те самые `a` и `b`);
# * **Описывать объект, который функция возвращает**;
# * **Прописывать в конце docstring пример использования функции**.
#
# **Давайте докрутим нашу функцию `get_last_posts()`, и добавим сюда docstring:**

# %%
# представим, что мы спустя долгое время откроем наш ноутбук. 
help(get_last_posts) # в справке мы увидим только параметры функции
# Out:
# Help on function get_last_posts in module __main__:
#
# get_last_posts(group_id, q, offset=0, method='wall.get')

# %% [markdown]
# Пропишем только описание:

# %%
def get_last_posts(group_id, q, offset=0, method='wall.get'):
    '''Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
    и возвращает pandas.DataFrame с информацией об этих постах.'''
    pass

# %%
help(get_last_posts)
# Out:
# Help on function get_last_posts in module __main__:
#
# get_last_posts(group_id, q, offset=0, method='wall.get')
#     Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
#     и возвращает pandas.DataFrame с информацией об этих постах.

# %%
get_last_posts()

# %% [markdown]
# Добавим информацию об аргументах:

# %%
posts
# Out:
#     owner_id        date                                               text
# 0 -203966578  1703315788  Выборы-выборы-выборы! 🗳 \n \nГолосование закан...  \
# 1 -203966578  1704051000  Дорогие вышкинцы!\n\nНаша команда хочет поздра...
# 2 -203966578  1703669400  Дорогие вышкинцы! \n \nСегодня мы подробно раз...
# 3 -203966578  1703496600  Дорогие вышкинцы!\n \nСегодня мы, совестно с П...
# 4 -203966578  1703414444  Уполномоченный по правам студентов и аспиранто...
#
#    likes  reposts
# 0     38        2
# 1     13        0
# 2     10        3
# 3     25        7
# 4     22        3

# %%
def get_last_posts(group_id, q, offset=0, method='wall.get'):
    '''Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
    обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
    Arguments:
        > group_id - int - id сообщества (без минуса в начале);
        > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
        > offset=0 - int - смещение постов;
        > method='wall.get' - str - название метода, используемого в функции.
    '''
    pass

# %%
help(get_last_posts)
# Out:
# Help on function get_last_posts in module __main__:
#
# get_last_posts(group_id, q, offset=0, method='wall.get')
#     Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
#     обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
#     Arguments:
#         > group_id - int - id сообщества (без минуса в начале);
#         > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
#         > offset=0 - int - смещение постов;
#         > method='wall.get' - str - название метода, используемого в функции.

# %% [markdown]
# Добавим информацию об объекте, который функция возвращает:

# %%
def get_last_posts(group_id, q, offset=0, method='wall.get'):
    '''Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
    обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
    Arguments:
        > group_id - int - id сообщества (без минуса в начале);
        > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
        > offset=0 - int - смещение постов;
        > method='wall.get' - str - название метода, используемого в функции.
    Returns:
        > pandas.DataFrame - с информацией о постах:
            : owner_id - int - id сообщества, выпустившего пост;
            : date - int - дата публикации поста в формате unixtime;
            : text - str - текст поста;
            : likes - int - число лайков на посте;
            : reposts - int - число репостов на посте.
    
    '''
    pass

# %%
help(get_last_posts)
# Out:
# Help on function get_last_posts in module __main__:
#
# get_last_posts(group_id, q, offset=0, method='wall.get')
#     Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
#     обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
#     Arguments:
#         > group_id - int - id сообщества (без минуса в начале);
#         > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
#         > offset=0 - int - смещение постов;
#         > method='wall.get' - str - название метода, используемого в функции.
#     Returns:
#         > pandas.DataFrame - с информацией о постах:
#             : owner_id - int - id сообщества, выпустившего пост;
#             : date - int - дата публикации поста в формате unixtime;
#             : text - str - текст поста;
#             : likes - int - число лайков на посте;
#             : reposts - int - число репостов на посте.

# %% [markdown]
# Добавим пример использования:

# %%
def get_last_posts(group_id, q, offset=0, method='wall.get'):
    '''Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
    обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
    Arguments:
        > group_id - int - id сообщества (без минуса в начале);
        > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
        > offset=0 - int - смещение постов;
        > method='wall.get' - str - название метода, используемого в функции.
    Returns:
        > pandas.DataFrame - с информацией о постах:
            : owner_id - int - id сообщества, выпустившего пост;
            : date - int - дата публикации поста в формате unixtime;
            : text - str - текст поста;
            : likes - int - число лайков на посте;
            : reposts - int - число репостов на посте.
    Example:
        >>> example = get_last_posts(group_id=203966578, q=100, offset=0, method='wall.get')
        >>> example
    
    '''
    pass

# %% [markdown]
# <font color='green'>Вуаля! Теперь запросим справку по функции:</font>

# %%
help(get_last_posts)
# Out:
# Help on function get_last_posts in module __main__:
#
# get_last_posts(group_id, q, offset=0, method='wall.get')
#     Функция get_last_posts() принимает на вход id сообщества, число постов (до 100), которые надо вернуть,
#     обращается к методу wall.get API ВК и возвращает pandas.DataFrame с информацией об этих постах.
#     Arguments:
#         > group_id - int - id сообщества (без минуса в начале);
#         > q - int - число последних записей, информацию о которых нужно вернуть (до 100);
#         > offset=0 - int - смещение постов;
#         > method='wall.get' - str - название метода, используемого в функции.
#     Returns:
#         > pandas.DataFrame - с информацией о постах:
#             : owner_id - int - id сообщества, выпустившего пост;
#             : date - int - дата публикации поста в формате unixtime;
#             : text - str - текст поста;
#             : likes - int - число лайков на посте;
#             : reposts - int - число репостов на посте.
#     Example:
#         >>> example = get_last_posts(group_id=203966578, q=100, offset=0, method='wall.get')
#         >>> example

# %% [markdown]
# А теперь давайте напишем функции, которые будут собирать даные о друзьях и друзьях наших друзей.
#
# ## Собираем данные о наших друзьях<a name="par5"></a>
#
# Зачем это дело нужно? А мы с вами попытаемся создать сеть своих друзей и понять, из каких сообществ она состоит:

# %% [markdown]
# <p></p>
# <center><b><font size=4>Задача №3</font></b></center>
#
# Познакомьтесь с документацией метода `friends.get`, доступной по [ссылке](https://dev.vk.com/ru/method/friends.get).
#
# **Сгенерируйте строку `parameters`, запрос (`url`), и сохраните результат обработки запроса в переменную `response`.**
#
# **Учтите следующие параметры:**
# * API должно возвращать информацию о максимально возможном числе друзей (найдите на странице: 1) как должен называться соответствующий параметр; и 2) какое максимально возможное число объектов пользователей метод может вернуть);
# * Список друзей должен быть отсортирован по алфавитному порядке;
#
# *Подсказка:* если вы указываете несколько параметров в `parameters`, они должны быть разделены знаком `&`. Пример:
# ```firstparameter=somevalue&secondparameter=somevalue```.
#
# **В результате у вас должно получиться похожий объект, где `676` это число друзей, а значения в `items` - id ваших друзей ВКонтакте**
#
# ```
# {'response': {'count': 676,
#   'items': [463008298,
#    511785586,
#    53414043,
#    501118101,
#    338357646,
#    343197585,
#    693641278,
#    203816538,
#    689200024,
#    64564860]}}```

# %%
# СТРОКА С ПАРАМЕТРАМИ
# СТРОКА С СОЗДАНИЕМ ССЫЛКИ
# ОТПРАВЛЯЕМ ЗАПРОС
parameters=f'count=500&order=name'
method = 'friends.get'
# Генерируем ссылку 
url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token

# Отправляем запрос:
response = requests.get(url) # привет, requests
friends_data = response.json() # превращаем ответ в объект json, сохраняем в переменную wall_data

# %%
friends_data['response']['items']
# Out:
# [463008298,
#  511785586,
#  53414043,
#  501118101,
#  338357646,
#  343197585,
#  693641278,
#  203816538,
#  689200024,
#  64564860,
#  434439412,
#  436070330,
#  225054933,
#  385407304,
#  306684264,
#  559703139,
#  382097528,
#  96389248,
#  617724146,
#  300293854,
#  382979302,
#  252667147,
#  237774842,
#  469186618,
#  551917168,
#  235249693,
#  170456007,
#  229952864,
#  374312900,
#  425429966,
#  562435389,
#  357249335,
#  188058932,
#  260857567,
#  245402649,
#  359827731,
#  350579968,
#  819177382,
#  357379132,
#  211810890,
#  800349051,
#  671432786,
#  556798826,
#  270184602,
#  2416234,
#  253300723,
#  365184281,
#  229405692,
#  74023038,
#  150333556,
#  257956576,
#  176786299,
#  159825308,
#  288076167,
#  10741524,
#  397207853,
#  52442885,
#  47402039,
#  157793137,
#  821924911,
#  254993988,
#  232366362,
#  382773391,
#  33626945,
#  111940612,
#  160254892,
#  254061067,
#  310660072,
#  190750807,
#  200219603,
#  105872275,
#  116029220,
#  131139397,
#  203148481,
#  345892406,
#  430131834,
#  232010456,
#  560283396,
#  264205295,
#  336938384,
#  200771928,
#  118384656,
#  181158751,
#  172447691,
#  410198457,
#  233324735,
#  142296372,
#  227644820,
#  320402200,
#  423258683,
#  281463775,
#  181102471,
#  268469445,
#  316201638,
#  592346204,
#  199814122,
#  99305683,
#  144484539,
#  745819482,
#  323923200,
#  139654296,
#  86226248,
#  280369976,
#  199458203,
#  328909835,
#  200590375,
#  120220186,
#  94339233,
#  156675595,
#  180761191,
#  109401327,
#  214575410,
#  251372125,
#  229628167,
#  110855291,
#  225843054,
#  227894752,
#  141238566,
#  165562935,
#  136785454,
#  170788632,
#  334012376,
#  283819101,
#  190609636,
#  341167730,
#  321069640,
#  151155479,
#  217367376,
#  97928806,
#  209740229,
#  398878518,
#  119525570,
#  545173674,
#  126322766,
#  182405613,
#  164191158,
#  166226503,
#  320339991,
#  56725912,
#  311599071,
#  12325849,
#  443274632,
#  275075075,
#  249654578,
#  419039441,
#  304572683,
#  262289748,
#  297647067,
#  426940860,
#  116823354,
#  345646314,
#  668344930,
#  179941806,
#  376919520,
#  152434332,
#  211868921,
#  235127068,
#  178778656,
#  116640274,
#  81742295,
#  40294783,
#  244761098,
#  84574644,
#  411088129,
#  151064205,
#  137998155,
#  195584629,
#  165519167,
#  154461397,
#  135827453,
#  112653563,
#  273375208,
#  57506502,
#  184180363,
#  380984056,
#  274393923,
#  202475824,
#  101244803,
#  332741927,
#  100847278,
#  312033427,
#  357101309,
#  234162691,
#  81955610,
#  171317851,
#  122815793,
#  483098773,
#  115314063,
#  426209439,
#  347150146,
#  188734498,
#  48529189,
#  160516331,
#  293331968,
#  127486944,
#  215544685,
#  53896364,
#  173860385,
#  425924523,
#  460179533,
#  247387838,
#  84912968,
#  143809289,
#  140311380,
#  476331308,
#  137063771,
#  175838800,
#  226530295,
#  338184189,
#  119798743,
#  403625832,
#  336145654,
#  248656280,
#  166695226,
#  154141259,
#  376618627,
#  289521604,
#  321257793,
#  176079025,
#  296654695,
#  137113734,
#  127991288,
#  94356003,
#  378281618,
#  218352223,
#  516930225,
#  281542978,
#  252180218,
#  183324466,
#  358409550,
#  339714706,
#  234851997,
#  249859337,
#  170011316,
#  604765916,
#  223396520,
#  93235970,
#  272096291,
#  254670348,
#  234684951,
#  247307781,
#  146512916,
#  160480466,
#  552273857,
#  211058196,
#  275220376,
#  228482714,
#  222345903,
#  399273396,
#  386643792,
#  348776518,
#  178633341,
#  50966702,
#  590171018,
#  164273777,
#  198806821,
#  144798758,
#  98297935,
#  307343806,
#  49235357,
#  50302822,
#  46892939,
#  228843641,
#  606551441,
#  303096440,
#  70569001,
#  110263714,
#  192862635,
#  206476983,
#  384651671,
#  68374620,
#  229452493,
#  151106516,
#  91488210,
#  110248399,
#  202304550,
#  165276158,
#  667375102,
#  323760100,
#  54780186,
#  222997032,
#  448495167,
#  225374808,
#  152904014,
#  182129118,
#  400901675,
#  290703552,
#  151556284,
#  242242220,
#  218522208,
#  254354386,
#  202296311,
#  95338471,
#  308961333,
#  478613267,
#  151489317,
#  174522612,
#  202477790,
#  167749978,
#  255284519,
#  280378156,
#  99835923,
#  1895676,
#  122388308,
#  274066679,
#  183186514,
#  171161387,
#  308758566,
#  180694858,
#  132570982,
#  57039283,
#  189274852,
#  366925808,
#  174366245,
#  322211651,
#  160978124,
#  138351182,
#  180315121,
#  87458281,
#  119214725,
#  203159383,
#  206066727,
#  139110462,
#  186491796,
#  138898770,
#  41437413,
#  16790170,
#  239688536,
#  236472662,
#  224284804,
#  257581038,
#  50945659,
#  363814967,
#  264907355,
#  119827468,
#  212233520,
#  321937455,
#  94831125,
#  204887171,
#  207642332,
#  90300241,
#  254257998,
#  171789570,
#  6690917,
#  222297972,
#  303732889,
#  216321842,
#  125661900,
#  178194663,
#  203917528,
#  135187349,
#  157904594,
#  130896,
#  243138105,
#  8734733,
#  137025593,
#  132703777,
#  385787816,
#  249423502,
#  251349432,
#  252194092,
#  561023465,
#  39422426,
#  184888402,
#  150655429,
#  256970281,
#  143419205,
#  171150321,
#  154109588,
#  423072612,
#  320717309,
#  579003824,
#  262681745,
#  354967442,
#  181567414,
#  387841236,
#  291886020,
#  42187308,
#  311430378,
#  377440854,
#  83844057,
#  155734805,
#  117164358,
#  159226539,
#  507858079,
#  363518956,
#  81091156,
#  190220467,
#  149268520,
#  136161093,
#  252276124,
#  84573350,
#  360279870,
#  179654703,
#  94989154,
#  322747261,
#  50733772,
#  167325352,
#  271220773,
#  312440859,
#  118577028,
#  462537098,
#  583298409,
#  140833101,
#  285920588,
#  192028512,
#  222044788,
#  84071057,
#  153819651,
#  195486930,
#  29567553,
#  114937408,
#  104174289,
#  83401019,
#  237176905,
#  301032216,
#  144831629,
#  452251062,
#  143295881,
#  478276862,
#  108016531,
#  43582908,
#  201122827,
#  133534267,
#  212940644,
#  160018988,
#  99170843,
#  95686521,
#  302820290,
#  492221893,
#  206649082,
#  69933302,
#  469375271,
#  193180498,
#  353780735,
#  190566081,
#  146093925,
#  612598983,
#  240918056,
#  173453019,
#  501971602,
#  132988370,
#  131731880,
#  200593619,
#  39613300,
#  571399580,
#  206814817,
#  32525177,
#  384497679,
#  167177017,
#  153879403,
#  142769518,
#  193211713,
#  356200076,
#  293571539,
#  432256827,
#  32151440,
#  334634357,
#  671293005,
#  274643518,
#  561708614,
#  396656660,
#  382221737,
#  48905537,
#  253862540,
#  145072312,
#  203308077,
#  92818192,
#  54666546,
#  152114541,
#  326426305,
#  50739889,
#  360901615,
#  589202205,
#  370514239,
#  186535095,
#  709743,
#  272752869,
#  365850939,
#  100506791,
#  202561855,
#  267345882,
#  215830236,
#  540628947,
#  292788872,
#  21634006,
#  326452339,
#  301925212,
#  235388948,
#  43907854,
#  361587741,
#  306345924,
#  186084074,
#  270139674,
#  4144285,
#  63653384,
#  170778996,
#  376698930,
#  84659882,
#  180064800]

# %% [markdown]
# **Теперь:**
# * Сохраните id ваших друзей в переменную `my_friends`.
# * Напечатайте длину этого списка.
# * Напечатайте 5 первых idшников ваших друзей.
#
#
# *У вас должно получиться что-то такое:*
# ```676
# [463008298, 511785586, 53414043, 501118101, 338357646]```

# %%
my_friends = friends_data['response']['items']
print(len(my_friends))
print(my_friends[:5])
# Out:
# 500
# [463008298, 511785586, 53414043, 501118101, 338357646]

# %% [markdown]
# **Супер. Теперь расширим нашу функцию.**
#
# **Запросим больше данных о наших друзьях:**
#
# * Добавим в `parameters` дополнительные параметры: уточним, что нам нужна расширенная информация по пользователям `&extended=1` и что нам нужна следующая информация про пользователей: `bdate,sex,domain`

# %%
parameters += f'&extended=1&fields=bdate,sex,domain' # уточняем параметры

# %% [markdown]
# Ниже добавьте код, который вы использовали в последней задаче (только без `parameters`).
#
# Он должен вернуть информацию о числе ваших друзей `{'count': n}` и ваших друзьях. В моем случае это выглядит так:
#
# ```
# {'response': {'count': 676,
#   'items': [{'id': 463008298,
#     'domain': 'al___lex',
#     'bdate': '17.8',
#     'track_code': 'e34d35e77p4tUxB3UJk-W0pbAyeX3b_xPziMprhtI-kSYRWLpWOD9SJiKHUCnGpZcsOK5Q22zOUmNJvI3B58',
#     'sex': 1,
#     'first_name': 'Alexandra',
#     'last_name': 'Oorzhak',
#     'can_access_closed': True,
#     'is_closed': False},```

# %%
# строку parameters мы уже создали
method = 'friends.get' # наш метод

# Генерируем ссылку 
url = 'https://api.vk.com/method/' + method +'?'+ parameters + '&v=' + version + '&access_token=' + token
response = requests.get(url) # привет, requests
friends_data = response.json() # превращаем ответ в объект json, сохраняем в переменную wall_data

# %%
friends_data # дожен получиться такой объект с информацией о наших друзьях
# Out:
# {'response': {'count': 676,
#   'items': [{'id': 463008298,
#     'domain': 'al___lex',
#     'bdate': '17.8',
#     'track_code': '22bfb2baxkxyrbwrkRjFaU1GO_zSXFfcB90ReRR42BHui6hl07-rJ33P0ymXSMBgdefQRTE3JMge0QYXcAuH',
#     'sex': 1,
#     'first_name': 'Alexandra',
#     'last_name': 'Oorzhak',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 511785586,
#     'domain': 'quindicosafare',
#     'bdate': '7.4.2004',
#     'track_code': '1a783628cKU3vrxoH5-i5VNykzWO_BKLUPt_5wsjRpA1xhDqj84dzmjbgW9ImqDuZ9R5gm2XYZ9J92iJb1AZ',
#     'sex': 1,
#     'first_name': 'Alina',
#     'last_name': 'Ell',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 53414043,
#     'domain': 'id53414043',
#     'bdate': '28.9.2000',
#     'track_code': '258ae3b1soSpkCp0qJUnlaGYVRhnlFNKt8fMlbkELNtV1vfL3zDf7_CpEnP6liSUkz-0n-_zM0eg3Kn73Xc',
#     'sex': 1,
#     'first_name': 'Angelika',
#     'last_name': 'Zagashvilli',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 501118101,
#     'domain': 'anna_oorzhak',
#     'track_code': 'e1809a4dGEauONqUampd7YNjD07J8fUl9IAgexJFN6Crp0ij8Nl1LfQBsJBqPwntuMHt_iqahjHtjDcVdjZo',
#     'sex': 1,
#     'first_name': 'Anna',
#     'last_name': 'Oorzhak',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 338357646,
#     'domain': 'aanopa',
#     'bdate': '10.12',
#     'track_code': 'c2d66d7bc--xUkZvX7PhzY8f2U3OAP5gJsDmuK85e_oP0Dl7ZJEehOpkez8Kv-OZvLo_-i1rjXQ_zPHWy0ok',
#     'sex': 1,
#     'first_name': 'Anopa',
#     'last_name': 'Anopa',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 343197585,
#     'domain': 'ood003',
#     'bdate': '26.6',
#     'track_code': '9a3f2544ucQPmKCk0JzoCuQiRrOvD78iJPiTIMdTfQeTy_Kw2_fUrwf8z6XRnOxX1oSsB0xkzDY99IROoyAi',
#     'sex': 2,
#     'first_name': 'Artjom',
#     'last_name': 'Rozhkov',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 693641278,
#     'domain': 'id693641278',
#     'bdate': '9.8.1993',
#     'track_code': '5a5c95daX2Qp5UdXb-W11SS3Bynk8ddH0ANpzJdvI1DszJkhqSEyD3OEfwU3tLeHExbikAeapFPJD36i8xx8',
#     'sex': 2,
#     'first_name': 'Ayomide',
#     'last_name': 'Adedini',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 203816538,
#     'domain': 'isbetsy',
#     'bdate': '22.8',
#     'track_code': 'b259af0afweIVgAMI7Iv2BA7U6gPSoWAEdbXW9EGEvTqFyWxhCgSbNJnOQsnuXXYIZ2yEewh9pQI2sA1tXVN',
#     'sex': 1,
#     'first_name': 'Beata',
#     'last_name': 'Isakova',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 385407304,
#     'domain': 'daria.samoylova2004',
#     'bdate': '7.8',
#     'track_code': '75f1a1df9qbgRL6826P5Lver-CgxsvCRauMgm1bANy7UoR3yvrGbzb8h1b3aoP59yAsandLZg4Vz7zf1MrNo',
#     'sex': 1,
#     'first_name': 'Daria',
#     'last_name': 'Samoylova',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 306684264,
#     'domain': 'darkness_fucking_triumph',
#     'track_code': 'c16ce20caYUNlRc5cA1ZHNw_TjmMO6LTJUfzTjFiU-7pXFOrKKEE7l-lfzohD11G4Z6qjG9Q0cc8S-QgVREM',
#     'sex': 1,
#     'first_name': 'Darkness',
#     'last_name': 'Triumph',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 559703139,
#     'domain': 'davvud',
#     'bdate': '3.10.2000',
#     'track_code': '77d8a00dqLhqoGwnkcbkjfTi-17z8RSiY8eJn8CM31a0PQKr2VPF0zGRAHfBnuPZzUAa5hCaZ7Z6y57xpP-A',
#     'sex': 2,
#     'first_name': 'Davud',
#     'last_name': 'Akramov',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 382097528,
#     'domain': 'whythepain',
#     'bdate': '12.9',
#     'track_code': '9c321f58YCcqiGfB6Lvp3c6dO5KUPzDxs4sUsaLc8D_6fURagDoNTCC6XpG1vu7T8jvbK3dUQ-WqhwPfxq-v',
#     'sex': 1,
#     'first_name': 'Death',
#     'last_name': 'Hey',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 96389248,
#     'domain': 'id96389248',
#     'bdate': '20.4',
#     'track_code': '73eea38aYdao4n3iSX6i4Io3_8I4PUDJxVRRyqk3zkP5Fjq3WfsMvfPRRe0cL_vvtJAVRbBaIMTSTzSkzUQ',
#     'sex': 1,
#     'first_name': 'Ekaterina',
#     'last_name': 'Lysenko',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 617724146,
#     'domain': 'elizavetaroschina',
#     'bdate': '9.1.2005',
#     'track_code': 'd5893d4dQtRjdmrhj5X3eD1x9Xelpnb4rN-xim9nEftl-WvR1K0vv2oXB7SMxqZzBNMTwEbNBey106bkCxRO',
#     'sex': 1,
#     'first_name': 'Elizaveta',
#     'last_name': 'Roschina',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 300293854,
#     'domain': 'evgenii.solodov',
#     'bdate': '20.3',
#     'track_code': 'e814baaadm16dEdzwnsumjxf9S1A5fkV9oTn_PS5NLZWnjPdW-YbBnBALyPFcn6TAfQSmKOOigHviPCSkMpr',
#     'sex': 2,
#     'first_name': 'Evgenii',
#     'last_name': 'Solodov',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 382979302,
#     'domain': 'hummyheadache',
#     'bdate': '14.1',
#     'track_code': 'b066c303HjYtE8iADHR_2Koh8bMUH4htBrbBMpHE8_X96pw5y45zXX4h-YANd3CLnIETAPd0-3kfutZc9bes',
#     'sex': 1,
#     'first_name': 'Hummy',
#     'last_name': 'Headache',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 252667147,
#     'domain': 'j.rustamov1',
#     'bdate': '29.8',
#     'track_code': '712720a2sd_yiBqp-DgElrkeMGW-z5f4KPoCOl4rvKmUCcpCPjLctPu8dqz6OlSUnrzW012k5Owx9hVUOljj',
#     'sex': 2,
#     'first_name': 'Jaloliddin',
#     'last_name': 'Rustamov',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 237774842,
#     'domain': 'jaroslawsnarski',
#     'track_code': 'dcccf6b4YtCJKg9HKvegQ1diDMHLC7qprTre1IhMfrRw3WRjIjMPu9ocZ0Eu96FCcsnqcihgyb20Nsm67D8h',
#     'sex': 2,
#     'first_name': 'Jaroslav',
#     'last_name': 'Snarski',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 469186618,
#     'domain': 'klorraine',
#     'track_code': '3294be59iPTzWbzdyqT-B49a3VPoiRAFJoaMSNwZaqTqOJDGDbzln_pt09_Pr_oLq_8-6gviYxE_ipsmuGo1',
#     'sex': 1,
#     'first_name': 'Kelly',
#     'last_name': 'Lorraine',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 551917168,
#     'domain': 'ts.khulan',
#     'bdate': '6.7.2005',
#     'track_code': 'a4545ac8kQBi2065dbrhCqOSUwRcc0RjGUnYJyNTPy0VJelBfBP8azy4cr8lue5YhzC3vb8YN3cARc9JRyBg',
#     'sex': 1,
#     'first_name': 'Khulan',
#     'last_name': 'Tsogmandakh',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 235249693,
#     'domain': 'diko1ana',
#     'bdate': '29.6',
#     'track_code': 'a439446cDPYShiSqqRJxn8OngRzCD2axNaBRJeMIj4t7yxt_YHlhnR2zTKuiFHDI7gJqriFkFaUsrEZLh3vQ',
#     'sex': 1,
#     'first_name': 'Lana',
#     'last_name': 'Dico',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 170456007,
#     'domain': 'id170456007',
#     'bdate': '15.6',
#     'track_code': '1a711ae0HFlOWY5RKJ07QbzXJAqWhbtz3xC0fobBXJPNGHU68HVxMhVpvlAtlDpFn3TGvHXuyGfGHKMQ4rID',
#     'sex': 1,
#     'first_name': 'Lena',
#     'last_name': 'Metlinskaya',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 229952864,
#     'domain': 'id229952864',
#     'bdate': '3.8.2001',
#     'track_code': '74c4c364CEVCV4Epx2QDvCW0uzaw7KyZ47oqtHEz_UKSJ4Y4AqhlLkpg7SPMOQjrAR9fg1OH3436tj3aFUCi',
#     'sex': 1,
#     'first_name': 'Lera',
#     'last_name': 'Blumberg',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 374312900,
#     'domain': 'lexa_baltika',
#     'track_code': '131ad0925gYaK0g-g7182W2mNSd_tEqf4iIsKakhcWqdDQZ4TVOLbRNOJG_R6n7bSAzXlpzfOYv7LjtHzVIu',
#     'sex': 2,
#     'first_name': 'Lexa',
#     'last_name': 'Baltika',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 425429966,
#     'domain': 'rtltmtfgmt',
#     'bdate': '7.9',
#     'track_code': '4983e9872LD5648iUJG8SpEwJPxGiiJeVpdJmVBMJNfqRTPCQqu126LZ53cHkLFPsJrAS6XhUUpPm173ND97',
#     'sex': 1,
#     'first_name': 'Lisa',
#     'last_name': 'Kojarinova',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 562435389,
#     'domain': 'meowllouxx',
#     'bdate': '24.1',
#     'track_code': '19c9bd3crubVSuxKgou00d1FHHxKGiqOtl7VSCmEHHDJHo6J7RLDjdp_0EqMi7KE8eX2xKlxWZqvUsImTfdD',
#     'sex': 1,
#     'first_name': 'Lou',
#     'last_name': 'Miller',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 357249335,
#     'domain': 'margaret_lis',
#     'bdate': '27.9',
#     'track_code': 'e24340beJFzVCje_ZyZD5ozXvyCxbd3W0Y5h6p0it2_-eqWB67BJN9oyCepiJ0Gzr3delFIGrsLIgnaE-VHo',
#     'sex': 1,
#     'first_name': 'Margaret',
#     'last_name': 'Eliseeva',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 188058932,
#     'domain': 'mmatveevamm',
#     'bdate': '18.2',
#     'track_code': 'eb0419f15vN5Z6u9ZERwBSwhw-LwHOXYvw2o5CiWmwJ5ewreiPKLmCZSwbhtSnkFD4siURN3lsymAb-KTOXE',
#     'sex': 1,
#     'first_name': 'Maria',
#     'last_name': 'Matveeva',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 260857567,
#     'domain': 'kgndss',
#     'bdate': '18.12',
#     'track_code': '14515c0dfDNNsW-RmKtPQdaFN7uLr9uDmFclOYWxjsXwRXKiTVkRWBLTUcWY_UdB_SPTDWjEqJeBWzJX4cLR',
#     'sex': 1,
#     'first_name': 'Marina',
#     'last_name': 'Kazyulina',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 359827731,
#     'domain': 'claymachinegun',
#     'bdate': '29.8',
#     'track_code': '20db578dCWxOQyHotj8ZlDZkLM9tnJ_kTu0MYt7FcYtZvRwCYl9kB0YnTLriZxPAHMDNf4737PBX4RsMurYu',
#     'sex': 1,
#     'first_name': 'Mrs',
#     'last_name': 'Robinson',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 350579968,
#     'domain': 'prince2300',
#     'bdate': '30.9',
#     'track_code': 'bdd4c3c71lBmRkf8VxegUXRKPknzj7_lemTpWeG6lwITmDNAAXG7Ozpwd65SFKQEU-Da8BDkzPFjaP43hcnI',
#     'sex': 2,
#     'first_name': 'Muhammad-Didarul-Islam',
#     'last_name': 'Prince',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 819177382,
#     'domain': 'id819177382',
#     'bdate': '29.10.1999',
#     'track_code': '0c053afa0M-Mh1cyJqFw_btpE_7__dV0Ih9XtBpbKSHGRZ4ltQO9pNCwOzohrXKpk8n5TRyWpmA7E0Dafih2',
#     'sex': 2,
#     'first_name': 'Muhammad-Sarim',
#     'last_name': 'Jalal',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 357379132,
#     'domain': 'id357379132',
#     'bdate': '12.1.2002',
#     'track_code': '47fd62c4xtbWv6WPNmbGsnwWZCVrk30u0gPO_LsyhXUrCOMQuqarvdmIlI86N8PmZbSFloj4DjrLD9mS30Ha',
#     'sex': 1,
#     'first_name': 'Polina',
#     'last_name': 'Podkopaeva',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 211810890,
#     'domain': 'sabinamalinaa',
#     'bdate': '19.9.2002',
#     'track_code': '3adaeb675asO7rrOL_ySLic4LzkIgsj9Y9tCusrNopRQW8ToeSaIwAGL1cwv9J4oNpPEiOvpu-l611XUrr79',
#     'sex': 1,
#     'first_name': 'Sabina',
#     'last_name': 'Galliamova',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 800349051,
#     'domain': 'saudade_23',
#     'bdate': '2.3.1999',
#     'track_code': 'c9eccaafUYVfj44I_5fyj06jujHHnUWWdMHhKsluGOEcgVKFlf887lfs4Qn2nvaPVQBdgST2NoJtzfZErR1H',
#     'sex': 1,
#     'first_name': 'Sagdiana',
#     'last_name': 'Allanazarova',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 671432786,
#     'domain': 'fallibilist',
#     'bdate': '2.3',
#     'track_code': '162f9ea0hA8_DiemZLvfkHbmjmOYCiBKcY_IgTDg83w9EoR9-9LpZGY_GKlnu9PFZ0Jk1HthU15og9_vVJOs',
#     'sex': 2,
#     'first_name': 'Sukhayl',
#     'last_name': 'Niyazov',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 556798826,
#     'domain': 'tbakytbai',
#     'bdate': '7.7',
#     'track_code': '1a43fd84fQbJlois-AQL6wYTJdQRwmHDbppJkA6HIuI-X8XuN8YQbZejt6H4BwvhGrjFY_KpEtd3ll7-avR9',
#     'sex': 2,
#     'first_name': 'Tim',
#     'last_name': 'Bakytbai',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 270184602,
#     'domain': 'id270184602',
#     'bdate': '30.4.2001',
#     'track_code': '4a9cbe08NJafIwIhWe4ZmsLT1mN3MTtsdATgsxt4hc90wkWOz-VZ_cxCbnEM7kyS03Y00JRaSHhtCPfdfwva',
#     'sex': 2,
#     'first_name': 'Vasilii',
#     'last_name': 'Molchanov',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 2416234,
#     'domain': 'dmitry.zemtsov',
#     'bdate': '9.8.1984',
#     'track_code': 'e1b1b6bfFp4GafxU7Pqa95tzAhu7gjZlmSJzM8sSgKjsO1wxDYN79QsPnwDoqp_3jtTW9z_2T2aZSxZdrw',
#     'sex': 2,
#     'first_name': 'Zemtsov',
#     'last_name': 'Dmitry',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 253300723,
#     'domain': 'abram.gendlerburg',
#     'bdate': '29.4',
#     'track_code': 'bf517131YW9YysNFxQ6aGLSAtgjLST1akSSWG_K69hCBSQlKAkMMBAH9_UOTDMgZoyRWuigiTk6IKIF1lsmp',
#     'sex': 2,
#     'first_name': 'Абрам',
#     'last_name': 'Гендлербург',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 365184281,
#     'domain': 'id365184281',
#     'track_code': '51aa570eh1f29YUhNr6S8elx_a43dhpOhNSpSPLz-TxMaWfHGZ7qPKzBuCFkvsH-9dAXHtQdaVqd2L4mloCm',
#     'sex': 1,
#     'first_name': 'Аглая',
#     'last_name': 'Иванова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 229405692,
#     'domain': 'nordlandd',
#     'bdate': '9.4.2002',
#     'track_code': '4c4e3e4asoVDdVEYCeFRHFwOk-GFF44J50_oiMluyBKmPaBjB8bf7kkRbx8KvgQcQKt4UmZ8_R3-Q__mrR2X',
#     'sex': 1,
#     'first_name': 'Адиль',
#     'last_name': 'Яфарова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 74023038,
#     'domain': 'azalia_areves',
#     'bdate': '13.12.2000',
#     'track_code': '68494f6cbugAHkbgIQuBQmJH-p6cGEmE27IFabwj_cRQ-GqLufYDg1suLO52DIVGeOcQGRR_KYnMqWAH2FA',
#     'sex': 1,
#     'first_name': 'Азалия',
#     'last_name': 'Исламгулова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 150333556,
#     'domain': 'aidar.kalimullin',
#     'bdate': '3.7',
#     'track_code': '849b5c7atb14X82DtbPTLTG-i9B9mF_9thT_Fque-O0vgKQOIWbY1is594e159V8KRhsZ57zLOmvGOh4z-2n',
#     'sex': 2,
#     'first_name': 'Айдар',
#     'last_name': 'Калимуллин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 257956576,
#     'domain': 'adrozdova1',
#     'bdate': '19.11.2001',
#     'track_code': '91c7e848YQr_NUP-pZKsDD2NYSiwN3URhqyrFW7bgXv6p60Y_vkMYacFe_qkx_MKJyuEn1NcBgWfoLx7Cqje',
#     'sex': 1,
#     'first_name': 'Алёна',
#     'last_name': 'Дроздова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 176786299,
#     'domain': 'ly.erma',
#     'bdate': '30.6',
#     'track_code': '740d85fdpvLOW6B42KhTd60tpiAg-t1i0Iprblw5Vq1zYZ73rlHLmZw4ny-Np1IptoxNmMORrnbJhnwAOEoJ',
#     'sex': 1,
#     'first_name': 'Алёна',
#     'last_name': 'Ермакова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 159825308,
#     'domain': 'alelik_sergeevna',
#     'bdate': '10.1.2001',
#     'track_code': '6eef2819fApi1NO_gjY7oj7xUNR5krjWvVRZhG4Z2obgi6Su9tYRYTG16r6HbGGnJVGybZr5y8KkWE7qCmqF',
#     'sex': 1,
#     'first_name': 'Алёна',
#     'last_name': 'Козлова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 288076167,
#     'domain': 'bzgly',
#     'bdate': '26.5',
#     'track_code': 'e3854c03-ZHsxTG-WFh3_B12hvpZByIfQ8yh5MJcOGLOmqjY1EaU-uTwDulVVXLyBNRiTLpsUQtawLaKpi9n',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Безуглый',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 10741524,
#     'domain': 'id10741524',
#     'bdate': '13.2',
#     'track_code': '8e9930abpNX2goNKxRKJC8ixUK7veIwJHcb_uOvKntTOBVSqpeHJvvm2vxmXHI8OzRC2KWcf7AQK3ZrWj7k',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Журавлев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 397207853,
#     'domain': 'a_izosenkov',
#     'bdate': '22.5',
#     'track_code': 'bf2736b2Jel3R7YIOAVgToA2nlRpPjKaNrJKuij0yP_0v92UCh1IgiUh2V42CmpLhp155opVQY4vvl3UTIeX',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Изосенков',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 52442885,
#     'domain': 'id52442885',
#     'bdate': '26.7.1999',
#     'track_code': '59e4922fTKnBtF1iXxe0MwUggEnpnkqiCaoV6tTr3F-CnVKplrwhwpvRNGBbErFiD4tnzmH5Kq8esXCEsJg',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Карпунин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 47402039,
#     'domain': 'mr_kirilov',
#     'bdate': '26.7.1996',
#     'track_code': '0f07b818Y0g2f7P0JdO8DhDDHlbS-2DsSrAIIe0vqiQXBQh-OEQOIzxPjfMrgugLE2P10VqcAOFdq21PiVw',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Кирилов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 157793137,
#     'domain': 'not_salieri',
#     'bdate': '26.6',
#     'track_code': 'edfb3eecX3MV3FMfQ3BnumQdJf7f_Ep5Q2ErTh9rReYfqF4ssEUyGBy6ah4TJDO6Y7_ESDyXOW1abTwgexga',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Кудряшов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 821924911,
#     'domain': 'amatvijenko',
#     'bdate': '15.4.2005',
#     'track_code': '940781aekmo9oq00JqATigxKPYlNm2LbifC5W69Y5rQFbBmpTm3_ATeVlzUm8B7bDeDeOa7wEc-Q_K41yyu5',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Матвиенко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 254993988,
#     'domain': 'meltgbs',
#     'bdate': '24.1',
#     'track_code': '9711e2f2uRmw0mJ-BFcajtGnEDfcXYFlratGFeilEH07UMGYnhLUcuu0WXgIBkfS1A36jj828nG0p1F7jNZP',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Мелик-Оганджанян',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 232366362,
#     'domain': 'id.aleksandrbro',
#     'bdate': '6.6.2001',
#     'track_code': '1df44f7dLgQDrjlZecoh0DbS66E1Apdy4bHija9T3q3NnUKNnVBDb1maBVIuzXPUN3IPEtZp5Gb4vfXjyyCB',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Микерин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 382773391,
#     'domain': 'aknovikov',
#     'bdate': '23.10.2003',
#     'track_code': '8de446698lXWeOLbrqQb33z4zsXxaP8d7QpYYGCiwutjIHz6UjmfPoRN0tz0ok3Qd1gldRIDjAn0Bk8OBNGd',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Новиков',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 33626945,
#     'domain': 'l_ex_21',
#     'bdate': '12.10',
#     'track_code': '238777afqUCrXyFPgM0YEqu-5N01uynWSBZd2F6wBkp1LUe3Fu3EK_A-G0jSyhgQqxkDWr3cSdtfDTi2OsM',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Осокин',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 111940612,
#     'domain': 'ralexander09',
#     'bdate': '9.9.2001',
#     'track_code': 'b37636b9IjdGNSsACjcE3Wz3vwKYaBX8DAuchKe1xiM3EtU6KxZPXBUDGgBfY17ZZlJcsXsDZugVB4vqw8aZ',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Романенко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 160254892,
#     'domain': 'astepss',
#     'track_code': '29cf27102vq9_RBAMF-DCogHtZgzCk18SqRKTi3NEJtBltUfNpu3kbCffBU3WtcPh6xeK9BhPmhTqF0gSb5P',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Степанянц',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 254061067,
#     'domain': 'deralexander1925',
#     'bdate': '25.3',
#     'track_code': '659dd13cfjhZb9ip63A49Ok2ztxbBWn4qubfKSHfihYUtVYgdaATU1FZ5_nqczGk5JUqarhuGuyz6shHRazV',
#     'sex': 2,
#     'first_name': 'Александр',
#     'last_name': 'Таёкин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 310660072,
#     'domain': 'sasha_vasilieva',
#     'track_code': '493cf8c8V48UZMe2cq5E2GlwOZaczbmn79IlzoQOuZ0S-I7QA9o65BpQ9rJyqkPeZNPcJX-myrP23jKg4H3m',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Васильева',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 190750807,
#     'domain': 'adoubt',
#     'track_code': 'fc9a51041gbDF2SFlRj8mklwkL2bCBbX1eGFdus0P-26EqqNrKS7bZh1XoGfGvOXR9tyC3hjZcPM7ZIYj0dg',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Даутова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 200219603,
#     'domain': 'elisovita',
#     'bdate': '4.6',
#     'track_code': '7d3df35bxToA6WRMfIWIaghprTnPnGE1XP_Hpn_78RvDZtWdAn2oUVPfVU10h4luDsxPiyz3EiFF89DIG4iu',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Елисовицкая',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 105872275,
#     'domain': 'alexis.kras',
#     'bdate': '22.2',
#     'track_code': '9a27c175-yEqZhf6wVTuTXkZfpQY0ns_44OlGijeVHt5YE2jVaOWSiJSKvLJBe5MC7ibIPu5CCv6j7J0TK0L',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Красинская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 116029220,
#     'domain': 'cd__mm',
#     'bdate': '16.12',
#     'track_code': 'f42290bbSrK2vI8ebosFtPnSO_zDNyBN9sNC0gq4um4cNHjcQMsn2b6PtB853gHggXPbTSBcU1nvz1W8bsvl',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Лисица',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 131139397,
#     'domain': 'alexandralounrua',
#     'bdate': '31.3.2001',
#     'track_code': '37dd308eeoQ1Ja1tyN-7sEaO6gacV-Mq0XMExEO0OcXfsH7dSFwX72kckmzMj-nhPS4BsH88kD7IfxOqJ8dm',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Ломанова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 203148481,
#     'domain': 'interference_101',
#     'bdate': '21.9.2001',
#     'track_code': 'dbe5034ceB9fiMEGDNnTxv_3UIavXP-Xw3AEK__kQQ2TmBeFx88VdAWw_wVZ2NTHhFC6Nkw3jIPafBNFm5ce',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Маяк',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 345892406,
#     'domain': 'girlslovepirates',
#     'bdate': '6.4',
#     'track_code': '6842e6a2CrFmOqn5ysCqciapru7BwZDdu5GMrJLI3gx90aSXGrxn2j4Kl_rKk_ZzUA5MWSKq48minZvC9ruB',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Можаева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 430131834,
#     'domain': 'alxndra_ogonyok',
#     'bdate': '22.5',
#     'track_code': '0ac874c3r84QwzI7rH_TOnwSCzTnLFycjmvFpSvEQA8y-8V1kZfCpR2gAzuueNY_CLnqgQRHL4iXZ9LLT7cf',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Пожарская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 232010456,
#     'domain': 'radina27',
#     'bdate': '28.3',
#     'track_code': '551426a6KwxOb7GabJPnGTNbuDXNDdka1Lzjs3XkIwa3HZun4VRGZ0Bd25Fuw-dKRfxfgi5mqg7NsPTdEZd8',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Радина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 560283396,
#     'domain': 'sanchousinka',
#     'bdate': '28.11.2003',
#     'track_code': '24ca4e49Nm4iZY4V5FZAQOb0bHEgj3FnaPp7T2yxwtygCSKSQ2hbBXFU4UHmAxFJklSHxsPkAnNx9mwhCMKd',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Рекина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 264205295,
#     'domain': 'filip_pova',
#     'bdate': '28.12',
#     'track_code': 'a927d12aK_jEY0DFr-MJwBU29vv2fRo25fGhipZC5uQOet-YP19Gk5wGe87_5QOWaJcdTxUWaSL8_bbk8jG5',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Филиппова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 336938384,
#     'domain': 'vika_ne_sasha',
#     'bdate': '23.10.2001',
#     'track_code': '467ca639dfAJpnJ4kk8MergwPohUL-0Imlvs1Omu0RdtbItN0qsYm1XDQn7DTFd8yZDUPbdEnhyDV_u6jd2O',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Чарская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 200771928,
#     'domain': 'shura_is',
#     'bdate': '4.4',
#     'track_code': '6708ee11Tec2SmF35SZXbPN0NIGPvkjl3LUELIEi6pA0KrdTcdEgjD8uWXewIwJtiN7UOGzVO_HFuRNC5VG1',
#     'sex': 1,
#     'first_name': 'Александра',
#     'last_name': 'Яковлева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 118384656,
#     'domain': 'sta_ssss',
#     'bdate': '19.5',
#     'track_code': 'a21d134b5SuzuhgXz4oSMiQ5aGAdtPuxvzQyZSNPaUrW9MeJK_qIQL7bdxKa1xZuW5yP1_7fiKWmOCULRzw2',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Ададуров',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 181158751,
#     'domain': 'kukuevskiy_flex',
#     'bdate': '17.8.2000',
#     'track_code': '102304c9t5dcs9F4SVU98Bq1eWOTuyfxx2uV53aiUlUFicCeN4va_AHS6XtJADrzbhGe03DQVOXeZ4KJEtEN',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Батищев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 172447691,
#     'domain': 'alexdolinin2911',
#     'bdate': '29.11',
#     'track_code': '7ad76ab1iEJwPMy0dchtHF8z6krCkIJ1jwi8M5j6noUEpLAWCYzlKXgJ8LEgm2kRJZYB-iH78WGWBKtd_InB',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Долинин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 410198457,
#     'domain': 'alexey.drobot',
#     'track_code': '860159e9xnk1hihF5CO8gbpEEVzQ4eW5j9LNWvUaTepl-WHnXZ6rEm3gQ0Wzcr2OzOP26jOKlq2W3to0kWkS',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Дробот',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 233324735,
#     'domain': 'padrederoma',
#     'bdate': '2.4',
#     'track_code': '26e20200Hu6J7cVMTsR7micotmboC00Oizj9AIsSR0R9tH9dp5ZzhdCL_U1IxS6bXIxX0gtgPhqSNOpu72EY',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Журбицкий',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 142296372,
#     'domain': 'nightmare2077',
#     'track_code': 'be3dda80p718CP8IxZmPb8ISKUHS8FP-kkCQ7aJpojYa_TMWAPfK1nEwxAzBmYQwpLLM8jGbIOqLTIeDxhr9',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Корягин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 227644820,
#     'domain': 'withfactsandlogics',
#     'bdate': '14.5',
#     'track_code': 'ce1421e5pvn8uaFrQg85emPqlC5Dr8eaTP9WoV9gYImCAKHXQpnLkvKAnGwRATgoBkF0n6DEtI5V80HPOxM_',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Пыхтеев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 320402200,
#     'domain': 'alex_rus_22',
#     'bdate': '10.3',
#     'track_code': '024c55aaVWj6ro-SYGYRSCYy6mDM_pkeCbF2krmVDfq3PNUZxOA4A6PI4pU2Z0RNRpMI0S-V6goQvWH83eZS',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Русов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 423258683,
#     'domain': 'asindinsky',
#     'bdate': '1.4',
#     'track_code': '0bd74cfclGtqVvfbZafcxdatSAzW985GeQ4Ua7K1liODDoEUjXr5ADUwnNlh9trGvQiivjWcvVJgAgMF1sbJ',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Синдинский',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 281463775,
#     'domain': 'uskofa',
#     'bdate': '20.8',
#     'track_code': '4efaab65BPN6fDS19Du49p2gklF4-0XkbNPDWdZegqGcH2t_VGRpmCdMCrSoabz2-gR35ZuQNvB139Q3si3d',
#     'sex': 2,
#     'first_name': 'Алексей',
#     'last_name': 'Скворцов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 181102471,
#     'domain': 'abakarov1797',
#     'bdate': '20.3',
#     'track_code': '9be3c727NnDgZqPkEmgkHKgprhJw351Ho4CtMIYr-HlViXncT9RbG7IEzrYYbi0fz45LopO07lO6jLpe4lin',
#     'sex': 2,
#     'first_name': 'Али',
#     'last_name': 'Абакаров',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 268469445,
#     'domain': 'aealiev',
#     'bdate': '3.9.2003',
#     'track_code': 'e3124c2b0SlUjxu18pwShXP_B-VGTTVJzSukSB3bXyLxsjdMrRO8Qg62KregxUOGHFjhUaUmRl3UJ7MmeagA',
#     'sex': 2,
#     'first_name': 'Али',
#     'last_name': 'Алиев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 316201638,
#     'domain': 'id_aliy_albotov',
#     'bdate': '28.4',
#     'track_code': 'b51c2642ED8agUTmpCwmOcpFikmjz-k3YzAyJnfHDXPzLd4ylrN9VEHkeO2kfiQwrOBr8ECkmiN6PCVIE7RS',
#     'sex': 2,
#     'first_name': 'Алий',
#     'last_name': 'Алботов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 592346204,
#     'domain': 'idid3000',
#     'bdate': '26.7.2003',
#     'track_code': 'e3b87c21PErPfo_7hPyOnyHYVp0krVnYaLoVDfpPPzPcdZaK2qtRIZxJ4vyP_NzNT3m0KMfGKsxxtgJjnjxg',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Акиева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 199814122,
#     'domain': 'kicaalina',
#     'bdate': '7.5.2001',
#     'track_code': '0f13ab3aIYcmvV8Z_pNg_JR3PmLrs98vvJmy3kyEL2aXkRDIifRM7H2PNRv1nz2o-dXe0QjYrDullaWwKPdw',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Беспалова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 99305683,
#     'domain': 'owlslowl',
#     'bdate': '22.1.2001',
#     'track_code': '18c8a5e9D8aVknpOlrs7t8qaBtQNRmwQoaem1Bm2bVmLuk8C8JBirZ2mQ0GcuGnnpjHnU4UhDB22vMO6fcU',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Бонай',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 144484539,
#     'domain': 'a.galieva2000',
#     'bdate': '28.9.2000',
#     'track_code': 'e74794048sGAmRjloIpNupz6KMGpxgBcSp-mScnmCzwEPLZsw0Gfqt77c-Onhx3k81zJeUqtc0hTk7EnrZVU',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Галиева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 745819482,
#     'domain': 'lublu_nebo_utrom',
#     'bdate': '6.12.2000',
#     'track_code': 'aeaa8bc8b8Zdfh1JUJzjjOeWG0d8R37we3JqcsD0yc5vHJ9quE0CrQdGJB8CzOLfgjHx9J8sDeRifn0cpIeW',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Левченко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 323923200,
#     'domain': 'polyakovatyopyat',
#     'bdate': '30.6',
#     'track_code': '342dbfefaIL34BZrRew0FQrpexVFOYBNmboP7Ah4FcCl6BQUJFkF6ajWe25D6jVFZEiZpKZS81mAthiCbAtK',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Полякова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 139654296,
#     'domain': 'alina.khamat',
#     'bdate': '8.5.2001',
#     'track_code': '7f17ecfbd431-WaHrQM9WU4rxRD2UlIPBLTOOYBstN_ApsXh8bIa5qrMWo_6Cj8PJIoupxU5IRsduNlX5B_r',
#     'sex': 1,
#     'first_name': 'Алина',
#     'last_name': 'Хаматдинова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 86226248,
#     'domain': 'anti__alice',
#     'bdate': '20.11',
#     'track_code': 'c2ee7615cM-PhrrXnzODPxOZc9-Rfv7TBzSzS2b-Nybp_iXMJmMdpNDk14qcZYU9fj6ZWBkZnt4QL9YlAo0',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Антипина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 280369976,
#     'domain': 'alisaglinskaya',
#     'bdate': '23.9',
#     'track_code': 'a15cb9f8sNQMwFiDydEcXQ_fPcfQryjNzZzEmGPgu113RS0Xs_rdvwKlMobDhB1TVnXYcDPEW9nUkNP2B5Pk',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Глинская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 199458203,
#     'domain': 'allll_cash',
#     'bdate': '20.8',
#     'track_code': '4e78f299eiV4jG0-XoH5u1LGx1N2SIqocOhnaRZnNxihUFqlla4XTiLvVzpTi6i9C2cl4ZUj-bxp5HAHchRo',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Карпенко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 328909835,
#     'domain': 'bulotkaaa',
#     'bdate': '8.12',
#     'track_code': '72d1fc52bj83GxveeJyurX9eCYb-4WpotPEucNAd905GeOKK3pEDVGx6cNQux_atJPXoMh2KGXyt_TketG6o',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Карпюк',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 200590375,
#     'domain': 'tur6r',
#     'bdate': '3.1',
#     'track_code': '1b2b7770X8giE3jvu-6AfpcdN2_NoCpQ-6DLx05UMTCMnYUm03syo3kqQO-86tZyxL3S2y7LWUTirNypKidu',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Никифорова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 120220186,
#     'domain': 'veitilnorge',
#     'bdate': '17.8',
#     'track_code': '23849fea_g97L66LJe296F_Qs4FC_kGIvFoLcpKTbuFJ2MDKTLaTZHROkdl15L-4C3JZNqGVMpylVhwc9uAx',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Сырбу',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 94339233,
#     'domain': 'shalisigo',
#     'bdate': '6.3.1919',
#     'track_code': '5f7c01c1gbe4DtSEYBpOxEAPiO8R8KMj1KteGLBtWa6dsFpI4Xvs3LFs7o0wHRzJF69paJmXwy7DsDt21B4',
#     'sex': 1,
#     'first_name': 'Алиса',
#     'last_name': 'Щербакова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 156675595,
#     'domain': 'akalustyan',
#     'bdate': '5.9.2001',
#     'track_code': '67b4c101dkrvsB0wKJ4WDSH3gfQf0oeX88nVHmgTj2QYEXgdzwgbIbDVIGV7nhIOclFqQPy59IPqxcJwDGDQ',
#     'sex': 2,
#     'first_name': 'Альберт',
#     'last_name': 'Агалян',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 180761191,
#     'domain': 'sempiternalwaysofme',
#     'bdate': '10.9',
#     'track_code': 'b6396cbbSLbNpQgvFxZbGuk6KLgBDjA5Bq_fOjMrEP60RNEA_0sl3cfDM3ocEAhKv5jDCOJlQy0fo8hUV1hP',
#     'sex': 2,
#     'first_name': 'Альберт',
#     'last_name': 'Круглов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 109401327,
#     'domain': 'takoysur',
#     'track_code': '2c8f2188KqFSYnaCJfOqSt-Y3jne6A7bNni5ZGgZ9prpvQSamhlHylpbT4Bw-qYchjg-jz2Dfc8vdK4KDGqp',
#     'sex': 2,
#     'first_name': 'Альберт',
#     'last_name': 'Яппаров',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 214575410,
#     'domain': 'amaroff',
#     'bdate': '13.6.2001',
#     'track_code': '55cdc930uQvoT1JgZlQ7_B6w8vouzD9Uwpc_RIHC2jZFbQxLG0_UYLB-PWExVTv_QhcRS82nTEDbmygq5bGF',
#     'sex': 2,
#     'first_name': 'Амир',
#     'last_name': 'Умаров',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 251372125,
#     'domain': 'nastya_dorush',
#     'bdate': '30.8',
#     'track_code': '89a10e22kvij5h94-SWMNFrZxVPYCaXsI0yqABiDRZ2rf7FYCeb_k6rVL3qqdoplAnsl5zti1vg6QL1ufPAa',
#     'sex': 1,
#     'first_name': 'Анастасія',
#     'last_name': 'Доруш',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 229628167,
#     'domain': 'ottokeana',
#     'bdate': '16.12.2001',
#     'track_code': 'f2685d3a9Q_6zvwa4QkMUWXfrJecSAPdGJmx4H5kAzlTREPNJvCYZPKqxxq1BAlaNn1IIX8jcMkBlaaOGhdc',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Акчурина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 110855291,
#     'domain': 'nistergy',
#     'bdate': '22.5',
#     'track_code': '59736d8aquc8C3AM-GDRbttGRnZMN_Sjgp_OJnn2_BcbtMAK1L_HjGE5SQTxNt1pguetxq9ch7ebk9lIHYWj',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Андретти',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 227894752,
#     'domain': 'welljusttag',
#     'bdate': '22.8.2001',
#     'track_code': '2ace6f3a09gykKF2345u70acg8S7pvW2-14q_1RK6vanNjuUWOy-szjxkHSPjGXuHzhkd1jNhqLiUj2RMDm1',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Артюшина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 141238566,
#     'domain': 'blatte',
#     'track_code': '70e4199bMIODYOEcPN6iYccordEASm14ScxZU0lOmOEaQye6Zcxd6NxS0E5p2qNlkY5JZuMhHmxQwE49LT3H',
#     'sex': 2,
#     'first_name': 'Анастасия',
#     'last_name': 'Брагина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 165562935,
#     'domain': 'id165562935',
#     'bdate': '4.7',
#     'track_code': '11ac32aeh8ba9ANdAVPtHaMl9r31GLPrHz9kjxrG0jzZ6DJ3vrvqrYjHbF5TB7sZ_o8XCRZzwP8GM3PhfrWN',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Бурякова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 136785454,
#     'domain': 'temnomayskaya',
#     'bdate': '12.8',
#     'track_code': 'b8d05864kMJ3TdIK3wYFK9Hkm9DRoIGZOmIHaDUrm4Y7eNZ-9Sz9qSh66lrUBVEqlEN8ZTLL8o0jbhAGUVjE',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Елфимова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 170788632,
#     'domain': 'kemmeritocracy',
#     'bdate': '21.6.2002',
#     'track_code': '6ba486f9d2244sjDMhJiAOu1XSimsEoHX07_dl7bl4FVZrLCZg8aBuHUp8M9EmRcohC8m0XbORNGQugYOqjI',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Кеммер',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 334012376,
#     'domain': 'witchdoctorz',
#     'bdate': '23.8',
#     'track_code': '0f901f7bWROhdemMBRVPge8p8kPc0MPI1ZThL98krKlvzw4EaEo0ePMT14sPFx6Dr4kX9D-7sNzMmPZBu1fz',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Козьякова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 283819101,
#     'domain': 'id283819101',
#     'bdate': '13.3',
#     'track_code': 'b720443eFW9qsmPLwurA82hP5fQcmBxWPnyCS5Lg1I2JFz61Q8Z4BDeCC53M68j2Iu0HRP_zb0IncJUl9pOL',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Котова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 190609636,
#     'domain': 'nastiy01',
#     'bdate': '1.2.2002',
#     'track_code': '99ea8ccerNsAMDEOYC8b89L_A2bDvTUWEA1pVFbGiu_k25g73ELBsFxTCw5qKE_1n1ri0SDWRgIJAX46MrXV',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Кочура',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 341167730,
#     'domain': 'a_n_asteysh',
#     'bdate': '13.6.2001',
#     'track_code': '122605f6tPQHJxm9dB8n4g3s9QguoEBEKmB7SGXl6Kg_2kJc0xzZnwofIO0lHHOyT0gUuc3LM1AzbGwmAZa3',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Леванова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 321069640,
#     'domain': 'lie__vk',
#     'bdate': '27.12.2000',
#     'track_code': '1f53588fqBu3Ervd3_3vNylKkijjRVhmbZt_p4ukzBKLsu-EsDfFcOp2gNrc9bpgZu90mQAuK3J0l2jJ79eT',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Подберезная',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 151155479,
#     'domain': 'anastassia_rr',
#     'bdate': '3.11.2000',
#     'track_code': '8dd450937V_K8GHB2FIF94Ziwx47htH_Ykjzmc-MysGsagElLO-ANJPGXpSLUAOnxMUmptjtout7ROT3q_-V',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Расторгуева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 217367376,
#     'domain': 'anastasiavt',
#     'track_code': 'c8dcf33ap5ZQ8WkQ8x-B8P5hD9XisST9ygBlGV6x4aUo9E45bgTK_Q3HBBr7Tov1scHqYgHaV-nTDHJ3OsK-',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Тараканова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 97928806,
#     'domain': 'anusoveove',
#     'bdate': '14.5.2002',
#     'track_code': '52d92823EmONYcG0Ss_ZbHFPERKwlBrWnctp6Hb5iBBU_H0e2Op_CIMFq70cwN5gMOz1lTjzetuK0AyGEoo',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Усовецкая',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 209740229,
#     'domain': 'fobll',
#     'bdate': '1.6',
#     'track_code': '028213513iOYdtZanFNA8W_4jX9D_cebg0fMsRjN3GAVhD81MpazSMQU7gmbXhX3JVltx6CWtI-aS9vffL6D',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Успенская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 398878518,
#     'domain': 'id398878518',
#     'track_code': 'd9087365nwcjI-p4HyHRgJxm1aMS9XvWr_OW669ghyKUDj94h2bybCxH034efN6O38A2GvGeCMK2_4GFyxPY',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Фролова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 119525570,
#     'domain': 'nstkhtv',
#     'track_code': 'f12b987ajRM5iNQ8E9YGoeTO4FfHWJfAnEX1AdTL8Tt-9yYdYPvgeGC6uT1EiVerrWgF5iQz5NSFSeJvsLiu',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Хитяева',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 545173674,
#     'domain': 'tsvetik4',
#     'bdate': '3.2',
#     'track_code': 'fbeb6dcf2vu71N2iGveRid1zK2IRFraJqjEF6-b7QivtGD9kdPe3kOC24_JL-pOGk9bO1_J9xZ2zPRKFgogd',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Цветик',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 126322766,
#     'domain': 'nastya_shilovskaya',
#     'bdate': '27.7.1998',
#     'track_code': 'ce102d68nz3dpYZ_4Cyj6z5jB-SRUf1S2bqtcN8trqdInpxAhyPyVtPBvHixLfXpcsfjU3I6jkbAtroeu17x',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Шиловская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 182405613,
#     'domain': 'hedgehoggyhoge',
#     'bdate': '12.9',
#     'track_code': '0bda96far8oYJ3EfYEW39VJk_I4ycYjFRm7iCDHcWtVx_alo3cTCoRUQTxY8R7OkGMEfPNEa-9FfYvVmVa8F',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Широбокова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 164191158,
#     'domain': 'schukinaau',
#     'bdate': '12.11',
#     'track_code': '796d5e39ZfdyUiUinvYq0yA7DTklRQOSONfOx5Gm5rr_-8qYLC4LkHcKERiX8yzWmQuv3pymaOEszsLQ_8KV5Q',
#     'sex': 1,
#     'first_name': 'Анастасия',
#     'last_name': 'Щукина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 166226503,
#     'domain': 'akruglov2',
#     'track_code': 'ff15750fc3MRZysL89vNUddNWY7rL2-7VH5hS7VkpyZmNmuIwGcdFBA4Gjf138pSZHr_bFnMBMhAZ21c2wDUeQ',
#     'sex': 2,
#     'first_name': 'Анатолий',
#     'last_name': 'Круглов',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 320339991,
#     'domain': 'gelichek',
#     'bdate': '21.12.2003',
#     'track_code': '04925b40HoEDO1d_BTyCuNrQAGAqIDEMkVkt-WGSeXg1xwODjh5w5lhiMxMFbIq8a-iqi5rDWn-FQCHuD_YKJw',
#     'sex': 1,
#     'first_name': 'Ангелина',
#     'last_name': 'Бабина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 56725912,
#     'domain': 'owl2018',
#     'bdate': '16.5',
#     'track_code': '6cba42c4UmdA9814c0IsGen3JpDmqhSFto6aftoL6V6EKurL6f88ABqt9EdzRyxJX8-EcGEic-W7mYEbtG-a',
#     'sex': 1,
#     'first_name': 'Ангелина',
#     'last_name': 'Зинина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 311599071,
#     'domain': 'rothaarigekarlik',
#     'bdate': '29.10',
#     'track_code': '6101ab56ssQiLYjUQGT8aPDyExXxqUpLwYw_Ntlg918sjSXGN4Xco3An7OVKN6xoTcqw8EFKITjVlTMhtwSEAA',
#     'sex': 1,
#     'first_name': 'Ангелина',
#     'last_name': 'Изюмова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 12325849,
#     'domain': 'grecenka',
#     'bdate': '16.3.1994',
#     'track_code': 'e93d50d2Q9aJEX9WPO44-RTaVBhBFZtlJYoO1OyjQXw7WxzysVctsdkZHWY47j2opOPz88ad_AUonRWxgscy',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Гречко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 443274632,
#     'domain': 'andrei_kras',
#     'track_code': '38284f8d_DqdzPedzmUHqSAAgbQf4uJ2veYoF8p0hnISwVZCoKuSXciXxvfNZwz5kTUkVawBiQWp_yQApBD1LQ',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Красовицкий',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 275075075,
#     'domain': 'flutzz',
#     'bdate': '10.7.2000',
#     'track_code': 'f776dabbOyAl9631qll9K-2UFefZxzohH22Bk6E8twZcXs6U4ytVR3-ky5muCCp9XaC2Am0kUVILdI2Ez1jEWQ',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Михайловский',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 249654578,
#     'domain': 'mokrugin_a',
#     'bdate': '15.12',
#     'track_code': '951a631dJXAQOPAO4LSiBJFC632-y9hDrzZsZvk5COpo_zlTFRVLFxVrwjextKhXLHdNmAcoszC7L2Bxl117tQ',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Мокрушин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 419039441,
#     'domain': 'id419039441',
#     'bdate': '1.6.2002',
#     'track_code': '04ffc983iS98KomRo1Zq60_He0XtO9shlQ81cpUrP8tuJZuAC4TnSHl46PmhXzDo9f_co13YsFKBFjll-09MlA',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Полтавский-Угольников',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 304572683,
#     'domain': 'andrprnn',
#     'bdate': '13.11',
#     'track_code': '8d7a4e7cghpr3KTjQzQne_Kitpeat5ylNPgXgTu1YXUuFasJs0TsfTiAl4lEPCN5T5ETfShU99Yg4RuWVdESKg',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Пронин',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 262289748,
#     'domain': 'andrewtyulenev',
#     'bdate': '30.11',
#     'track_code': '0c485f09cVM_02W6wsBxrmT0j5FJFXfniC3uNMD90Ou5SbzEWVEfNDiNV4KTlHGr18wrd_D2HJScNOIjrpmjtA',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Тюленев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 297647067,
#     'domain': 'dre.impuls',
#     'bdate': '6.3',
#     'track_code': '6ee64b0bZ9iBSPaynz4ZapFen7nHLcxlei9Zgq9HyEDmfjR6Z38Jv4Aax93LM0tlKWg8XXHOpxZuNlWVwSO7Hw',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Шпанчук',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 426940860,
#     'domain': 'shulga_andrei',
#     'bdate': '27.11.1985',
#     'track_code': 'fd292495aK966CG8-p-o7jKKQPG8DKWqB6ttUQQ2rVzEnWtQOPgGyCvhRdSozqmzi7vrFQ3vztkTsmFGalLeAw',
#     'sex': 2,
#     'first_name': 'Андрей',
#     'last_name': 'Шульга',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 116823354,
#     'domain': 'remarka_please',
#     'bdate': '1.5.2002',
#     'track_code': '7cccc61e2Mz8kbDdZ8KA-Gg12XwfnrgFEHdgcpjbtoLjt1TVB2m2q_zP0exuxoPw1Ad5m6p903YEbmxl9r_F3Q',
#     'sex': 1,
#     'first_name': 'Анжелика',
#     'last_name': 'Бутова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 345646314,
#     'domain': 'annaravina',
#     'bdate': '19.6.2001',
#     'track_code': 'fa003f34cQom6VzVsiiH3ZO3f_TbCVb6eaIEqtzleUr7PbJR658fbXDmObniKtCKKIDfF27qPYltuwi9soEKFQ',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Аравина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 668344930,
#     'domain': 'id668344930',
#     'bdate': '8.5',
#     'track_code': 'f60036979VA9iNoYxYp_QpL3TVAmgI0kkyLwSKp-IOvofPY0u4CbN2rU6HeVin5JNsLnsZdj5leHO_xfxBpTtA',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Блинова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 179941806,
#     'domain': 'annavidus',
#     'bdate': '11.5',
#     'track_code': '3c9286adS3POyx-Hpnl4ksWY2ckxYD8Ttd9SSv70B2XeWCfz-wMlFM-ReeiuL3ibYKhyK4aDVGChxl5dkJB0Og',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Видус',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 376919520,
#     'domain': 'goderad_maverick',
#     'bdate': '17.7',
#     'track_code': '0de3ab525sFOMO8hx4YyUe67T-LyS-kB6pAQkG0jq5e23jq8b9KIphQ6iUzDgTYJTYPpAkOognL-iRyHA0fYyA',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Викторова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 152434332,
#     'domain': 'itsagrits',
#     'bdate': '10.1',
#     'track_code': '6c88d564k-BeTGo6a3ONMpgA2fwHRFVw_XqwicFQbOv6VUFmvbb9h1wXWQdrJ9o2ODV5HbSnPgPpY7yerzQftA',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Гриценко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 211868921,
#     'domain': 'eroshenk0',
#     'bdate': '2.7',
#     'track_code': '5427841fawCA8rvkktVnVmq5dd9bhNDrs4hVMj56mGIeYBvw_1AFZ4eq2NqR1m5cyIDfP-tnu5inkVklUB7rPQ',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Ерошенко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 235127068,
#     'domain': 'violetsrblue',
#     'bdate': '10.6',
#     'track_code': '8854f0e1yOparny-IMTXzR6BDqazLeHRXfSVgpSvDqyrLWiO7BmmjV32TYAklYbKubetQgrOiqJJ7ZmV-st98w',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Иванова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 178778656,
#     'domain': 'karkovskayaaa',
#     'bdate': '6.12',
#     'track_code': '661d468bVnO4cmd0SUd_RWBq8_9mntDNYuCTnsY4Xj4E8NOH2eU4FO19X0VAFiFKwVNWGNF9u752-Z-JqFwtYQ',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Карковская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 116640274,
#     'domain': 'id116640274',
#     'track_code': 'e0ea0f45w17LQjun1nowxNT7W80wLjdGeAuEeZLsXfgSGttdUGStOcodX5nfeDTKd8r6KIXNXDVsEohu_Igupw',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Костикова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 81742295,
#     'domain': 'latunh',
#     'bdate': '2.11.2000',
#     'track_code': 'a086b870AnjiQgMLljFAZSdXGIA9f4lVnW7oBGNz4Tk3fnMbc8BsH7cQZzGaMBVjjWSyZ7r37jWQefNhDReS',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Латунь',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 40294783,
#     'domain': 'annalulikyan',
#     'bdate': '17.1.2002',
#     'track_code': 'e50229e1rhWrc3dHC0MI27BuZQiLGDwpxflDgK1f_yglyuM8pcfAcq4sQCpaEA3VHVjO6QyQW0nI7ljlwzuM',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Луликян',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 244761098,
#     'domain': 'a.nna_m',
#     'bdate': '11.12',
#     'track_code': 'e58dc893aok_lyzrWgG495xIKnuLphcY3Buq1lwS-Ns_kqwiSlkE7j_MTYFZUbvxMHiJkDJFfGvIAqbBMnaLhA',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Молчанова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 84574644,
#     'domain': 'frfrfranna',
#     'bdate': '8.6.2001',
#     'track_code': '9982293aYoNNk9QhmLblyfYNqjOPUeykmuz7OUC2ZL1XwE2stskM5BzO5h6X47XKWToN1QjZi8SX--BcLtIX',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Морозова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 411088129,
#     'domain': 'annasspronina',
#     'bdate': '25.6.2003',
#     'track_code': '56b46a58OPA-m0FWU765yM7UynAWDkmh54lyJRjO3a1J1XoKhc9Wlz7AdmhTvbzNau1okK7tItLzkH4ydqqu8g',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Пронина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 151064205,
#     'domain': 'staroverovann',
#     'bdate': '26.6.2001',
#     'track_code': 'ad4dbc3e56Co4iy-0D2AKZhCgJXTb2NOpzkfIKgTTlPjr5HTAGOJx_ixTYeEaoZ4M3chd2eMCD2zIBM3xnc9DA',
#     'sex': 1,
#     'first_name': 'Анна',
#     'last_name': 'Староверова',
# ...
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Богачёв',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 334634357,
#     'domain': 'id334634357',
#     'track_code': 'be6107f9CmTsTQ1nTVcMRIFqJov6HPvuAlF3XfPvxFBcM91LixhkA71FP1dMUFpEcl2GbEz_kJ0WSHtKnYu3Dw',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Боднарюк',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 671293005,
#     'domain': 'botayharder',
#     'bdate': '11.7.1986',
#     'track_code': '0c71dc9bhPt-pcyOOh7AzeDwR-fPnHMo9apFKlZGJ3Etg9mqm33qnCj9reE0SpXKGMDkBXt_GFvhs0k9OCJULg',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Каинитов',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 274643518,
#     'domain': 'zatboy',
#     'bdate': '16.8.2001',
#     'track_code': 'addb72a5oHnnuS3K-houkUfBIefCVTRjoglTxPS0S717p0UA25bOHrDjSfOqSHvBsfGHBHu2XxC2EF_TmtA44g',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Крючков',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 561708614,
#     'domain': 'mitskm',
#     'bdate': '30.3.2004',
#     'track_code': '8e7434177R4O_dm5DRv3qSVX43uXMwzvztSSql06qZzz7a4RnnGDeQukuodaH_-t1mxGmCLQZ5zazZ69M17aww',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Мицкевич',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 396656660,
#     'domain': 'marecov',
#     'bdate': '26.1.2001',
#     'track_code': '98471b820RXhE15VDFQnWflAxXDPDcriQ0bBMTEKdv4CokMUDvW_cuAebz4KCyFfCHVglH7uoZFXX80mX24FoQ',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Носков',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 382221737,
#     'domain': 'osmevl',
#     'bdate': '26.5',
#     'track_code': '3598cbf0zy6pbDYj2X-OqqEUICI9Fqhmc65D7aWmdS3d8hVo2EWhSfo_VU-Pc9r5ViaEw4v1wxVnt0_6y8IGcg',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Осипенко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 48905537,
#     'domain': 'id48905537',
#     'track_code': 'a64863fdc4_IuPyJnRNrDo0JBYTb1stQ8yU5qgwIy0SDiHqGlwsd6J-2mLmZSDcOfj-lYVxerDD-MiLPYmy4',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Френкель',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 253862540,
#     'domain': 'verycoollife03',
#     'bdate': '3.12',
#     'track_code': '9fa40f6cig3AtAGYWlhr8-1LiY5rFTZCXBNbUtv7NgG6Mnaj6ZLkapLmMaULC276HHovaNr2XTFICldFtZ9FXg',
#     'sex': 2,
#     'first_name': 'Максим',
#     'last_name': 'Яровой',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 145072312,
#     'domain': 'mans111',
#     'bdate': '15.8.2001',
#     'track_code': 'b94c9668uiQ6vXTgtDAt1z0-LNVoVpiIhFiK4Lmg6Mtcb4_ys1DUQ2rkFdm3NyjSwg-MNtu18_uQQYb318SblA',
#     'sex': 2,
#     'first_name': 'Мансур',
#     'last_name': 'Аглиев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 203308077,
#     'domain': 'marantino_1',
#     'bdate': '25.6',
#     'track_code': '92d21799UwBM37ZK35wF-R5FfUkDX9rvUgRKcP1bp6JrrukVFCw9ZxmNjybcmAar537erLW8sZxGHUZnkz_U_Q',
#     'sex': 2,
#     'first_name': 'Марат',
#     'last_name': 'Жаров',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 92818192,
#     'domain': 'marta_zhuravleva',
#     'bdate': '10.1.2001',
#     'track_code': 'db2ed161Kh99ufVN9KNxaX-kzh8xZ_o8taBEmfD0mVxEw5BT9rBEeCvrzHerqCtvjZZk_7bvnVy4t1_8npDq',
#     'sex': 1,
#     'first_name': 'Маргарита',
#     'last_name': 'Журавлева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 54666546,
#     'domain': 'qlxblwlxlwlxlwldxlp',
#     'bdate': '21.5.2003',
#     'track_code': 'b4b2d75dtCTfQZ1c8-ipyoQEp03KU9iorvHhZ6zYT5BeuzDPwynaQ4VMpGT-7qbLeTIAqU3bv8ij5voCwrw8',
#     'sex': 1,
#     'first_name': 'Маргарита',
#     'last_name': 'Рябова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 152114541,
#     'domain': 'm.timirbaeva',
#     'bdate': '2.2',
#     'track_code': 'dd927b90GVZnH4JNpid2YsyIw2k2AUqK-dRxh3FXzMDhzpgULXN3MTJHtHevKnwxMb9lj4biIfntzX2QHzO_nw',
#     'sex': 1,
#     'first_name': 'Маргарита',
#     'last_name': 'Тимирбаева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 326426305,
#     'domain': 'mylastnameisnticecream',
#     'bdate': '22.2.2004',
#     'track_code': 'f595567dmC8TMiYJaO59JMbzl5_ZcfwZquExAvvTVAiCj-mN6_f2SEY4ETNivX0gOcY3fW2Sl2q--D0VlbcnVw',
#     'sex': 1,
#     'first_name': 'Маргарита',
#     'last_name': 'Шашнова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 50739889,
#     'domain': 'borissovam',
#     'bdate': '30.8',
#     'track_code': '588f06caAK_cdQ-y90fnPtAfUAo49c6mfXWVKCald-BNwyDfFbRuyIombInyQOZvJyT74b99qcZwYo5NSMEE',
#     'sex': 1,
#     'first_name': 'Марина',
#     'last_name': 'Борисова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 360901615,
#     'domain': 'marishahochetspat',
#     'bdate': '4.5',
#     'track_code': 'c1e04e86b9kaCMUboqFX8yWFLurCInBWydQJg0W5J0Iardt8EFgBvk9apCGp9QXz2reLCXbBGyXdzQWUK91UHQ',
#     'sex': 1,
#     'first_name': 'Мариша',
#     'last_name': 'Терская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 589202205,
#     'domain': 'maria_anttt',
#     'bdate': '18.9',
#     'track_code': 'c1754607ceXg26XyexIJalpUO5_SrUSZaOvbkLo9QE3-6ds_6SMfguKJwJ1-GwJsumWafWZOL-p88teH1FkzEg',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Ант',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 370514239,
#     'domain': 'arbuzova.mary',
#     'track_code': '9e69e3b58EPm6-wbeRPj1z_01zGNqswdkAtkrXN-LjYWH1j01zCeJLTl3yVzQeuD38N20DVJp26EEmi6HRpdaQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Арбузова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 186535095,
#     'domain': 'mbegtina',
#     'bdate': '21.8',
#     'track_code': '911b1691qwKY7DiZV46RfDJAAng-bHSCPDmizX6sOk4XPYRKeoLFZc6xCaFWhsJ803ahk4qPH_EoIK7aEMhJEQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Бегтина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 709743,
#     'domain': 'mariabystrova',
#     'bdate': '9.9',
#     'track_code': 'ce73618cSIiO_K2KP-M6gmpXXnTBx1vwu-FjhanNJvAbqCNU65om7972m7tptmbWjWfLyyFQNoevkwrgxw',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Быстрова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 272752869,
#     'domain': 'sbimmoral',
#     'bdate': '1.10',
#     'track_code': '03b144042-Pw05OXFVylE2oK43gDjqIyXsLsDKVUsAztJ0Z9_8W1hKSMo6lEDa4QiztInLttyUFK2-AbyzDDUw',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Дынкина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 365850939,
#     'domain': 'id365850939',
#     'bdate': '21.8',
#     'track_code': '4c6144cb3dm1S5mJrBV91cQx1C60t-FrNGbi_Jy194I2QQ4kP6SzvuREq-SoR37fJAJ-zwxUihggf-7r8tGE3Q',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Колосова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 100506791,
#     'domain': 'korolkovo',
#     'track_code': 'e58a73fchjdkvMgLRP-PhVT__ODAfsRBJ34UpRjol3ujDNtahVfoUDG1_TsR_o-IsspYC3CdrzIzZxiydozkJA',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Королькова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 202561855,
#     'domain': 'dream_of_lilac',
#     'bdate': '7.8',
#     'track_code': '28121208sRhYwCn9BRRi2JUoJNzJVSpd7x4tWrezv7DySyLH3ITffwqbSJcHHDXfdBqPO322QS77ByFN2dfM7w',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Лабазанова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 267345882,
#     'domain': 'mariialysenko',
#     'bdate': '18.1',
#     'track_code': '8ec12a7c4AczLBETE3Jy7OUkhb9qdnOu00pm7tlaWVCzjW3eXAqOYDEicikWdnfqCRIuVdmVGN3HU2r5tz4qDw',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Лысенко',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 215830236,
#     'domain': 'mrrkaa',
#     'bdate': '20.4',
#     'track_code': 'c416740b33BPTuOqszSbArfxpvzXynJjofCrnBSUfBqwxRjR3_6xFx8S15azMZZeXcIHHWApGRC16aeLevAPRQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Мишхожева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 540628947,
#     'domain': 'bwovllln',
#     'bdate': '9.7',
#     'track_code': '51dd6a83Zkt68CrWq7BfvMpWe2YDj-feKQkmAyR04FYPwWzmj-8ILCH9H-f4sA28Im3RgLVsjK09ECoUShCTCQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Овина',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 292788872,
#     'domain': 'id292788872',
#     'bdate': '16.12',
#     'track_code': 'e659dd4cxFiHF8NBzlGgQiD9HA5Xe0kDEXcgPURofcLQmr0aRWyqP4FE9CuYXPYRw8a36-SYInAFbiwqKgwOnQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Правдолюбенко',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 21634006,
#     'domain': 'wartenbergwheel',
#     'bdate': '26.3',
#     'track_code': '9d92cb14LvQsHpqX0Gb0mQ96sn8slTZLMuEZHOLOJFLxfqgAdEBAk3pM_K2DZvSf50kRm6sdUSs_9gJ5jKpX',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Родионова',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 326452339,
#     'domain': 'm.rondikova',
#     'bdate': '12.11.2003',
#     'track_code': 'd2bc9ccf-f9RcwbHuZ4BOzn00Wmv66jykZ60n0cymn7e4vnxsV2XmAorZfi6yQZp0cVxiBcIw4GFh7iIKVbpIQ',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Рондикова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 301925212,
#     'domain': 'beata_beatrix',
#     'track_code': 'c87b1d0dxGvWaqZTQL7N5ZMDPOoLesN030RhxKWcQm2qVLPQRaSqDNQ4lDlBu8XpfzWdCbiZqAfLXW3Ty_gxMg',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Сидоренко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 235388948,
#     'domain': 'mariesolntseva',
#     'bdate': '28.10.2002',
#     'track_code': '2f878a4698Cb1LEurAo6y5E0aXT6Q2NJ_Hq1F3JOtyhuOZ-_dbaZp8nZgxD_DzrNdg_DkkOgCDroY7kAHCrEdw',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Солнцева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 43907854,
#     'domain': 'maria_uchaeva',
#     'bdate': '3.3',
#     'track_code': 'ad2b3578-qePsMgaG3-UUz1FL7L5qtMScKwUt3JokWM6L0zlBaiUwI-6rnMYfcta6n6JVH4itHJ9uw_SHAzi',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Учаева',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 361587741,
#     'domain': 'miaxgarsia',
#     'bdate': '11.5',
#     'track_code': '2e80da321Nv-C1EU1CRr484HbuWaPxFHCdwzkzTmPK6ICOYT5wa6vP8CYH7VJ2PgFzPKAyrcejQdxT-EWoJP8Q',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Черкасов',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 306345924,
#     'domain': 'shapmars',
#     'bdate': '1.4',
#     'track_code': '0a478618gKQUL06_zLO_XzaNu6P5j31MA8VYBdZv1qjNYgyIIYXuwxFzKIXMt7xY4LsRQ0xsFj8X3FQSuAul9w',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Шаповалова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 186084074,
#     'domain': 'ftot68',
#     'bdate': '8.6.2001',
#     'track_code': 'e8b752c6JtNGePBoWeyKt8ZqbuHCgwN1t47vnjdEI-3WGxGCfM5ItBAiyQQJto3jHV3NBHdgaAajl-OJWSBQsg',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Шумейко',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 270139674,
#     'domain': 'mariselits',
#     'bdate': '23.7',
#     'track_code': 'db2ae4f9Z12uwyanJDM0H7A1_rs5zxlpqusy-33Xaon94u-13nAJOv-ZR5gjNTEdZw9bXowschq-8j7sE7MZ1g',
#     'sex': 1,
#     'first_name': 'Мария',
#     'last_name': 'Юшковская',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 4144285,
#     'domain': 'id4144285',
#     'bdate': '29.5',
#     'track_code': '9ed27a92HWbIBQ_j2hPmwwei1IXNJH12t6U2UiG1vxWF5C2KVDtzAZtaO93XQ7fF0JlyUSGgCQ-0pV83T9E',
#     'sex': 1,
#     'first_name': 'Марта',
#     'last_name': 'Измайлова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 63653384,
#     'domain': 'hellwasboring',
#     'bdate': '16.4',
#     'track_code': 'd2cc957c8JjZdopFpBse7TlBZBO_fuOqU5NhqHQp9yTUOwvqxrie_40l7HumGBzu7HHP9Tj2hMpehHrNGk2E',
#     'sex': 1,
#     'first_name': 'Маруся',
#     'last_name': 'Горшкова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 170778996,
#     'domain': 'mriaolegovna',
#     'bdate': '11.3',
#     'track_code': '48481c7aHi1NZqUOX7AP7_rOLF00c-gtZRdH9xWsbJrmKfhZglhwSkg6xjEPtV7tKvWGtoOQg15xDkvge8gfxQ',
#     'sex': 1,
#     'first_name': 'Марья',
#     'last_name': 'Голодова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 376698930,
#     'domain': 'kwakuskakwa',
#     'track_code': '372144558dCL7gyZ1S19CN5ThHpa0LPnnfsnBRuSDD9ClBLyW4qft4nkbvXefClYD2gum-sz2JSJ4isSdfZ_YA',
#     'sex': 1,
#     'first_name': 'Марья',
#     'last_name': 'Морева',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 84659882,
#     'domain': 'chrispower',
#     'bdate': '5.6',
#     'track_code': 'fff0c0f7R7m1FSf-RFljm6kBzcwkeJLDI1qCbK9soDNBPHxZDA0p3rAdRpBEVW3LeTpmLKPw9aMuTZkJwQjT',
#     'sex': 2,
#     'first_name': 'Матвей',
#     'last_name': 'Бакшук',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 180064800,
#     'domain': 'mtvbsl',
#     'bdate': '20.9.2001',
#     'track_code': 'ece785e6JJFaIj_8J8dx0pNYMTQnshZgkipWhH5fO7IsdpwntrRK9gB-CMQmzXXXT2-a1pZRfROGM1qTEDtI7Q',
#     'sex': 2,
#     'first_name': 'Матвей',
#     'last_name': 'Бислер',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 64471095,
#     'domain': 'matvikkk',
#     'bdate': '9.10',
#     'track_code': '02708cb4vZAd4rSIcKuc9aMOKd1kPSj80HqqsobG0X6d783kk6XT9x3tgbcj_c31eT2DOuO1T5zdbbHX6KKi',
#     'sex': 2,
#     'first_name': 'Матвей',
#     'last_name': 'Медведев',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 249200856,
#     'domain': 'matvei.revazov',
#     'bdate': '16.4.2003',
#     'track_code': '0851aea1cdAkD0qyaDaNNzqUrnPORvijBaufd8oF44ogS6FQPIwftyNdft1vZ9Jk5qcFlHmlk9ARspNgpGGQ1Q',
#     'sex': 2,
#     'first_name': 'Матвей',
#     'last_name': 'Ревазов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 220662252,
#     'domain': 'milanawhale',
#     'bdate': '27.11',
#     'track_code': '8754038am3Q6VgFyrDe262WbzotXkp06oI206Mh_AOVdIPYxmjL1E2heMx-rPbPpvqpvbORx9km0lLj_phtzug',
#     'sex': 1,
#     'first_name': 'Милана',
#     'last_name': 'Лысенкова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 198944065,
#     'domain': 'pavbooo',
#     'bdate': '26.12',
#     'track_code': 'e4e3e98byoy7diT5dDLxgqeFroustHK03Ma2Ujw8ipsNg5_Gobuk6-AkR8F3OfzafbINbxhXGcfI37pFUlj5xA',
#     'sex': 1,
#     'first_name': 'Милена',
#     'last_name': 'Боровкова',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 356537264,
#     'domain': 'miravrodedatochnomira',
#     'track_code': 'b07ec0abB8a4PwAVa7eJNqM37ImnU2BrWhcGS9gMMOfwEI34N6NpobplMiVrsodnfwNNbRKwCxhODgpctmhDuA',
#     'sex': 1,
#     'first_name': 'Мира',
#     'last_name': 'Киркевич',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 274660984,
#     'domain': 'miroslavkrasnov',
#     'bdate': '25.9',
#     'track_code': 'c1ccd67eDmWPRFGfaWibN2ANRFiw8dCX0q07luZDNRS6aj_De_9gAo0XZaJob5g5pj7usgUSu-TGtDeBiCdGSw',
#     'sex': 2,
#     'first_name': 'Мирослав',
#     'last_name': 'Краснов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 180177040,
#     'domain': 'mitya1917',
#     'bdate': '20.8',
#     'track_code': 'd6ccad1f-7UzkkUNpmsI3VrsDW6W5jpzclDVVeCrGJCIPigEB8eV0jGccT2uZg_ZnNiuiCcFUQBmSdlCjs9rzw',
#     'sex': 2,
#     'first_name': 'Митя',
#     'last_name': 'Думбров',
#     'can_access_closed': True,
#     'is_closed': True},
#    {'id': 229232848,
#     'domain': 'stealme',
#     'bdate': '29.1',
#     'track_code': 'aa33d538l3_fHSusmxOnikOsCWN8SFumdLBjTpLYXKCCQa2sW0D5GItFGMCRFv3agp2ihcWrMNVgqW9Z_Lwv_w',
#     'sex': 2,
#     'first_name': 'Михаил',
#     'last_name': 'Алфимов',
#     'can_access_closed': True,
#     'is_closed': False},
#    {'id': 588358050,
#     'domain': 'catt_inside',
#     'bdate': '2.10.2004',
#     'track_code': 'f05f6fac_4qiOX4jNT88yJxIbd-CpB6EWgdY22AxXapKsWhXtUWR7fYwShxjPjKZWnPOODNHdfdOHlTMDlUu9Q',
#     'sex': 2,
#     'first_name': 'Михаил',
#     'last_name': 'Журавлев',
#     'can_access_closed': True,
#     'is_closed': False}],
#   'profiles': []}}

# %% [markdown]
# <p></p>
# <center><b><font size=4>Задача №4</font></b></center>
#
# **Напишите функцию `get_my_friends()`, которая принимает на вход параметр `method` (используемый метод) и возвращает `pandas.DataFrame` с базовой информацией о ваших друзьях:**
#
# * `id` пользователя;
# * `first_name` пользователя;
# * `last_name` пользователя;
# * `sex` – указанный пол пользователя;
# * `is_closed` - профиль пользователя "закрытый" (`True`) или нет (`False`).
#
#
# *Подсказка: выведите на экран переменную `parameters`. Поместите её в тело функции*.

# %%
parameters
# Out:
# 'count=500&order=name&extended=1&fields=bdate,sex,domain'

# %%
def get_my_friends(method='friends.get'):
    # 1. Отправляем запрос
    parameters = 'count=5000&order=name&extended=1&extended=1&fields=bdate,sex,domain'
    url = 'https://api.vk.com/method/' + method +'?' + parameters + '&v=' + version + '&access_token=' + token
    response = requests.get(url)
    response = response.json()
    
    # 2. Собираем данные
    ids = [response['response']['items'][i]['id'] for i in range(len(response['response']['items']))]
    first_names = [response['response']['items'][i]['first_name'] for i in range(len(response['response']['items']))]
    last_names = [response['response']['items'][i]['last_name'] for i in range(len(response['response']['items']))]
    sex_of_users = [response['response']['items'][i]['sex'] for i in range(len(response['response']['items']))]
    is_closed_profiles = [response['response']['items'][i]['is_closed'] for i in range(len(response['response']['items']))]
    
    # 3. Соберите pandas.DataFrame
    df = pd.DataFrame({'friend_id': ids,
                      'first_name': first_names,
                      'last_name': last_names,
                      'sex': sex_of_users,
                      'is_closed': is_closed_profiles})
    return df

# %%
my_friends = get_my_friends() # функция должна выводить датафрейм с вашими друзьями
my_friends
# Out:
#      friend_id first_name    last_name  sex  is_closed
# 0    463008298  Alexandra      Oorzhak    1      False
# 1    511785586      Alina          Ell    1       True
# 2     53414043   Angelika  Zagashvilli    1      False
# 3    501118101       Anna      Oorzhak    1       True
# 4    338357646      Anopa        Anopa    1      False
# ..         ...        ...          ...  ...        ...
# 671  245402649      Maxim         Bong    2      False
# 672  225843054  Анастасия    Анисимова    1       True
# 673  211058196    Виталий         Чаус    2       True
# 674  322747261        Ира        Голос    1      False
# 675  182197491        Юля     Комарова    1      False
#
# [676 rows x 5 columns]

# %% [markdown]
# Давайте обработаем наш датафрейм. Во-первых, создадим переменную `full_name`:

# %%
 # склеим значения из двух колонок с помощью пробела
my_friends['full_name'] = my_friends['first_name'] + ' ' + my_friends['last_name']
my_friends['full_name'] # получилась новая колонка
# Out:
# 0         Alexandra Oorzhak
# 1                 Alina Ell
# 2      Angelika Zagashvilli
# 3              Anna Oorzhak
# 4               Anopa Anopa
#                ...
# 671              Maxim Bong
# 672     Анастасия Анисимова
# 673            Виталий Чаус
# 674               Ира Голос
# 675            Юля Комарова
# Name: full_name, Length: 676, dtype: object

# %% [markdown]
# Во-вторых, преобразуем в более понятные значения значения из колонки `sex`:

# %%
# используем запись в словаре
# если в переменной sex находится 1, вернется значение "ж"
# если в переменной sex находится 2, вернется значение "м"
my_friends['sex'] = my_friends['sex'].apply(lambda x: {1: 'ж', 2: 'м'}[x]) # используем apply() и анонимную функцию
my_friends['sex'] # смотрим на колонку
# Out:
# 0      ж
# 1      ж
# 2      ж
# 3      ж
# 4      ж
#       ..
# 671    м
# 672    ж
# 673    м
# 674    ж
# 675    ж
# Name: sex, Length: 676, dtype: object

# %% [markdown]
# <p></p>
# <center><b><font size=4>Задача №5</font></b></center>
#
# **А теперь давайте попрактикуемся в написании docstrings: напишите docstring к нашей функции. Сделайте следующее:**
# * Укажите её общее описание: что она делает, к чему обращается, что возвращает (в одно предложение);
# * На какой метод API опирается;
# * Какие аргументы принимает;
# * Что возвращает (и какие атрибуты есть у этого объекта);
# * Пример использования функции.

# %%
def get_my_friends(method='friends.get'):
    '''Функция обращается к методу friends.get API ВК, получает данные по вашим друзьям
    и возвращает pandas.DataFrame с информацией о ваших друзьях.
    
    Args:
    > method='friends.get'
    Returns:
    > pandas.DataFrame с информацией о ваших друзьях:
        > friend_id : int - id вашего друга вконтакте;
        > first_name : str - имя вашего друга вконтакте;
        > last_name : str - фамилия вашего друга вконтакте;
        > sex : int - отображаемый пол (1 - ж, 2 - м);
        > is_closed : bool - закрыт профиль у человека или нет (True - да, False - нет)
    Example:
        >>> get_my_friends() 
    '''
    # Ваша docstring - тут!
    
    # Ваш код функции - тут!
    # 1. Отправляем запрос
    parameters = 'count=5000&order=name&extended=1&extended=1&fields=bdate,sex,domain'
    url = 'https://api.vk.com/method/' + method +'?' + parameters + '&v=' + version + '&access_token=' + token
    response = requests.get(url)
    response = response.json()
    
    # 2. Собираем данные
    ids = [response['response']['items'][i]['id'] for i in range(len(response['response']['items']))]
    first_names = [response['response']['items'][i]['first_name'] for i in range(len(response['response']['items']))]
    last_names = [response['response']['items'][i]['last_name'] for i in range(len(response['response']['items']))]
    sex_of_users = [response['response']['items'][i]['sex'] for i in range(len(response['response']['items']))]
    is_closed_profiles = [response['response']['items'][i]['is_closed'] for i in range(len(response['response']['items']))]
    
    # 3. Соберите pandas.DataFrame
    df = pd.DataFrame({'friend_id': ids,
                      'first_name': first_names,
                      'last_name': last_names,
                      'sex': sex_of_users,
                      'is_closed': is_closed_profiles})
    return df

# %%
help(get_my_friends) # вот такую справку можно написать по вашей функции:
# Out:
# Help on function get_my_friends in module __main__:
#
# get_my_friends(method='friends.get')
#     Функция обращается к методу friends.get API ВК, получает данные по вашим друзьям
#     и возвращает pandas.DataFrame с информацией о ваших друзьях.
#
#     Args:
#     > method='friends.get'
#     Returns:
#     > pandas.DataFrame с информацией о ваших друзьях:
#         > friend_id : int - id вашего друга вконтакте;
#         > first_name : str - имя вашего друга вконтакте;
#         > last_name : str - фамилия вашего друга вконтакте;
#         > sex : int - отображаемый пол (1 - ж, 2 - м);
#         > is_closed : bool - закрыт профиль у человека или нет (True - да, False - нет)
#     Example:
#         >>> get_my_friends()

# %% [markdown]
# ## Генерируем данные для сетевого анализа<a name="par6"></a>
#
# Ниже я предлагаю вам воспользоваться уже написанными мной функциями для сбора данных по друзьям и кратко поясню, что происходит и как вы можете сгенерировать сетевые данные с помощью API ВКонтакте:

# %%
from time import sleep # чтобы делать паузы
import tqdm # прогресс-бар

# %%
def get_id_of_user_from_link(user_link, method='util.resolveScreeenName'):
    '''
    Функция get_id_of_user_from_link(user_link) принимает на вход ссылку на страницу пользователя ВКонтакте
    и возвращает его id.
    
    Args:
        :user_link: string - ссылка на пользователя;
    Returns:
        :user_id: string - id пользователя в виде строки
    Example:
        >>>> one_user_id = get_id_of_user_from_link('https://vk.com/lika.kapustina')
        >>>> one_user_id # 441721976
    '''

    screen_name = user_link.replace('https://vk.com/', '')

    # может быть такое, что ссылка на пользователя содержит id (vk.com/id777)
    if screen_name.startswith('id') == True and screen_name[2:].isdigit() == True:
        user_id = screen_name.replace('id', '')

    # если нет, нам нужно сделать запрос к ВК и получить id пользователя
    else:
        method_for_get_id = 'utils.resolveScreenName'
        parameters='screen_name=' + screen_name
        url = 'https://api.vk.com/method/' + method_for_get_id +'?'+ parameters + '&v=' + version + '&access_token=' + token
        response = requests.get(url)
        response = response.json()
        user_id = response['response']['object_id']
        
    # возвращаю id
    return user_id


def get_id_of_all_users_links(users_links, method='util.resolveScreeenName'):
    '''
    Функция get_ids_of_all_users_from_links(user_links) принимает на вход СПИСОК со ссылками на аккаунты пользователей,
    обращается внутри себя к методу `get_id_of_user_from_link(user_link)`,
    и возвращает СТРОКУ с id пользователей, записанных через строку.
    
    Args:
        :users_links: list - список с ссылками на пользователей;
    Returns:
        :users_ids_string: string - id пользователей, записанные через запятую в виде строки.
    Example:
        >>>> list_with_ids = get_id_of_all_users_links(['https://vk.com/lika.kapustina','https://vk.com/sdilov','https://vk.com/sofiagreseva'])
        >>>> list_with_ids
        
    '''
    users_ids_list = [] # создаем пустой список
    
    # идем по всему списку из ссылок
    for user_link in tqdm.tqdm(users_links):
        user_id = get_id_of_user_from_link(f'{user_link}') # получаем id пользователя
        users_ids_list.append(user_id)
        sleep(0.4) # небольшая пауза    
    
    users_ids_string = ','.join([str(i) for i in users_ids_list])
    
    return users_ids_string # возвращаем строку с id пользователей


def get_friends_of_user_only_ids(user_id, method='friends.get'):
    '''Функция get_friends_of_user_only_ids принимает на вход id пользователя ВКонтакте и возвращает строку, где через
    запятую перечислены id его друзей.
    
    Method: https://dev.vk.com/method/friends.get
    
    Args:
        :user_id: id пользователя ВКонтакте
    Returns:
        :friends_string: string с id друзей пользователя
    Example:
        >>>> limarenko_friends = get_friends_of_user('533710525')
        >>>> limarenko_friends # '626130,957188,1053362,2058801,3279648,4120747,5823842,8523846,11146055,11860274,25758390,169272036,171462727,182026369,196603818,322659228,462979979,520753933,538671248,550960397,550966564,551354669,551382456,551506228,578750417,606932606,616844912,633974128,660930698,665881497,670425420,689458339,703017057,703621379,708192084,708405503,710516910,710520153,710787650,711209497,711761122,711978083,711991565,712541914,712544833,712545388,713904031

    '''
    # осуществляем запрос
    parameters = 'count=5000' # берем максимум - 5000 друзей
    url = 'https://api.vk.com/method/' + method +'?' + parameters + '&v=' + version + '&access_token=' + token + '&user_id=' + user_id
    response = requests.get(url)
    one_data = response.text
    
    # обрабатываем данные
    first_index = one_data.index('[')
    second_index = one_data.index(']')
    friends_string = one_data[first_index+1:second_index]
    return friends_string # возвращаем строку с id друзей пользователя


def get_friends_of_user_full_info_in_df(user_id, type_of = 'id', method='friends.get'):
    '''Функция get_friends_of_user_info_df принимает на вход ИЛИ id пользователя ИЛИ ССЫЛКУ ВКонтакте 
    и возвращает датафрейм, где перечислены данные его друзей.
    
    Method: https://dev.vk.com/method/friends.get
    
    Args:
        :user_id: id пользователя ВКонтакте;
        :type_of: тип введенных данных (id пользователя ('id')/ссылка на него('link')).
        
    Returns:
        :pandas.DataFrame: датафрейм с информацией о друзьях пользователя.
        
        > friend_owner: id пользователя, информация о чьих друзьях указана далее.
        > user_id: id пользователя;
        > user_name: имя пользователя;
        > user_surname: фамилия пользователя;
        > user_sex: пол пользователя;
        > user_domain: короткое имя пользователя (нужно для ссылки);
        > user_is_closed: закрыта ли страница пользователя;
        > user_link: сссылка на страницу пользователя.
        
    Example:
        >>>> limarenko_friends = get_friends_of_user('533710525')
        >>>> limarenko_friends # '626130,957188,1053362,2058801,3279648,4120747,5823842,8523846,11146055,11860274,25758390,169272036,171462727,182026369,196603818,322659228,462979979,520753933,538671248,550960397,550966564,551354669,551382456,551506228,578750417,606932606,616844912,633974128,660930698,665881497,670425420,689458339,703017057,703621379,708192084,708405503,710516910,710520153,710787650,711209497,711761122,711978083,711991565,712541914,712544833,712545388,713904031

    '''
    
    # если type_of = 'link' (то есть, не id), нужно получить id пользователя
    if type_of != 'id':
        link = user_id #значит, нам попалась ссылка и из нее нужно вынуть screen_name пользователя
        screen_name = link.replace('https://vk.com/', '')
        
        # может быть такое, что ссылка на полььзователя содержит id (vk.com/id777)
        if screen_name.startswith('id') == True and screen_name[2:].isdigit() == True:
            user_id = screen_name.replace('id', '')
        
        # если нет, нам нужно сделать запрос к ВК и получить id пользователя
        else:
            method_for_get_id = 'utils.resolveScreenName'
            parameters='screen_name=' + screen_name
            url = 'https://api.vk.com/method/' + method_for_get_id +'?'+ parameters + '&v=' + version + '&access_token=' + token
            response = requests.get(url)
            response = response.json()
            user_id = response['response']['object_id']

    
    # осуществляем запрос
    parameters = 'count=5000' + '&extended=1' + '&fields=bdate,city,country,sex,domain' + '&name_case=nom' # берем максимум - 5000 друзей
    url = 'https://api.vk.com/method/' + method +'?' + parameters + '&v=' + version + '&access_token=' + token + '&user_id=' + str(user_id)
    response = requests.get(url)
    response = response.json()
    
    # собираем данные для датафрейма
    number_of_friends = response['response']['count'] # число друзей у пользователя
    
    # список: чьи друзья в этом датафрейме?
    owner_of_friends = [user_id] * number_of_friends
    
    
    # общая информация, получается без необходимости использовать try-except.
    friends_ids = [response['response']['items'][i]['id'] for i in range(number_of_friends)]
    friends_first_names = [response['response']['items'][i]['first_name'] for i in range(number_of_friends)]
    friends_second_names = [response['response']['items'][i]['last_name'] for i in range(number_of_friends)]
    friends_sexs = [response['response']['items'][i]['sex'] for i in range(number_of_friends)]
    friends_is_closed = [response['response']['items'][i]['is_closed'] for i in range(number_of_friends)]


    
    # информация, которую нужно получать через try-except
    friends_domains = []
    for i in range(number_of_friends):
        try:
            one_domain = response['response']['items'][i]['domain']
        except:
            one_domain = str(response['response']['items'][i]['id'])
        friends_domains.append(one_domain)
        
        
    ## ссылки на пользвателей; если есть domain - значит, с domain; если нет - значит, с id
    friends_links = list(map(lambda x: f'https://vk.com/{x}' if x.isdigit() == False else \
                       f'https://vk.com/id{x}', friends_domains))
        
    # собираем датафрейм
    friends_df = pd.DataFrame({'friend_owner': owner_of_friends,
                               'user_id': friends_ids,
                              'user_name': friends_first_names,
                              'user_surname': friends_second_names,
                              'user_sex': friends_sexs,
                              'user_domain': friends_domains,
                              'user_is_closed': friends_is_closed,
                              'user_link': friends_links})
    return friends_df


def get_friends_of_a_few_users_full_info_in_df(users_ids, type_of='id', method='friends.get'):
    '''Функция get_friends_of_a_few_users_info_df принимает на вход строку с id пользователей ВКонтакте,
    записанными через запятую, обращается к функции get_friends_of_user_full_info_in_df(user_id),
    и возвращает pandas.DataFrame с информацией о всех друзьях всех указанных пользователей
    
    Method: https://dev.vk.com/method/friends.get
    
    Args:
        :users_ids: string: ИЛИ id пользователей ВКонтакте ИЛИ ссылки на страницы пользователей ВКонтакте, записанных через запятую;
        :type_of: string: тип данных на входе (по умолчанию 'id' - id пользователей), либо 'link' - ссылки на пользователей.
    
    Returns:
        :pandas.DataFrame: датафрейм с информацией о друзьях пользователей, чьи id переданы функции.
        > friend_owner: id пользователя, информация о чьих друзьях указана далее.
        > user_id: id пользователя;
        > user_name: имя пользователя;
        > user_surname: фамилия пользователя;
        > user_sex: пол пользователя;
        > user_domain: короткое имя пользователя (нужно для ссылки);
        > user_is_closed: закрыта ли страница пользователя;
        > user_link: сссылка на страницу пользователя.
        
    Example:
        >>>> some_friends = get_friends_of_a_few_users_full_info_in_df('48905537,12900237')
        >>>> some_friends
        
    Exmple:
        >>>> my_friends_list = ['https://vk.com/zzimablue',
                                   'https://vk.com/ksperov',
                                   'https://vk.com/sofiagreseva',
                                   'https://vk.com/sdilov',
                                   'https://vk.com/narepapoyan',
                                   'https://vk.com/kirillmuzyka']
        >>>> my_friends_string = ','.join(my_friends_list)
        >>>> friends_of_my_friends = get_friends_of_a_few_users_full_info_in_df(my_friends_string, type_of='link')
        >>>> friends_of_my_friends
    '''
    
    users_ids = users_ids.split(',')
    
    full_users_friends_data = pd.DataFrame()
    
    for user_id in tqdm.tqdm(users_ids):
        try:
            one_user_friends_data = get_friends_of_user_full_info_in_df(user_id,
                                                                       type_of = type_of)
            full_users_friends_data = pd.concat([full_users_friends_data, one_user_friends_data])
            sleep(0.4)
        except Exception as e:
            print(e)
    
    return full_users_friends_data

# %% [markdown]
# Теперь запустим код ниже:
#
# **Сперва введите сюда ссылку на ваш профиль:**

# %%
# вводим ссылку на ваш профиль:
vk_profile_link = input('Введите ссылку на ваш профиль ВКонтакте: ') # моя, например, 'https://vk.com/lika.kapustina'

# %%
friends_data = get_friends_of_user_full_info_in_df(vk_profile_link, type_of = 'link') # получаем список друзей

my_friends_list = friends_data['user_link'].tolist() # получаем список друзей наших друзей
my_friends_string = ','.join(my_friends_list)        # склеиваем idшники друзей в строку, разделяемым запятыми
 
# а теперь пользуемся функцией get_friends_of_a_few_users_full_info_in_df - 
# и получаем датафрейм с моими друзьями 
# и друзьями всех друзей моих друзей (людей, которых я знаю лично и через 1 рукопожатие)
friends_of_my_friends = get_friends_of_a_few_users_full_info_in_df(my_friends_string, type_of='link')
# Out:
#   9%|███▋                                      | 59/676 [01:36<12:30,  1.22s/it]
# 'response'
#  41%|████████████████▌                        | 274/676 [06:37<07:55,  1.18s/it]
# 'response'
#  50%|████████████████████▎                    | 335/676 [08:02<06:23,  1.13s/it]
# 'response'
#  54%|█████████████████████▉                   | 362/676 [08:36<04:54,  1.07it/s]
# 'response'
#  54%|██████████████████████▏                  | 366/676 [08:39<04:11,  1.23it/s]
# 'response'
#  61%|████████████████████████▊                | 410/676 [09:39<04:39,  1.05s/it]
# 'response'
#  76%|███████████████████████████████▎         | 516/676 [11:58<02:30,  1.06it/s]
# 'response'
#  90%|████████████████████████████████████▊    | 607/676 [13:56<01:05,  1.05it/s]
# 'response'
#  90%|████████████████████████████████████▉    | 608/676 [13:56<00:51,  1.31it/s]
# 'response'
#  99%|████████████████████████████████████████▍| 667/676 [15:12<00:08,  1.01it/s]
# 'response'
# 100%|█████████████████████████████████████████| 676/676 [15:22<00:00,  1.36s/it]

# %%
friends_of_my_friends # датафрейм выглядит.. прилично!
# Out:
#    friend_owner    user_id   user_name user_surname  user_sex    user_domain
# 0        130896       1450       Елена      Карпова         1  karmannoe_zlo  \
# 1        130896       6487      Михаил       Шлемин         2         id6487
# 2        130896       9337      Даниил     Олегович         2      hashmaker
# 3        130896      11446  Константин  Печенежский         2   konstantin_p
# 4        130896      12662    Григорий    Григорьев         2        evil_gr
# ..          ...        ...         ...          ...       ...            ...
# 41    821924911  601140432      Михаил       Иванов         2       mibog108
# 42    821924911  612597498     Дмитрий        Котов         2    id612597498
# 43    821924911  720390827        Юрий     Слепичев         2         yurimj
# 44    821924911  736387180      Michel       Angelo         2       imshvets
# 45    821924911  767150124       Ultra        Fanta         2    id767150124
#
#     user_is_closed                     user_link
# 0            False  https://vk.com/karmannoe_zlo
# 1            False         https://vk.com/id6487
# 2            False      https://vk.com/hashmaker
# 3            False   https://vk.com/konstantin_p
# 4            False        https://vk.com/evil_gr
# ..             ...                           ...
# 41           False       https://vk.com/mibog108
# 42           False    https://vk.com/id612597498
# 43           False         https://vk.com/yurimj
# 44           False       https://vk.com/imshvets
# 45            True    https://vk.com/id767150124
#
# [325971 rows x 8 columns]

# %% [markdown]
# Немного обработаем датафрейм, **чтобы там остались только мои друзья, но появились данные о дружеских связях между ними**

# %%
my_friends_ids = friends_data['user_id'].tolist() # сохраняем список только моих друзей в список
my_friends_ids.append(friends_data['friend_owner'].unique()[0]) # добавляем в список себя

# создаем small_df, сбрасываем дупликаты
small_df = friends_of_my_friends[['user_id', 'user_name', 'user_surname']].drop_duplicates()
friends_of_my_friends = pd.merge(friends_of_my_friends, small_df, left_on='friend_owner', right_on='user_id')
friends_of_my_friends = friends_of_my_friends[['user_id_x', 'user_name_x', 'user_surname_x', 'user_id_y', 'user_name_y', 'user_surname_y']]

# Создаем колонки с полными именами пользователей
friends_of_my_friends['user_x'] = friends_of_my_friends['user_name_x'] + ' ' + friends_of_my_friends['user_surname_x']
friends_of_my_friends['user_y'] = friends_of_my_friends['user_name_y'] + ' ' + friends_of_my_friends['user_surname_y']

# Оставляем в friends_of_my_friends только тех пользователей, которые есть у вас в друзьях:
friends_of_my_friends = friends_of_my_friends[(friends_of_my_friends['user_id_x'].isin(my_friends_ids)) &\
                     friends_of_my_friends['user_id_y'].isin(my_friends_ids)]
friends_of_my_friends # финальный датафрейм!
# Out:
#         user_id_x user_name_x user_surname_x  user_id_y user_name_y
# 784      12325849      Андрей         Гречко     130896        Егор  \
# 963      38031682       Юлиан       Баландин     130896        Егор
# 968      38584695       Федор     Духновский     130896        Егор
# 987      42187308        Иван    Александров     130896        Егор
# 994      43907854       Мария         Учаева     130896        Егор
# ...           ...         ...            ...        ...         ...
# 296989  202296311      Данила        Морозов  821924911   Александр
# 296997  241798539     Николай          Лобов  821924911   Александр
# 297002  274066679       Дарья      Рахмалёва  821924911   Александр
# 297013  441721976        Lika      Kapustina  821924911   Александр
# 297016  483098773     Арсений      Самусенко  821924911   Александр
#
#        user_surname_y             user_x               user_y
# 784           Юрескул      Андрей Гречко         Егор Юрескул
# 963           Юрескул     Юлиан Баландин         Егор Юрескул
# 968           Юрескул   Федор Духновский         Егор Юрескул
# 987           Юрескул   Иван Александров         Егор Юрескул
# 994           Юрескул       Мария Учаева         Егор Юрескул
# ...               ...                ...                  ...
# 296989      Матвиенко     Данила Морозов  Александр Матвиенко
# 296997      Матвиенко      Николай Лобов  Александр Матвиенко
# 297002      Матвиенко    Дарья Рахмалёва  Александр Матвиенко
# 297013      Матвиенко     Lika Kapustina  Александр Матвиенко
# 297016      Матвиенко  Арсений Самусенко  Александр Матвиенко
#
# [28164 rows x 8 columns]

# %% [markdown]
# Давайте сохраним наши данные.

# %%
friends_of_my_friends.to_excel('my_friends_network_31_01_2024.xlsx')

# %% [markdown]
# А теперь прочитаем их заново и создадим объект `GEXF` для дальнейшей работы в GEFI. Для этого импортируем пакет `networkx`, позволяющий строить сети и работать с сетевыми объектами в Python.
#
# <font color='orange'>Если на моменте импорта `networkx` вы столкнулись с ошибкой</font> ```ImportError: cannot import name 'gcd' from 'fractions' (/opt/anaconda3/lib/python3.9/fractions.py)```, откройте этот ноутбук в Google Colab и продолжите работу там.

# %%
import networkx as nx # импортируем пакет networkx как nx для того чтобы работать с сетями

# %%
df = pd.read_excel('my_friends_network_31_01_2024.xlsx') # сохраняем в df наш датафрейм

# %% [markdown]
# Тут мы используем функцию `.from_pandas_edgelist()`, которая позволяет создать сеть на основе датафрейма `pandas`, где `user_x` - это пользователь, от которого исходит ребро, а `user_y` - пользователь, к которому идет ребро. Запустим код ниже и сохраним нашу сеть в переменную `G`.

# %%
G = nx.from_pandas_edgelist(df, 'user_x', 'user_y')

# %%
G # сетевой объект

# %% [markdown]
# А теперь сохраним эту самую сеть в формате `.gexf`, чтобы дальше мы могли открыть этот файл в Gephi.

# %%
nx.write_gexf(G, "my_friends_network_31_01_2024.gexf") # сохраняем

# %% [markdown]
# А теперь давайте откроем **Gephi Lite** – недавно вышедшую онлайн-версию программы Gephi, которую вы можете открыть онлайн.
#
# * Откройте ссылку: https://gephi.org/gephi-lite/ ;
# * Выберите `open local graph`, и откройте документ `my_friends_network_31_01_2024.gexf`;
# * Откройте `Statistics` и посчитайте `degree` и `Louvian community detection` метрики;
# * Откройте `Appearence (node)` и установите цвет в зависимости от модулярности;
# * Откройте `Layout` и поэкспериментируйте с позицией сети.
#
# **Обсуждали ли вы модулярность и метод выявления сообществ Лувена?**

# %% [markdown]
# ## Заключение<a name="parlast"></a>
#
# Сегодня мы с вами обсудили API ВКонтакте. Надеюсь, это было полезно для вас. То, что я советую вам помнить:
# * **Если можно использовать API - используйте API**;
# * **Запомните способ, с помощью которого генерируются запросы к API ВКонтакте**;
# * **Работаешь с API и не понимаешь что делать? Обращайся к документации!**
